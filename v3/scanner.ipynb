# %%
import pandas as pd
from datetime import datetime
import yfinance as yf
from scipy.stats import linregress
import numpy as np
import ta
import os
import matplotlib.pyplot as plt

# %%
#get circuit limit data for stocks 
circuit_limit = pd.read_csv("F:\\Bot\\MomentumStrategy\\nifty500_price_bands.csv")
circuit_limit['stock_name'] = circuit_limit['stock_name'].str.strip()
print(circuit_limit.columns)
# Out:
# Index(['stock_name', 'price_band'], dtype='object')

# %%
def exponential_regression(x, y):
    #log of closing price
    log_y = np.log(y)

    #get slope, and r_value
    slope, intercept, r_value, _, _ = linregress(x, log_y)

    '''
    r**2 -> coefficient of determinent
    ranges from 0 - 1
    ''' 
    return slope, intercept, r_value**2

# %%
def annualize_return(daily_slope):
    return ((np.exp(daily_slope) ** 250) - 1) * 100

# %%
def calculate_adjusted_return(df, ticker):
    '''
    returns -> list [ticker, slope, annualized_return, adjusted return]
    '''

    #getting last 90 days data
    x = np.arange(90)                   #list from 0-89
    y = df['close'].iloc[-90:].values   #last 90 closing prices


    slope, intercept, r2 = exponential_regression(x, y)
    annualized_return = annualize_return(slope)
    
    adjusted_return = annualized_return * r2
    

    return [ticker, slope, annualized_return, adjusted_return]

# %%
def check_circuits(df, upper_circuit=20, lower_circuit=20):
    '''
    hit -> if circuit was hit in the last 90 days
    freq -> frequency of circuit hits 
    '''

    hit = False
    freq = 0
    upper_circuit = int(upper_circuit) - 0.01
    lower_circuit = int(lower_circuit) - 0.01

    # Filtering the last 90 days data
    days_90 = df.iloc[-90:, :].copy()

    # Calculate the upper and lower circuit levels
    days_90.loc[:, 'upper_circuit'] = days_90['close'].shift(1) * (1 + upper_circuit / 100)
    days_90.loc[:, 'lower_circuit'] = days_90['close'].shift(1) * (1 - lower_circuit / 100)

    # Initialize the circuit columns 
    days_90['Hit Upper Circuit'] = False
    days_90['Hit Lower Circuit'] = False

    # Explicitly cast columns to bool dtype
    days_90['Hit Upper Circuit'] = days_90['Hit Upper Circuit'].astype(bool)
    days_90['Hit Lower Circuit'] = days_90['Hit Lower Circuit'].astype(bool)

   
    days_90.loc[days_90['high'] >= days_90['upper_circuit'], 'Hit Upper Circuit'] = True    
    days_90.loc[days_90['low'] <= days_90['lower_circuit'], 'Hit Lower Circuit'] = True

    # Count the number of hits for both upper and lower circuits
    upper_circuit_hits = days_90['Hit Upper Circuit'].sum()
    lower_circuit_hits = days_90['Hit Lower Circuit'].sum()
    freq = upper_circuit_hits + lower_circuit_hits

    # Determine if there were any hits
    if freq > 0:
        hit = True

    return hit, freq

# %%
def check_circuits_on_full_df(df, upper_circuit=20, lower_circuit=20):
    
    '''function only for simulation

    Returns two new columns:
    - circuit_hit_90d`: True/False if a circuit was hit in the last 90 days.
    - circuit_freq_90d`: The frequency of circuit hits in the last 90 days.'''
    
    circuit_hit_90d = []
    circuit_freq_90d = []

    for i in range(len(df)):
        if i < 90:
            # If we have less than 90 rows, use what we have
            sub_df = df.iloc[:i+1]
        else:
            # Otherwise, use the last 90 rows
            sub_df = df.iloc[i-89:i+1]

        hit, freq = check_circuits(sub_df, upper_circuit, lower_circuit)
        circuit_hit_90d.append(hit)
        circuit_freq_90d.append(freq)

    df['circuit_hit_90d'] = circuit_hit_90d
    df['circuit_freq_90d'] = circuit_freq_90d

    return df

# %%
def calculate_atr(df, window=14):
    atr = ta.volatility.AverageTrueRange(df['high'], df['low'], df['close'], window=window)
    # Calculate RMA manually
    rma_atr = atr.average_true_range().ewm(alpha=1/window, min_periods=window, adjust=False).mean()
    return rma_atr

# %%
def get_sma(df, window = 200):
    df.columns = [i.lower() for i in df.columns]
    #SMA calcluation
    df['sma_' + str(window)] = ta.trend.sma_indicator(df['close'], window=window)
    df['sma_' + str(window)+'_above'] = df['close'] > df['sma_' + str(window)] 
    return df

# %%
nifty500_data = pd.read_csv('F:\\Bot\\MomentumStrategy\\nifty500_data.csv')
nifty500_data.columns = [i.strip().lower() for i in nifty500_data.columns]
nifty500_data['date'] = pd.to_datetime(nifty500_data['date'], format='%d-%b-%y').dt.date
nifty500_data = get_sma(nifty500_data)


nifty50_data = pd.read_csv('F:\\Bot\\MomentumStrategy\\nifty50_data.csv')
nifty50_data.columns = [i.strip().lower() for i in nifty50_data.columns]
nifty50_data['date'] = pd.to_datetime(nifty50_data['date'], format='%d-%b-%y').dt.date
nifty50_data = get_sma(nifty50_data)


nifty500_stocks = pd.read_csv('F:\\Bot\\csv_files\\nifty500list.csv')
#filtering csv to EQ and getting only symbol column
nifty500_stocks = nifty500_stocks.loc[nifty500_stocks['Series'] == 'EQ', 'Symbol']
print(nifty500_data.shape, nifty500_stocks.shape, nifty50_data.shape)
# Out:
# (664, 9) (500,) (664, 9)

# %%
nifty500_data.tail()
# Out:
#            date      open      high       low     close  shares traded
# 659  2024-08-30  23728.55  23766.40  23673.95  23734.55   7.015025e+09  \
# 660  2024-09-02  23835.20  23835.20  23693.65  23760.70   2.522874e+09
# 661  2024-09-03  23817.00  23817.55  23771.20  23788.45   1.814622e+09
# 662  2024-09-04  23611.80  23761.40  23605.35  23748.90   2.062020e+09
# 663  2024-09-05  23821.00  23836.35  23749.05  23762.80            NaN
#
#      turnover (₹ cr)      sma_200  sma_200_above
# 659        201988.80  20717.12950           True
# 660         90696.23  20749.65000           True
# 661         88512.76  20781.78675           True
# 662         91617.99  20813.93825           True
# 663              NaN  20845.21200           True

# %%
def get_positional_data(nifty500_stocks, 
                        specific_date = datetime.today().date() - pd.Timedelta(days = 1),  
                        num_periods = 400, path = 'F:\\Bot\\data dump\\outputs\\', 
                        account_value = 1000000,
                        risk_factor = 0.002):
    
    '''
    nifty500_stocks ->  list of stock names
    specific_date   ->  extract data till previous date
    numperiods      ->  number of datapoints (days) to be extracted from csv
    path            ->  path for csv file for stock data

    returns a filtered dataframe
    
    '''
    
    main_df = pd.DataFrame(columns=['stock_name', 'prev_close', 'slope', 'annualized_return', 'adjusted_return', 'prev_sma_100_above', 'circuit_hitted', 'circuit_freq', 'prev_atr_20'])


    for i in nifty500_stocks:
        try:
            
            data = pd.read_csv(path + i + '.csv')  # readin file
            data['Date'] = pd.to_datetime(data['Date']).dt.date  #converting to datetime columns
            
            # Filter data up to the specific date
            data = data[data['Date'] <= specific_date]
            
            # Select the last 400 data points
            data = data.iloc[-num_periods:]
            

            # If less than 400 data points, continue to next stock
            if len(data) < num_periods:
                continue

        except Exception as e:
            print(e)
            continue

        
        ''' 
        getting sma and circuit is repeated data, we already have that in csv file
        remove it later on
        
        '''
        # Getting sma
        data = get_sma(data, 100)

        # Circuit hit
        
        circuit = circuit_limit.loc[circuit_limit['stock_name'] == i, 'price_band'].values[0]
        #print(i, circuit)
        if not circuit:
            hit, freq = check_circuits(data, 
                                    upper_circuit = circuit, 
                                    lower_circuit = circuit)
        else:
            hit, freq = check_circuits(data)
        
        # Getting atr
        data['atr_20'] = calculate_atr(data, 20)
        
        
        
        # Getting slope, annualized return, adjusted_return
        l = calculate_adjusted_return(data, i)
        new_row = {
            'stock_name': l[0],
            'prev_close': data['close'].iloc[-1],
            'slope': l[1],
            'annualized_return': l[2],
            'adjusted_return': l[3],
            'prev_sma_100_above': data['sma_100_above'].iloc[-1],
            'circuit_hitted': hit,
            'circuit_freq': freq,
            'prev_atr_20': data['atr_20'].iloc[-1]
        }
        
        # Adding to dataframe
        main_df.loc[len(main_df.index)] = new_row
    

    filtered_df = main_df.sort_values(by='adjusted_return', ascending=False)
    
    account_value = 1000000
    risk_factor = 0.002

    #filtering
    filtered_df['no_of_shares'] = [account_value * risk_factor]/filtered_df['prev_atr_20']
    filtered_df['no_of_shares'] = filtered_df['no_of_shares'].astype(int)
    
    

    #checking till our cumulative cash reached close to account value
    filtered_df['invested_amount'] = filtered_df['no_of_shares'] * filtered_df['prev_close']
    filtered_df['cumulative_invested_amount'] = filtered_df['invested_amount'].cumsum()

    
    return filtered_df

# %%
def get_and_save_positional_data(nifty500_stocks, specific_date):
    # Define the filename based on the specific date
    filename = f"positions_{specific_date}.csv"
    filepath = os.path.join("F:\Bot\MomentumStrategy\positionalData", filename)

    # Check if the file already exists
    if os.path.exists(filepath):
        print(f"File {filename} already exists. Loading existing data.")
        position_data = pd.read_csv(filepath)
    else:
        # Generate the positional data
        position_data = get_positional_data(nifty500_stocks, specific_date)
        
        # Save to CSV
        position_data.to_csv(filepath, index=False)
        print(f"Positional data saved to {filename}.")

    return position_data

# %%
def preprocess(df, stock_name):
    #getting circuits
    circuit = circuit_limit.loc[circuit_limit['stock_name'] == stock_name, 'price_band'].values[0]
    if not circuit:
            df = check_circuits_on_full_df(df, 
                                    upper_circuit = circuit, 
                                    lower_circuit = circuit)
    else:
        df = check_circuits_on_full_df(df)

    #getting sma

    df = get_sma(df, 100)
    return df

# %%
data_dict = {}

# %%
initial_cash = 1000000  # Example starting cash
risk_factor = 0.002
cash_in_hand = initial_cash
portfolio = {}

# %%
def simulate(start_date, end_date, nifty500_data):
    
    global cash_in_hand, portfolio
    
    equity = []
    dates = []

    
    current_date = start_date

    last_rebalance_date = current_date
    last_buying_date = current_date - pd.Timedelta(days = 8)

    while current_date <= end_date:
        current_nifty_500_datapoint = nifty500_data.loc[nifty500_data['date'] == current_date]
        
        if  current_nifty_500_datapoint.empty:  # 5 is Saturday, 6 is Sunday #if it was market holiday
            print(current_date, 'market holiday! or sat sun')
            current_date += pd.Timedelta(days=1)
            continue

        print(current_date)
        
        # Daily exit condition check
        stock_to_exit = []
        for stock in portfolio:
            try:
                # Load the latest data for the stock
                stock_df = data_dict[stock]
                sma_100 = stock_df.loc[stock_df['Date'] < current_date, 'sma_100_above'].values[-1]
                circuit_check = stock_df.loc[stock_df['Date'] < current_date, 'circuit_hit_90d'].values[-1]
                
                # Exit conditions
                if not sma_100:
                    print(stock, 'below SMA')
                    stock_to_exit.append(stock)
                
                elif circuit_check:
                    print(stock, 'circuit hit')
                    stock_to_exit.append(stock)
                    
            except Exception as e:
                print(f"Error checking exit conditions for {stock}: {e}")
                stock_to_exit.append(stock)
            
        # Exiting stocks and adding to cash in hand
        for stock in stock_to_exit:

            # Sell on the opening of the next day
            sell_price = data_dict[stock].loc[data_dict[stock]['Date'] == current_date, 'open'].values[0]
            exit_amount = sell_price * portfolio[stock]['shares']
            cash_in_hand += exit_amount
            print(f'Sold {stock} at {sell_price} on {current_date }, realized gain: {exit_amount - portfolio[stock]["invested_amount"]}')
            del portfolio[stock]

        
        # Monthly rebalancing check
        if (current_date - last_rebalance_date).days >= 30:
            print('Rebalancing on ', current_date)
            # Get positional data for the current month
            positional_data = get_and_save_positional_data(nifty500_stocks, current_date)
            last_rebalance_date = current_date
            # Rebalance: Remove shares
            positional_data['rank'] = positional_data['stock_name'].rank(method='first')
            for stock in list(portfolio.keys()):
                stock_rank = positional_data.loc[positional_data['stock_name'] == stock, 'rank'].values[0]
                if stock_rank > 75:
                    
                    sell_price = data_dict[stock].loc[data_dict[stock]['Date'] >= current_date, 'open'].values[0]
                    
                    exit_amount = sell_price * portfolio[stock]['shares']
                    cash_in_hand += exit_amount
                    print(f'Sold {stock} at {sell_price} on {current_date + pd.Timedelta(days=1)} due to rank {stock_rank}, realized gain: {exit_amount - portfolio[stock]["invested_amount"]}')
                    del portfolio[stock]

            # Rebalance: Adjust shares (both adding and reducing)
            for i, row in positional_data.iterrows():
                if row['stock_name'] in portfolio:
                    current_shares = portfolio[row['stock_name']]['shares']
                    new_shares = row['no_of_shares']

                    # Reducing shares
                    if abs(new_shares - current_shares) / current_shares > 0.05 and current_shares > new_shares:
                        shares_to_sell = current_shares - new_shares
                        sell_price = data_dict[row['stock_name']].loc[data_dict[row['stock_name']]['Date'] >= current_date, 'open'].values[0]
                        sell_amount = shares_to_sell * sell_price

                        portfolio[row['stock_name']]['shares'] = new_shares
                        portfolio[row['stock_name']]['invested_amount'] -= sell_amount
                        cash_in_hand += sell_amount
                        print(f'Reduced {row["stock_name"]} to {new_shares} shares on {current_date}')

                    # Adding shares
                    elif new_shares > current_shares and abs(new_shares - current_shares) / current_shares > 0.05:
                        shares_to_buy = new_shares - current_shares

                        buy_price = data_dict[row['stock_name']].loc[data_dict[row['stock_name']]['Date'] >= current_date, 'open'].values[0]
                        
                        buy_amount = shares_to_buy * buy_price

                        if cash_in_hand >= buy_amount:
                            portfolio[row['stock_name']]['shares'] += shares_to_buy
                            portfolio[row['stock_name']]['invested_amount'] += buy_amount
                            cash_in_hand -= buy_amount
                            print(f'Increased {row["stock_name"]} to {portfolio[row["stock_name"]]["shares"]} shares on {current_date}')

            # Update last rebalancing date
            last_rebalance_date = current_date
        
        # Weekly buying condition check
        if (current_date - last_buying_date).days > 7:
            
            
            positional_data = get_and_save_positional_data(nifty500_stocks, current_date)
            last_buying_date = current_date

            # Buying new stocks
            for i, row in positional_data.iterrows():
                if row['stock_name'] not in portfolio:
                    if (
                        row['prev_sma_100_above'] 
                        and not row['circuit_hitted'] 
                        and row['no_of_shares'] != 0
                        and cash_in_hand > row['invested_amount'] 
                        and nifty500_data.loc[nifty500_data['Date'].dt.date <= current_date, 'sma_200_above'].values[-1]
                    ):
                        stock_df = data_dict.get(row['stock_name'], pd.read_csv("F:\\Bot\\data dump\\outputs\\" + row['stock_name'] + '.csv'))
                        stock_df['Date'] = pd.to_datetime(stock_df['Date']).dt.date
                        data_dict[row['stock_name']] = stock_df

                        current_opening_price = stock_df.loc[stock_df['Date'] >= current_date, 'open'].values[0]
                        portfolio[row['stock_name']] = {
                            'entry_date': current_date,
                            'shares': row['no_of_shares'],
                            'invested_amount': row['no_of_shares'] * current_opening_price
                        }
                        cash_in_hand -= portfolio[row['stock_name']]['invested_amount']
                        print(f'Bought {row["stock_name"]} on {current_date} at {current_opening_price} no of share : {row["no_of_shares"]}')


        # Calculating equity
        equity_value = sum(
            portfolio[stock]['shares'] * data_dict[stock].loc[data_dict[stock]['Date'] >= current_date, 'close'].values[0]
            for stock in portfolio
        ) + cash_in_hand
        equity.append(equity_value)
        dates.append(current_date)

        current_date += pd.Timedelta(days=1)

    return equity, dates

# %%
start_date = datetime(2023, 1, 2).date()
end_date = datetime(2024, 8, 30).date()

equity, dates = simulate(start_date, end_date, nifty500_data)
# Out:
# 2023-01-02
# Buying on  2023-01-02
# File positions_2023-01-02.csv already exists. Loading existing data.
# Bought RVNL on 2023-01-02 at 68.25 no of share : 605
# Bought MAZDOCK on 2023-01-02 at 798.0 no of share : 49
# Bought UNIONBANK on 2023-01-02 at 80.9 no of share : 553
# Bought BANKINDIA on 2023-01-02 at 88.95 no of share : 516
# Bought J&KBANK on 2023-01-02 at 56.9 no of share : 747
# Bought GODFRYPHLP on 2023-01-02 at 1986.0 no of share : 26
# Bought MAHABANK on 2023-01-02 at 30.85 no of share : 1317
# Bought JSL on 2023-01-02 at 241.0 no of share : 249
# Bought IOB on 2023-01-02 at 32.4 no of share : 1306
# Bought CENTRALBK on 2023-01-02 at 32.4 no of share : 1195
# Bought INDIANB on 2023-01-02 at 287.0 no of share : 187
# Bought JKLAKSHMI on 2023-01-02 at 822.55 no of share : 67
# Bought PNB on 2023-01-02 at 56.8 no of share : 984
# Bought COCHINSHIP on 2023-01-02 at 265.48 no of share : 141
# Bought IRFC on 2023-01-02 at 32.7 no of share : 1535
# Sold BEML at 1994.95 on 2023-10-27, realized gain: -8141.0999999999985
# 2023-10-27
# 2023-10-28
# 2023-10-28
# 2023-10-29
# 2023-10-29
# 2023-10-30
# Buying on  2023-10-30
# File positions_2023-10-30.csv already exists. Loading existing data.
# Bought UCOBANK on 2023-10-30 at 38.35 no of share : 1076
# 2023-10-31
# 2023-11-01
# 2023-11-02
# 2023-11-03
# 2023-11-04
# 2023-11-04
# 2023-11-05
# 2023-11-05
# 2023-11-06
# Buying on  2023-11-06
# File positions_2023-11-06.csv already exists. Loading existing data.
# 2023-11-07
# 2023-11-08
# 2023-11-09
# 2023-11-10
# 2023-11-11
# 2023-11-11
# 2023-11-12
# 2023-11-12
# 2023-11-13
# Rebalancing on  2023-11-13
# File positions_2023-11-13.csv already exists. Loading existing data.
# Sold JWL at 321.8 on 2023-11-14 due to rank 249.0, realized gain: 2443.75
# Sold BSE at 2134.8 on 2023-11-14 due to rank 79.0, realized gain: 30061.20000000001
# Sold HBLPOWER at 320.6 on 2023-11-14 due to rank 185.0, realized gain: 6320.600000000006
# Sold KALYANKJIL at 338.05 on 2023-11-14 due to rank 252.0, realized gain: 16079.199999999997
# Sold HSCL at 249.2 on 2023-11-14 due to rank 200.0, realized gain: 1737.5999999999913
# Sold SUZLON at 38.6 on 2023-11-14 due to rank 409.0, realized gain: 20144.799999999996
# Sold TITAGARH at 795.0 on 2023-11-14 due to rank 428.0, realized gain: 1962.7999999999956
# Sold RECLTD at 328.3 on 2023-11-14 due to rank 366.0, realized gain: 10591.5
# Sold J&KBANK at 108.6 on 2023-11-14 due to rank 233.0, realized gain: -1386.2000000000044
# Sold RAILTEL at 254.25 on 2023-11-14 due to rank 358.0, realized gain: 7978.5
# Sold GLAND at 1644.0 on 2023-11-14 due to rank 160.0, realized gain: -198.0
# Sold IRCON at 153.0 on 2023-11-14 due to rank 227.0, realized gain: 4755.800000000003
# Sold RKFORGE at 707.0 on 2023-11-14 due to rank 372.0, realized gain: 6106.0
# Sold SAMMAANCAP at 171.3 on 2023-11-14 due to rank 378.0, realized gain: -199.75
# Sold MAPMYINDIA at 2109.65 on 2023-11-14 due to rank 285.0, realized gain: -3241.899999999994
# Sold CENTRALBK at 44.2 on 2023-11-14 due to rank 90.0, realized gain: -3942.899999999994
# Sold MAHABANK at 43.2 on 2023-11-14 due to rank 280.0, realized gain: -4962.199999999997
# Sold JSWENERGY at 389.15 on 2023-11-14 due to rank 243.0, realized gain: -2647.9500000000044
# Sold JSL at 487.9 on 2023-11-14 due to rank 242.0, realized gain: 3498.2999999999956
# Sold BSOFT at 592.0 on 2023-11-14 due to rank 80.0, realized gain: 12920.0
# Sold MAZDOCK at 1999.0 on 2023-11-14 due to rank 290.0, realized gain: -3347.4000000000015
# Sold IDEA at 14.0 on 2023-11-14 due to rank 206.0, realized gain: 6933.0999999999985
# Sold UCOBANK at 37.45 on 2023-11-14 due to rank 440.0, realized gain: -968.3999999999942
# Reduced ANANDRATHI to 29 shares on 2023-11-13
# Reduced ADANIPOWER to 130 shares on 2023-11-13
# Bought SWSOLAR on 2024-07-22 at 630.2 no of share : 59
# 2024-07-23
# 2024-07-24
# 2024-07-25
# 2024-07-26
# 2024-07-27
# 2024-07-27
# 2024-07-28
# 2024-07-28
# 2024-07-29
# Buying on  2024-07-29
# File positions_2024-07-29.csv already exists. Loading existing data.
# 2024-07-30
# 2024-07-31
# 2024-08-01
# 2024-08-02
# ABCAPITAL below SMA
# Sold ABCAPITAL at 204.0 on 2024-08-03, realized gain: -7459.980000000003
# 2024-08-03
# 2024-08-03
# 2024-08-04
# 2024-08-04
# 2024-08-05
# SUPREMEIND below SMA
# BRIGADE below SMA
# FINPIPE below SMA
# THERMAX below SMA
# SWSOLAR below SMA
# Sold SUPREMEIND at 5001.1 on 2024-08-06, realized gain: -6982.799999999996
# Sold BRIGADE at 1205.35 on 2024-08-06, realized gain: -3636.800000000003
# Sold FINPIPE at 290.1 on 2024-08-06, realized gain: -3948.5499999999956
# Sold THERMAX at 4575.25 on 2024-08-06, realized gain: -5416.0
# Sold SWSOLAR at 644.0 on 2024-08-06, realized gain: 814.1999999999971
# Buying on  2024-08-05
# File positions_2024-08-05.csv already exists. Loading existing data.
# Bought SUZLON on 2024-08-05 at 69.9 no of share : 969
# Bought DEEPAKFERT on 2024-08-05 at 931.0 no of share : 59
# Bought GLENMARK on 2024-08-05 at 1415.0 no of share : 53
# Bought SUNTECK on 2024-08-05 at 565.3 no of share : 84
# 2024-08-06
# SCHAEFFLER below SMA
# SKFINDIA below SMA
# Sold SCHAEFFLER at 3940.0 on 2024-08-07, realized gain: -55.0
# Sold SKFINDIA at 5448.85 on 2024-08-07, realized gain: -3968.399999999994
# 2024-08-07
# 2024-08-08
# 2024-08-09
# CARBORUNIV below SMA
# Sold CARBORUNIV at 1510.2 on 2024-08-10, realized gain: -5967.0
# 2024-08-10
# 2024-08-10
# 2024-08-11
# 2024-08-11
# 2024-08-12
# Buying on  2024-08-12
# File positions_2024-08-12.csv already exists. Loading existing data.
# Bought INDIACEM on 2024-08-12 at 366.0 no of share : 160
# Bought SUVENPHAR on 2024-08-12 at 940.0 no of share : 58
# 2024-08-13
# BALKRISIND below SMA
# Sold BALKRISIND at 2799.05 on 2024-08-14, realized gain: -7565.8499999999985
# 2024-08-14
# TIMKEN below SMA
# ESCORTS below SMA
# Sold TIMKEN at 3702.0 on 2024-08-15, realized gain: -3773.0
# Sold ESCORTS at 3674.95 on 2024-08-15, realized gain: -4080.850000000006
# 2024-08-15
# 2024-08-16
# 2024-08-17
# 2024-08-17
# 2024-08-18
# 2024-08-18
# 2024-08-19
# Rebalancing on  2024-08-19
# File positions_2024-08-19.csv already exists. Loading existing data.
# Sold COCHINSHIP at 2206.0 on 2024-08-20 due to rank 110.0, realized gain: -10812.0
# Sold POWERINDIA at 12099.0 on 2024-08-20 due to rank 360.0, realized gain: -456.0
# Sold FINCABLES at 1456.0 on 2024-08-20 due to rank 154.0, realized gain: -4249.5999999999985
# Sold EXIDEIND at 498.05 on 2024-08-20 due to rank 150.0, realized gain: -6514.749999999993
# Sold EMAMILTD at 825.85 on 2024-08-20 due to rank 143.0, realized gain: 3668.4000000000087
# Sold DIXON at 12550.0 on 2024-08-20 due to rank 132.0, realized gain: 300.0
# Sold UNOMINDA at 1165.0 on 2024-08-20 due to rank 458.0, realized gain: 6401.4000000000015
# Sold MOTHERSON at 187.0 on 2024-08-20 due to rank 310.0, realized gain: -3619.2100000000064
# Sold CROMPTON at 446.0 on 2024-08-20 due to rank 118.0, realized gain: 2058.199999999997
# Sold M&M at 2859.9 on 2024-08-20 due to rank 287.0, realized gain: 3563.3000000000175
# Sold GPIL at 995.7 on 2024-08-20 due to rank 178.0, realized gain: -6830.399999999994
# Sold HONAUT at 51990.0 on 2024-08-20 due to rank 205.0, realized gain: -4550.0
# Sold WHIRLPOOL at 2103.15 on 2024-08-20 due to rank 474.0, realized gain: 3745.600000000006
# Sold SAREGAMA at 517.0 on 2024-08-20 due to rank 393.0, realized gain: -1612.0
# Sold COROMANDEL at 1773.95 on 2024-08-20 due to rank 114.0, realized gain: 8076.950000000012
# Sold JKPAPER at 484.0 on 2024-08-20 due to rank 246.0, realized gain: -8262.0
# Sold GRINDWELL at 2455.0 on 2024-08-20 due to rank 183.0, realized gain: -4901.4000000000015
# Sold CUMMINSIND at 3781.0 on 2024-08-20 due to rank 121.0, realized gain: -2835.0
# Sold POLYCAB at 6700.0 on 2024-08-20 due to rank 356.0, realized gain: 1090.0
# Sold TRENT at 6575.0 on 2024-08-20 due to rank 445.0, realized gain: 11505.0
# Sold SUMICHEM at 539.0 on 2024-08-20 due to rank 413.0, realized gain: 3680.0
# Sold NBCC at 183.64 on 2024-08-20 due to rank 323.0, realized gain: -1769.8800000000047
# Sold KNRCON at 343.0 on 2024-08-20 due to rank 266.0, realized gain: 607.2000000000044
# Sold SUZLON at 80.64 on 2024-08-20 due to rank 421.0, realized gain: 10407.059999999998
# Sold DEEPAKFERT at 953.0 on 2024-08-20 due to rank 127.0, realized gain: 1298.0
# Sold GLENMARK at 1582.1 on 2024-08-20 due to rank 168.0, realized gain: 8856.299999999988
# Sold SUNTECK at 596.9 on 2024-08-20 due to rank 417.0, realized gain: 2654.4000000000015
# Sold INDIACEM at 365.95 on 2024-08-20 due to rank 219.0, realized gain: -8.0
# Sold SUVENPHAR at 1002.3 on 2024-08-20 due to rank 420.0, realized gain: 3613.399999999994
# Reduced BIKAJI to 76 shares on 2024-08-19
# Reduced BLUEDART to 7 shares on 2024-08-19
# Reduced BHARATFORG to 36 shares on 2024-08-19
# Reduced APARINDS to 5 shares on 2024-08-19
# Buying on  2024-08-19
# File positions_2024-08-19.csv already exists. Loading existing data.
# Bought COCHINSHIP on 2024-08-19 at 2206.0 no of share : 15
# Bought EMAMILTD on 2024-08-19 at 825.85 no of share : 63
# Bought SUZLON on 2024-08-19 at 80.64 no of share : 831
# Bought DEEPAKFERT on 2024-08-19 at 953.0 no of share : 52
# Bought INDIACEM on 2024-08-19 at 365.95 no of share : 163
# Bought MOTHERSON on 2024-08-19 at 187.0 no of share : 310
# Bought DIXON on 2024-08-19 at 12550.0 no of share : 5
# Bought SUVENPHAR on 2024-08-19 at 1002.3 no of share : 55
# Bought COROMANDEL on 2024-08-19 at 1773.95 no of share : 41
# Bought WHIRLPOOL on 2024-08-19 at 2103.15 no of share : 29
# Bought GRANULES on 2024-08-19 at 660.0 no of share : 118
# Bought OIL on 2024-08-19 at 690.0 no of share : 73
# Bought FINCABLES on 2024-08-19 at 1456.0 no of share : 31
# Bought UNOMINDA on 2024-08-19 at 1165.0 no of share : 44
# Bought GLENMARK on 2024-08-19 at 1582.1 no of share : 51
# Bought CHOLAHLDNG on 2024-08-19 at 1615.0 no of share : 35
# Bought VGUARD on 2024-08-19 at 524.15 no of share : 118
# Bought JKPAPER on 2024-08-19 at 484.0 no of share : 83
# Bought OFSS on 2024-08-19 at 10969.3 no of share : 5
# Bought AFFLE on 2024-08-19 at 1580.0 no of share : 37
# Bought NATCOPHARM on 2024-08-19 at 1466.05 no of share : 44
# Bought KNRCON on 2024-08-19 at 343.0 no of share : 117
# Bought TRENT on 2024-08-19 at 6575.0 no of share : 11
# Bought CROMPTON on 2024-08-19 at 446.0 no of share : 145
# Bought GLAXO on 2024-08-19 at 2969.95 no of share : 20
# Bought LALPATHLAB on 2024-08-19 at 3310.0 no of share : 24
# Bought PRAJIND on 2024-08-19 at 714.7 no of share : 72
# Bought JUBLFOOD on 2024-08-19 at 645.0 no of share : 114
# Bought SUNTV on 2024-08-19 at 823.7 no of share : 80
# Bought NBCC on 2024-08-19 at 183.64 no of share : 214
# Bought SUNTECK on 2024-08-19 at 596.9 no of share : 83
# Bought GESHIP on 2024-08-19 at 1392.45 no of share : 32
# Bought CERA on 2024-08-19 at 10148.75 no of share : 6
# Bought POWERINDIA on 2024-08-19 at 12099.0 no of share : 3
# 2024-08-20
# 2024-08-21
# 2024-08-22
# 2024-08-23
# 2024-08-24
# 2024-08-24
# 2024-08-25
# 2024-08-25
# 2024-08-26
# Buying on  2024-08-26
# File positions_2024-08-26.csv already exists. Loading existing data.
# 2024-08-27
# 2024-08-28
# 2024-08-29
# BDL below SMA
# Sold BDL at 1300.0 on 2024-08-30, realized gain: 28342.71
# 2024-08-30
# COCHINSHIP below SMA
# Sold COCHINSHIP at 1881.0 on 2024-08-31, realized gain: -4875.0

# %%
plt.figure(figsize=(20, 6))
plt.plot(dates,equity, linestyle='-', color='b')
plt.xlabel('Date')
plt.ylabel('Equity Value')
plt.title('Equity Value Over Time')
plt.grid(True)
plt.show()

# %%
total_return = (equity[-1] - equity[0]) / equity[0] * 100
print('total_return : ', total_return)
# Out:
# total_return :  148.3186821407149

# %%
equity_series = pd.Series(equity)

running_max = equity_series.cummax()

drawdown = (equity_series - running_max) / running_max

max_drawdown = drawdown.min()

print(f"\nMaximum drawdown: {max_drawdown * 100:.2f}%")
plt.figure(figsize=(20, 6))
plt.plot(dates, drawdown, linestyle='-', color='r')
plt.xlabel('Date')
plt.ylabel('Drawdown %')
plt.title('Drawdown Over Time')
plt.grid(True)
plt.show()
# Out:
# Maximum drawdown: -13.85%
