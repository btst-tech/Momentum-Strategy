# %%
import pandas as pd
from datetime import datetime
import yfinance as yf
from scipy.stats import linregress
import numpy as np
import ta
import os
import matplotlib.pyplot as plt

# %%
#get circuit limit data for stocks 
circuit_limit = pd.read_csv("F:\\Bot\\MomentumStrategy\\nifty500_price_bands.csv")
circuit_limit['stock_name'] = circuit_limit['stock_name'].str.strip()
print(circuit_limit.columns)
# Out:
# Index(['stock_name', 'price_band'], dtype='object')

# %%
def exponential_regression(x, y):
    #log of closing price
    log_y = np.log(y)

    #get slope, and r_value
    slope, intercept, r_value, _, _ = linregress(x, log_y)

    '''
    r**2 -> coefficient of determinent
    ranges from 0 - 1
    ''' 
    return slope, intercept, r_value**2

# %%
def annualize_return(daily_slope):
    return ((np.exp(daily_slope) ** 250) - 1) * 100

# %%
def calculate_adjusted_return(df, ticker):
    '''
    returns -> list [ticker, slope, annualized_return, adjusted return]
    '''

    #getting last 90 days data
    x = np.arange(90)                   #list from 0-89
    y = df['close'].iloc[-90:].values   #last 90 closing prices


    slope, intercept, r2 = exponential_regression(x, y)
    annualized_return = annualize_return(slope)
    
    adjusted_return = annualized_return * r2
    

    return [ticker, slope, annualized_return, adjusted_return]

# %%
def check_circuits(df, upper_circuit=20, lower_circuit=20):
    '''
    hit -> if circuit was hit in the last 90 days
    freq -> frequency of circuit hits 
    '''

    hit = False
    freq = 0
    upper_circuit = int(upper_circuit) - 0.01
    lower_circuit = int(lower_circuit) - 0.01

    # Filtering the last 90 days data
    days_90 = df.iloc[-90:, :].copy()

    # Calculate the upper and lower circuit levels
    days_90.loc[:, 'upper_circuit'] = days_90['close'].shift(1) * (1 + upper_circuit / 100)
    days_90.loc[:, 'lower_circuit'] = days_90['close'].shift(1) * (1 - lower_circuit / 100)

    # Initialize the circuit columns 
    days_90['Hit Upper Circuit'] = False
    days_90['Hit Lower Circuit'] = False

    # Explicitly cast columns to bool dtype
    days_90['Hit Upper Circuit'] = days_90['Hit Upper Circuit'].astype(bool)
    days_90['Hit Lower Circuit'] = days_90['Hit Lower Circuit'].astype(bool)

   
    days_90.loc[days_90['high'] >= days_90['upper_circuit'], 'Hit Upper Circuit'] = True    
    days_90.loc[days_90['low'] <= days_90['lower_circuit'], 'Hit Lower Circuit'] = True

    # Count the number of hits for both upper and lower circuits
    upper_circuit_hits = days_90['Hit Upper Circuit'].sum()
    lower_circuit_hits = days_90['Hit Lower Circuit'].sum()
    freq = upper_circuit_hits + lower_circuit_hits

    # Determine if there were any hits
    if freq > 0:
        hit = True

    return hit, freq

# %%
def check_circuits_on_full_df(df, upper_circuit=20, lower_circuit=20):
    
    '''function only for simulation

    Returns two new columns:
    - circuit_hit_90d`: True/False if a circuit was hit in the last 90 days.
    - circuit_freq_90d`: The frequency of circuit hits in the last 90 days.'''
    
    circuit_hit_90d = []
    circuit_freq_90d = []

    for i in range(len(df)):
        if i < 90:
            # If we have less than 90 rows, use what we have
            sub_df = df.iloc[:i+1]
        else:
            # Otherwise, use the last 90 rows
            sub_df = df.iloc[i-89:i+1]

        hit, freq = check_circuits(sub_df, upper_circuit, lower_circuit)
        circuit_hit_90d.append(hit)
        circuit_freq_90d.append(freq)

    df['circuit_hit_90d'] = circuit_hit_90d
    df['circuit_freq_90d'] = circuit_freq_90d

    return df

# %%
def calculate_atr(df, window=14):
    atr = ta.volatility.AverageTrueRange(df['high'], df['low'], df['close'], window=window)
    # Calculate RMA manually
    rma_atr = atr.average_true_range().ewm(alpha=1/window, min_periods=window, adjust=False).mean()
    return rma_atr

# %%
def get_sma(df, window = 200):
    df.columns = [i.lower() for i in df.columns]
    #SMA calcluation
    df['sma_' + str(window)] = ta.trend.sma_indicator(df['close'], window=window)
    df['sma_' + str(window)+'_above'] = df['close'] > df['sma_' + str(window)] 
    return df

# %%
ticker = "^CRSLDX"

# Fetch the historical data
nifty500_data = yf.download(ticker, start="2022-01-01", end="2024-08-31")
print(nifty500_data.shape)
nifty500_data = get_sma(nifty500_data)
nifty500_stocks = pd.read_csv('F:\\Bot\\csv_files\\nifty500list.csv')
#filtering csv to EQ and getting only symbol column
nifty500_stocks = nifty500_stocks.loc[nifty500_stocks['Series'] == 'EQ', 'Symbol']
nifty500_data.to_csv('nifty500.csv')

nifty500_data = pd.read_csv('nifty500.csv')
nifty500_stocks= pd.read_csv('F:\\Bot\\csv_files\\nifty500list.csv')
nifty500_stocks = nifty500_stocks.loc[nifty500_stocks['Series'] == 'EQ', 'Symbol']
# Out:
# [*********************100%***********************]  1 of 1 completed
# (653, 6)

# %%
nifty500_data.tail()
# Out:
#            Date          open          high           low         close
# 648  2024-08-26  23514.300781  23579.750000  23466.750000  23561.750000  \
# 649  2024-08-27  23592.000000  23633.199219  23555.550781  23604.849609
# 650  2024-08-28  23646.800781  23679.349609  23547.250000  23615.949219
# 651  2024-08-29  23618.250000  23664.349609  23494.449219  23631.400391
# 652  2024-08-30  23728.550781  23766.400391  23673.949219  23734.550781
#
#         adj close    volume       sma_200  sma_200_above
# 648  23561.750000  19994300  20502.214531           True
# 649  23604.849609  22130300  20536.411533           True
# 650  23615.949219  24488600  20570.360781           True
# 651  23631.400391  29804300  20604.512285           True
# 652  23734.550781  70150200  20639.520293           True

# %%
def get_positional_data(nifty500_stocks, 
                        specific_date = datetime.today().date() - pd.Timedelta(days = 1),  
                        num_periods = 400, path = 'F:\\Bot\\data dump\\outputs\\', 
                        account_value = 1000000,
                        risk_factor = 0.002):
    
    '''
    nifty500_stocks ->  list of stock names
    specific_date   ->  extract data till previous date
    numperiods      ->  number of datapoints (days) to be extracted from csv
    path            ->  path for csv file for stock data

    returns a filtered dataframe
    
    '''
    
    main_df = pd.DataFrame(columns=['stock_name', 'prev_close', 'slope', 'annualized_return', 'adjusted_return', 'prev_sma_100_above', 'circuit_hitted', 'circuit_freq', 'prev_atr_20'])


    for i in nifty500_stocks:
        try:
            
            data = pd.read_csv(path + i + '.csv')  # readin file
            data['Date'] = pd.to_datetime(data['Date']).dt.date  #converting to datetime columns
            
            # Filter data up to the specific date
            data = data[data['Date'] <= specific_date]
            
            # Select the last 400 data points
            data = data.iloc[-num_periods:]
            

            # If less than 400 data points, continue to next stock
            if len(data) < num_periods:
                continue

        except Exception as e:
            print(e)
            continue

        
        ''' 
        getting sma and circuit is repeated data, we already have that in csv file
        remove it later on
        
        '''
        # Getting sma
        data = get_sma(data, 100)

        # Circuit hit
        
        circuit = circuit_limit.loc[circuit_limit['stock_name'] == i, 'price_band'].values[0]
        #print(i, circuit)
        if not circuit:
            hit, freq = check_circuits(data, 
                                    upper_circuit = circuit, 
                                    lower_circuit = circuit)
        else:
            hit, freq = check_circuits(data)
        
        # Getting atr
        data['atr_20'] = calculate_atr(data, 20)
        
        
        
        # Getting slope, annualized return, adjusted_return
        l = calculate_adjusted_return(data, i)
        new_row = {
            'stock_name': l[0],
            'prev_close': data['close'].iloc[-1],
            'slope': l[1],
            'annualized_return': l[2],
            'adjusted_return': l[3],
            'prev_sma_100_above': data['sma_100_above'].iloc[-1],
            'circuit_hitted': hit,
            'circuit_freq': freq,
            'prev_atr_20': data['atr_20'].iloc[-1]
        }
        
        # Adding to dataframe
        main_df.loc[len(main_df.index)] = new_row
    

    filtered_df = main_df.sort_values(by='adjusted_return', ascending=False)
    
    account_value = 1000000
    risk_factor = 0.002

    #filtering
    filtered_df['no_of_shares'] = [account_value * risk_factor]/filtered_df['prev_atr_20']
    filtered_df['no_of_shares'] = filtered_df['no_of_shares'].astype(int)
    
    

    #checking till our cumulative cash reached close to account value
    filtered_df['invested_amount'] = filtered_df['no_of_shares'] * filtered_df['prev_close']
    filtered_df['cumulative_invested_amount'] = filtered_df['invested_amount'].cumsum()

    
    return filtered_df

# %%
def get_and_save_positional_data(nifty500_stocks, specific_date):
    # Define the filename based on the specific date
    filename = f"positions_{specific_date}.csv"
    filepath = os.path.join("F:\Bot\MomentumStrategy\positionalData", filename)

    # Check if the file already exists
    if os.path.exists(filepath):
        print(f"File {filename} already exists. Loading existing data.")
        position_data = pd.read_csv(filepath)
    else:
        # Generate the positional data
        position_data = get_positional_data(nifty500_stocks, specific_date)
        
        # Save to CSV
        position_data.to_csv(filepath, index=False)
        print(f"Positional data saved to {filename}.")

    return position_data

# %%
def preprocess(df, stock_name):
    #getting circuits
    circuit = circuit_limit.loc[circuit_limit['stock_name'] == stock_name, 'price_band'].values[0]
    if not circuit:
            df = check_circuits_on_full_df(df, 
                                    upper_circuit = circuit, 
                                    lower_circuit = circuit)
    else:
        df = check_circuits_on_full_df(df)

    #getting sma

    df = get_sma(df, 100)
    return df

# %%
data_dict = {}

# %%
initial_cash = 1000000  # Example starting cash
risk_factor = 0.002
cash_in_hand = initial_cash
portfolio = {}

# %%
def simulate(start_date, end_date, nifty500_data):
    
    global cash_in_hand, portfolio
    
    equity = []
    dates = []

    nifty500_data['Date'] = pd.to_datetime(nifty500_data['Date'])
    current_date = start_date

    start_day_weekday = start_date.weekday()  # Store the start date's weekday
    rebalancing_week = 0  # To track biweekly rebalancing
    
    while current_date <= end_date:
        print(current_date)
        # Daily exit condition check
        stock_to_exit = []
        for stock in portfolio:
            try:
                # Load the latest data for the stock
                stock_df = data_dict[stock]
                sma_100 = stock_df.loc[stock_df['Date'] < current_date, 'sma_100_above'].values[-1]
                circuit_check = stock_df.loc[stock_df['Date'] <= current_date, 'circuit_hit_90d'].values[-1]
                
                # Exit conditions
                if not sma_100:
                    print(stock, 'below SMA')
                    stock_to_exit.append(stock)
                
                elif circuit_check:
                    print(stock, 'circuit hit')

                    stock_to_exit.append(stock)
                    
            except Exception as e:
                print(f"Error checking exit conditions for {stock}: {e}")
                stock_to_exit.append(stock)
            
        # Exiting stocks and adding to cash in hand
        for stock in stock_to_exit:
            #we will sell on opening of next day
            sell_price = data_dict[stock].loc[data_dict[stock]['Date'] > current_date, 'open'].values[0]


            exit_amount = sell_price * portfolio[stock]['shares']
            cash_in_hand += exit_amount
            print(f'Sold {stock} at {sell_price} on {current_date + pd.Timedelta(days = 1)}, realized gain: {exit_amount - portfolio[stock]["invested_amount"]}')
            del portfolio[stock]


        #buying
        if current_date.weekday() == start_day_weekday:
            positional_data = get_and_save_positional_data(nifty500_stocks, current_date)

            # Rank-based exit
            positional_data['rank'] = positional_data['stock_name'].rank(method='first')
            for stock in list(portfolio.keys()):
                stock_rank = positional_data.loc[positional_data['stock_name'] == stock, 'rank'].values[0]
                if stock_rank > 75:
                    sell_price = data_dict[stock].loc[data_dict[stock]['Date'] >= current_date, 'open'].values[0]
                    exit_amount = sell_price * portfolio[stock]['shares']
                    cash_in_hand += exit_amount
                    print(f'Sold {stock} at {sell_price} on {current_date + pd.Timedelta(days=1)} due to rank {stock_rank}, realized gain: {exit_amount - portfolio[stock]["invested_amount"]}')
                    del portfolio[stock]

            # Buying new stocks
            for i, row in positional_data.iterrows():
                if row['stock_name'] not in portfolio:
                    if (
                        row['prev_sma_100_above'] 
                        and not row['circuit_hitted'] 
                        and row['no_of_shares'] != 0
                        and cash_in_hand > row['invested_amount'] 
                        and nifty500_data.loc[nifty500_data['Date'].dt.date <= current_date, 'sma_200_above'].values[-1]
                    ):
                        stock_df = data_dict.get(row['stock_name'], pd.read_csv("F:\\Bot\\data dump\\outputs\\" + row['stock_name'] + '.csv'))
                        stock_df['Date'] = pd.to_datetime(stock_df['Date']).dt.date
                        data_dict[row['stock_name']] = stock_df

                        current_opening_price = stock_df.loc[stock_df['Date'] >= current_date, 'open'].values[0]
                        portfolio[row['stock_name']] = {
                            'entry_date': current_date,
                            'shares': row['no_of_shares'],
                            'invested_amount': row['no_of_shares'] * current_opening_price
                        }
                        cash_in_hand -= portfolio[row['stock_name']]['invested_amount']
                        print(f'Bought {row["stock_name"]} on {current_date} at {current_opening_price} no of share : {row["no_of_shares"]}')

        
        
        # Biweekly rebalancing check
        if current_date.weekday() == start_day_weekday and rebalancing_week % 2 == 0:
            for i, row in positional_data.iterrows():
                if row['stock_name'] in portfolio:
                    current_shares = portfolio[row['stock_name']]['shares']
                    new_shares = row['no_of_shares']

                    if abs(new_shares - current_shares) / current_shares > 0.05:
                        if current_shares > new_shares:  # Reducing shares
                            shares_to_sell = current_shares - new_shares
                            sell_price = data_dict[row['stock_name']].loc[data_dict[row['stock_name']]['Date'] >= current_date, 'open'].values[0]
                            sell_amount = shares_to_sell * sell_price
                            portfolio[row['stock_name']]['shares'] = new_shares
                            portfolio[row['stock_name']]['invested_amount'] -= sell_amount
                            cash_in_hand += sell_amount
                            print(f'Reduced {row["stock_name"]} to {new_shares} shares on {current_date}')

                        elif new_shares > current_shares:  # Adding shares
                            shares_to_buy = new_shares - current_shares
                            buy_price = data_dict[row['stock_name']].loc[data_dict[row['stock_name']]['Date'] >= current_date, 'open'].values[0]
                            buy_amount = shares_to_buy * buy_price

                            if cash_in_hand >= buy_amount:
                                portfolio[row['stock_name']]['shares'] += shares_to_buy
                                portfolio[row['stock_name']]['invested_amount'] += buy_amount
                                cash_in_hand -= buy_amount
                                print(f'Increased {row["stock_name"]} to {portfolio[row["stock_name"]]["shares"]} shares on {current_date}')
        
        # Calculating equity
        equity_value = sum(
            portfolio[stock]['shares'] * data_dict[stock].loc[data_dict[stock]['Date'] >= current_date, 'close'].values[0]
            for stock in portfolio
        ) + cash_in_hand
        equity.append(equity_value)
        dates.append(current_date)

        current_date += pd.Timedelta(days=1)
        rebalancing_week += 1

    return equity, dates

# %%
start_date = datetime(2023, 1, 1).date()
end_date = datetime(2024, 8, 30).date()

equity, dates = simulate(start_date, end_date, nifty500_data)
# Out:
# 2023-01-01
# File positions_2023-01-01.csv already exists. Loading existing data.
# Bought RVNL on 2023-01-01 at 68.25 no of share : 608
# Bought MAZDOCK on 2023-01-01 at 798.0 no of share : 50
# Bought UNIONBANK on 2023-01-01 at 80.9 no of share : 563
# Bought BANKINDIA on 2023-01-01 at 88.95 no of share : 524
# Bought GODFRYPHLP on 2023-01-01 at 1986.0 no of share : 27
# Bought J&KBANK on 2023-01-01 at 56.9 no of share : 759
# Bought MAHABANK on 2023-01-01 at 30.85 no of share : 1342
# Bought JSL on 2023-01-01 at 241.0 no of share : 254
# Bought CENTRALBK on 2023-01-01 at 32.4 no of share : 1217
# Bought COCHINSHIP on 2023-01-01 at 265.48 no of share : 141
# Bought IOB on 2023-01-01 at 32.4 no of share : 1342
# Bought INDIANB on 2023-01-01 at 287.0 no of share : 190
# Bought GRSE on 2023-01-01 at 487.0 no of share : 77
# Bought JKLAKSHMI on 2023-01-01 at 822.55 no of share : 67
# Bought PNB on 2023-01-01 at 56.8 no of share : 994
# Bought IRCON on 2023-01-01 at 60.0 no of share : 703
# Bought IRFC on 2023-01-01 at 32.7 no of share : 1564
# Bought RAYMOND on 2023-01-01 at 1475.0 no of share : 30
# Bought BLS on 2023-01-01 at 165.8 no of share : 261
# Bought IIFL on 2023-01-01 at 469.42 no of share : 118
# Bought BHEL on 2023-01-01 at 79.55 no of share : 704
# 2023-01-02
# 2023-01-03
# 2023-01-04
# 2023-01-05
# 2023-01-06
# 2023-01-07
# COCHINSHIP below SMA
# Sold COCHINSHIP at 252.45 on 2023-01-08, realized gain: -1837.2300000000032
# 2023-01-08
# File positions_2023-01-08.csv already exists. Loading existing data.
# Sold RVNL at 74.0 on 2023-01-09 due to rank 355.0, realized gain: 3496.0
# Sold MAZDOCK at 809.3 on 2023-01-09 due to rank 277.0, realized gain: 565.0
# Sold UNIONBANK at 81.5 on 2023-01-09 due to rank 419.0, realized gain: 337.79999999999563
# Sold GODFRYPHLP at 2012.0 on 2023-01-09 due to rank 160.0, realized gain: 702.0
# Sold J&KBANK at 55.85 on 2023-01-09 due to rank 224.0, realized gain: -796.9499999999971
# Sold MAHABANK at 31.2 on 2023-01-09 due to rank 269.0, realized gain: 469.6999999999971
# Sold JSL at 242.3 on 2023-01-09 due to rank 233.0, realized gain: 330.20000000000437
# Sold CENTRALBK at 31.9 on 2023-01-09 due to rank 87.0, realized gain: -608.5
# Sold IOB at 31.35 on 2023-01-09 due to rank 214.0, realized gain: -1409.0999999999913
# Sold INDIANB at 295.95 on 2023-01-09 due to rank 206.0, realized gain: 1700.5
# Sold GRSE at 478.45 on 2023-01-09 due to rank 170.0, realized gain: -658.3499999999985
# Sold JKLAKSHMI at 761.1 on 2023-01-09 due to rank 230.0, realized gain: -4117.149999999994
# Sold PNB at 57.0 on 2023-01-09 due to rank 323.0, realized gain: 198.8000000000029
# Sold IRCON at 59.05 on 2023-01-09 due to rank 218.0, realized gain: -667.8499999999985
# Sold IRFC at 33.05 on 2023-01-09 due to rank 220.0, realized gain: 547.3999999999942
# Sold RAYMOND at 1469.9 on 2023-01-09 due to rank 342.0, realized gain: -153.0
# Sold IIFL at 447.99 on 2023-01-09 due to rank 202.0, realized gain: -2528.7400000000052
# Bought RVNL on 2023-01-08 at 74.0 no of share : 596
# Bought UNIONBANK on 2023-01-08 at 81.5 no of share : 527
# Bought MAZDOCK on 2023-01-08 at 809.3 no of share : 49
# Bought J&KBANK on 2023-01-08 at 55.85 no of share : 713
# Bought GODFRYPHLP on 2023-01-08 at 2012.0 no of share : 25
# Bought MAHABANK on 2023-01-08 at 31.2 no of share : 1244
# Bought JSL on 2023-01-08 at 242.3 no of share : 234
# Bought IOB on 2023-01-08 at 31.35 no of share : 1208
# Bought CENTRALBK on 2023-01-08 at 31.9 no of share : 1135
# Bought IRFC on 2023-01-08 at 33.05 no of share : 1449
# Bought PNB on 2023-01-08 at 57.0 no of share : 958
# Bought INDIANB on 2023-01-08 at 295.95 no of share : 182
# Bought IRCON on 2023-01-08 at 59.05 no of share : 671
# Bought JKLAKSHMI on 2023-01-08 at 761.1 no of share : 66
# Bought RAYMOND on 2023-01-08 at 1469.9 no of share : 30
# Bought IIFL on 2023-01-08 at 447.99 no of share : 116
# Bought GRSE on 2023-01-08 at 478.45 no of share : 76
# Bought BANKBARODA on 2023-01-08 at 184.3 no of share : 371
# 2023-01-09
# 2023-01-10
# 2023-01-11
# 2023-01-12
# 2023-01-13
# 2023-01-14
# 2023-01-15
# File positions_2023-01-15.csv already exists. Loading existing data.
# Sold RVNL at 81.3 on 2023-01-16 due to rank 355.0, realized gain: 4350.799999999996
# Sold UNIONBANK at 79.1 on 2023-01-16 due to rank 419.0, realized gain: -1264.800000000003
# Sold MAZDOCK at 783.0 on 2023-01-16 due to rank 277.0, realized gain: -1288.699999999997
# Sold J&KBANK at 57.15 on 2023-01-16 due to rank 224.0, realized gain: 926.8999999999942
# Sold GODFRYPHLP at 2042.0 on 2023-01-16 due to rank 160.0, realized gain: 750.0
# Sold MAHABANK at 31.95 on 2023-01-16 due to rank 269.0, realized gain: 933.0
# Sold JSL at 238.9 on 2023-01-16 due to rank 233.0, realized gain: -795.6000000000058
# Sold IOB at 30.2 on 2023-01-16 due to rank 214.0, realized gain: -1389.2000000000044
# Sold CENTRALBK at 30.95 on 2023-01-16 due to rank 87.0, realized gain: -1078.25
# Sold IRFC at 34.0 on 2023-01-16 due to rank 220.0, realized gain: 1376.550000000003
# Sold PNB at 56.95 on 2023-01-16 due to rank 323.0, realized gain: -47.89999999999418
# Sold INDIANB at 286.0 on 2023-01-16 due to rank 206.0, realized gain: -1810.9000000000015
# Sold IRCON at 63.2 on 2023-01-16 due to rank 218.0, realized gain: 2784.6500000000087
# Sold JKLAKSHMI at 769.2 on 2023-01-16 due to rank 230.0, realized gain: 534.6000000000058
# Sold RAYMOND at 1476.0 on 2023-01-16 due to rank 342.0, realized gain: 183.0
# Sold IIFL at 464.31 on 2023-01-16 due to rank 202.0, realized gain: 1893.1199999999953
# Sold GRSE at 493.0 on 2023-01-16 due to rank 170.0, realized gain: 1105.800000000003
# Bought RVNL on 2023-01-15 at 81.3 no of share : 593
# Bought UNIONBANK on 2023-01-15 at 79.1 no of share : 517
# Bought J&KBANK on 2023-01-15 at 57.15 no of share : 692
# Bought JSL on 2023-01-15 at 238.9 no of share : 223
# Bought GODFRYPHLP on 2023-01-15 at 2042.0 no of share : 24
# Bought MAHABANK on 2023-01-15 at 31.95 no of share : 1201
# Bought MAZDOCK on 2023-01-15 at 783.0 no of share : 49
# Bought IOB on 2023-01-15 at 30.2 no of share : 1154
# Bought CENTRALBK on 2023-01-15 at 30.95 no of share : 1108
# Bought IRFC on 2023-01-15 at 34.0 no of share : 1407
# Bought PNB on 2023-01-15 at 56.95 no of share : 944
# Bought IRCON on 2023-01-15 at 63.2 no of share : 659
# Bought INDIANB on 2023-01-15 at 286.0 no of share : 180
# Bought RBLBANK on 2023-01-15 at 177.2 no of share : 331
# Bought GICRE on 2023-01-15 at 187.05 no of share : 236
# Bought RAYMOND on 2023-01-15 at 1476.0 no of share : 30
# Bought TITAGARH on 2023-01-15 at 222.5 no of share : 212
# Reduced BANKINDIA to 479 shares on 2023-01-15
# Reduced BLS to 246 shares on 2023-01-15
# 2023-01-16
# 2023-01-17
# 2023-01-18
# 2023-01-19
# 2023-01-20
# 2023-01-21
# 2023-01-22
# File positions_2023-01-22.csv already exists. Loading existing data.
# Sold RVNL at 77.55 on 2023-01-23 due to rank 355.0, realized gain: -2223.75
# Sold UNIONBANK at 82.6 on 2023-01-23 due to rank 419.0, realized gain: 1809.5
# Sold J&KBANK at 55.6 on 2023-01-23 due to rank 224.0, realized gain: -1072.5999999999913
# Sold JSL at 259.8 on 2023-01-23 due to rank 233.0, realized gain: 4660.699999999997
# Sold GODFRYPHLP at 1930.0 on 2023-01-23 due to rank 160.0, realized gain: -2688.0
# Sold MAHABANK at 31.45 on 2023-01-23 due to rank 269.0, realized gain: -600.5
# Sold MAZDOCK at 772.5 on 2023-01-23 due to rank 277.0, realized gain: -514.5
# Sold IOB at 30.9 on 2023-01-23 due to rank 214.0, realized gain: 807.8000000000029
# Sold CENTRALBK at 32.1 on 2023-01-23 due to rank 87.0, realized gain: 1274.2000000000044
# Sold IRFC at 33.4 on 2023-01-23 due to rank 220.0, realized gain: -844.2000000000044
# Sold PNB at 57.25 on 2023-01-23 due to rank 323.0, realized gain: 283.1999999999971
# Sold IRCON at 61.2 on 2023-01-23 due to rank 218.0, realized gain: -1318.0
# Sold INDIANB at 287.95 on 2023-01-23 due to rank 206.0, realized gain: 351.0
# Sold RBLBANK at 172.95 on 2023-01-23 due to rank 344.0, realized gain: -1406.75
# Sold GICRE at 174.2 on 2023-01-23 due to rank 151.0, realized gain: -3032.600000000006
# Sold RAYMOND at 1515.0 on 2023-01-23 due to rank 342.0, realized gain: 1170.0
# Sold TITAGARH at 222.35 on 2023-01-23 due to rank 404.0, realized gain: -31.80000000000291
# Bought RVNL on 2023-01-22 at 77.55 no of share : 588
# Bought J&KBANK on 2023-01-22 at 55.6 no of share : 687
# Bought UNIONBANK on 2023-01-22 at 82.6 no of share : 518
# Bought JSL on 2023-01-22 at 259.8 no of share : 218
# Bought IOB on 2023-01-22 at 30.9 no of share : 1130
# Bought MAHABANK on 2023-01-22 at 31.45 no of share : 1177
# Bought GODFRYPHLP on 2023-01-22 at 1930.0 no of share : 23
# Bought CENTRALBK on 2023-01-22 at 32.1 no of share : 1110
# Bought IRFC on 2023-01-22 at 33.4 no of share : 1404
# Bought PNB on 2023-01-22 at 57.25 no of share : 940
# Bought MAZDOCK on 2023-01-22 at 772.5 no of share : 50
# Bought IRCON on 2023-01-22 at 61.2 no of share : 660
# Bought NIACL on 2023-01-22 at 125.3 no of share : 350
# Bought GICRE on 2023-01-22 at 174.2 no of share : 226
# Bought RBLBANK on 2023-01-22 at 172.95 no of share : 328
# Bought TITAGARH on 2023-01-22 at 222.35 no of share : 211
# Bought INDIANB on 2023-01-22 at 287.95 no of share : 182
# 2023-01-23
# 2023-01-24
# 2023-01-25
# 2023-01-26
# 2023-01-27
# 2023-01-28
# BANKBARODA below SMA
# Sold BANKBARODA at 158.1 on 2023-01-29, realized gain: -9720.200000000004
# 2023-01-29
# File positions_2023-01-29.csv already exists. Loading existing data.
# Sold RVNL at 73.0 on 2023-01-30 due to rank 355.0, realized gain: -2675.4000000000015
# Sold J&KBANK at 52.45 on 2023-01-30 due to rank 224.0, realized gain: -2164.050000000003
# Sold UNIONBANK at 74.2 on 2023-01-30 due to rank 419.0, realized gain: -4351.199999999997
# Sold JSL at 254.95 on 2023-01-30 due to rank 233.0, realized gain: -1057.300000000003
# Sold IOB at 26.35 on 2023-01-30 due to rank 214.0, realized gain: -5141.5
# Sold MAHABANK at 27.8 on 2023-01-30 due to rank 269.0, realized gain: -4296.049999999999
# Sold GODFRYPHLP at 1908.0 on 2023-01-30 due to rank 160.0, realized gain: -506.0
# Sold CENTRALBK at 28.3 on 2023-01-30 due to rank 87.0, realized gain: -4218.0
# Sold IRFC at 30.05 on 2023-01-30 due to rank 220.0, realized gain: -4703.399999999994
# Sold PNB at 51.1 on 2023-01-30 due to rank 323.0, realized gain: -5781.0
# Sold MAZDOCK at 723.75 on 2023-01-30 due to rank 277.0, realized gain: -2437.5
# Sold IRCON at 56.7 on 2023-01-30 due to rank 218.0, realized gain: -2970.0
# Sold NIACL at 115.9 on 2023-01-30 due to rank 303.0, realized gain: -3290.0
# Sold GICRE at 173.25 on 2023-01-30 due to rank 151.0, realized gain: -214.6999999999971
# Sold RBLBANK at 150.65 on 2023-01-30 due to rank 344.0, realized gain: -7314.399999999994
# Sold TITAGARH at 217.9 on 2023-01-30 due to rank 404.0, realized gain: -938.9499999999971
# Sold INDIANB at 282.35 on 2023-01-30 due to rank 206.0, realized gain: -1019.1999999999971
# Bought RVNL on 2023-01-29 at 73.0 no of share : 591
# Bought JSL on 2023-01-29 at 254.95 no of share : 214
# Bought J&KBANK on 2023-01-29 at 52.45 no of share : 690
# Bought UNIONBANK on 2023-01-29 at 74.2 no of share : 524
# Bought IOB on 2023-01-29 at 26.35 no of share : 1131
# Bought MAHABANK on 2023-01-29 at 27.8 no of share : 1178
# Bought CENTRALBK on 2023-01-29 at 28.3 no of share : 1128
# Bought GODFRYPHLP on 2023-01-29 at 1908.0 no of share : 23
# Bought IRFC on 2023-01-29 at 30.05 no of share : 1416
# Bought SWANENERGY on 2023-01-29 at 328.5 no of share : 141
# Bought PNB on 2023-01-29 at 51.1 no of share : 944
# Bought GICRE on 2023-01-29 at 173.25 no of share : 223
# Bought NIACL on 2023-01-29 at 115.9 no of share : 348
# Bought TITAGARH on 2023-01-29 at 217.9 no of share : 210
# Bought GPIL on 2023-01-29 at 381.75 no of share : 129
# Bought IRCON on 2023-01-29 at 56.7 no of share : 667
# Bought RBLBANK on 2023-01-29 at 150.65 no of share : 326
# Bought PFC on 2023-01-29 at 109.16 no of share : 621
# 2023-01-30
# 2023-01-31
# 2023-02-01
# 2023-02-02
# 2023-02-03
# 2023-02-04
# 2023-02-05
# File positions_2023-02-05.csv already exists. Loading existing data.
# Sold RVNL at 72.75 on 2023-02-06 due to rank 356.0, realized gain: -147.75
# Sold JSL at 266.25 on 2023-02-06 due to rank 233.0, realized gain: 2418.2000000000044
# Sold J&KBANK at 52.75 on 2023-02-06 due to rank 224.0, realized gain: 207.0
# Sold UNIONBANK at 74.3 on 2023-02-06 due to rank 422.0, realized gain: 52.39999999999418
# Sold IOB at 26.75 on 2023-02-06 due to rank 214.0, realized gain: 452.3999999999978
# Sold MAHABANK at 28.85 on 2023-02-06 due to rank 270.0, realized gain: 1236.9000000000015
# Sold CENTRALBK at 28.0 on 2023-02-06 due to rank 87.0, realized gain: -338.40000000000146
# Sold GODFRYPHLP at 1827.0 on 2023-02-06 due to rank 160.0, realized gain: -1863.0
# Sold IRFC at 31.55 on 2023-02-06 due to rank 220.0, realized gain: 2124.0
# Sold SWANENERGY at 272.5 on 2023-02-06 due to rank 389.0, realized gain: -7896.0
# Sold PNB at 51.9 on 2023-02-06 due to rank 324.0, realized gain: 755.1999999999971
# Sold GICRE at 155.3 on 2023-02-06 due to rank 151.0, realized gain: -4002.8499999999985
# Sold NIACL at 107.95 on 2023-02-06 due to rank 304.0, realized gain: -2766.600000000006
# Sold TITAGARH at 193.3 on 2023-02-06 due to rank 407.0, realized gain: -5166.0
# Sold GPIL at 385.0 on 2023-02-06 due to rank 164.0, realized gain: 419.25
# Sold IRCON at 57.15 on 2023-02-06 due to rank 218.0, realized gain: 300.1499999999942
# Sold RBLBANK at 157.0 on 2023-02-06 due to rank 345.0, realized gain: 2070.0999999999985
# Sold PFC at 113.32 on 2023-02-06 due to rank 319.0, realized gain: 2583.3600000000006
# Bought JSL on 2023-02-05 at 266.25 no of share : 206
# Bought RVNL on 2023-02-05 at 72.75 no of share : 588
# Bought J&KBANK on 2023-02-05 at 52.75 no of share : 681
# Bought IOB on 2023-02-05 at 26.75 no of share : 1123
# Bought UNIONBANK on 2023-02-05 at 74.3 no of share : 520
# Bought MAHABANK on 2023-02-05 at 28.85 no of share : 1163
# Bought CENTRALBK on 2023-02-05 at 28.0 no of share : 1144
# Bought SWANENERGY on 2023-02-05 at 272.5 no of share : 132
# Bought GPIL on 2023-02-05 at 385.0 no of share : 128
# Bought JWL on 2023-02-05 at 100.3 no of share : 439
# Bought IRFC on 2023-02-05 at 31.55 no of share : 1405
# Bought GICRE on 2023-02-05 at 155.3 no of share : 215
# Bought GODFRYPHLP on 2023-02-05 at 1827.0 no of share : 23
# Bought JINDALSAW on 2023-02-05 at 130.45 no of share : 456
# Bought PNB on 2023-02-05 at 51.9 no of share : 911
# Bought TITAGARH on 2023-02-05 at 193.3 no of share : 205
# Bought NIACL on 2023-02-05 at 107.95 no of share : 344
# Bought PFC on 2023-02-05 at 113.32 no of share : 588
# 2023-02-06
# 2023-02-07
# SWANENERGY below SMA
# Sold SWANENERGY at 268.45 on 2023-02-08, realized gain: -534.5999999999985
# 2023-02-08
# 2023-02-09
# 2023-02-10
# 2023-02-11
# NIACL below SMA
# Sold NIACL at 103.1 on 2023-02-12, realized gain: -1668.4000000000015
# 2023-02-12
# File positions_2023-02-12.csv already exists. Loading existing data.
# Sold JSL at 257.95 on 2023-02-13 due to rank 233.0, realized gain: -1709.800000000003
# Sold RVNL at 71.0 on 2023-02-13 due to rank 356.0, realized gain: -1029.0
# Sold J&KBANK at 53.8 on 2023-02-13 due to rank 224.0, realized gain: 715.0499999999956
# Sold IOB at 27.4 on 2023-02-13 due to rank 214.0, realized gain: 729.9499999999971
# Sold UNIONBANK at 73.9 on 2023-02-13 due to rank 422.0, realized gain: -208.0
# Sold MAHABANK at 28.2 on 2023-02-13 due to rank 270.0, realized gain: -755.9500000000044
# Sold CENTRALBK at 27.95 on 2023-02-13 due to rank 87.0, realized gain: -57.20000000000073
# Sold GPIL at 367.0 on 2023-02-13 due to rank 164.0, realized gain: -2304.0
# Sold JWL at 101.95 on 2023-02-13 due to rank 240.0, realized gain: 724.3500000000058
# Sold IRFC at 30.2 on 2023-02-13 due to rank 220.0, realized gain: -1896.75
# Sold GICRE at 159.0 on 2023-02-13 due to rank 151.0, realized gain: 795.5
# Sold GODFRYPHLP at 1771.0 on 2023-02-13 due to rank 160.0, realized gain: -1288.0
# Sold JINDALSAW at 142.45 on 2023-02-13 due to rank 227.0, realized gain: 5472.0
# Sold PNB at 51.4 on 2023-02-13 due to rank 324.0, realized gain: -455.5
# Sold TITAGARH at 216.6 on 2023-02-13 due to rank 407.0, realized gain: 4776.5
# Sold PFC at 116.4 on 2023-02-13 due to rank 319.0, realized gain: 1811.0400000000081
# Bought JSL on 2023-02-12 at 257.95 no of share : 203
# Bought RVNL on 2023-02-12 at 71.0 no of share : 586
# Bought J&KBANK on 2023-02-12 at 53.8 no of share : 679
# Bought IOB on 2023-02-12 at 27.4 no of share : 1135
# Bought JINDALSAW on 2023-02-12 at 142.45 no of share : 422
# Bought GPIL on 2023-02-12 at 367.0 no of share : 126
# Bought MAHABANK on 2023-02-12 at 28.2 no of share : 1171
# Bought SWANENERGY on 2023-02-12 at 271.95 no of share : 122
# Bought JWL on 2023-02-12 at 101.95 no of share : 417
# Bought UNIONBANK on 2023-02-12 at 73.9 no of share : 523
# Bought CENTRALBK on 2023-02-12 at 27.95 no of share : 1170
# Bought USHAMART on 2023-02-12 at 190.9 no of share : 222
# Bought GICRE on 2023-02-12 at 159.0 no of share : 209
# Bought TITAGARH on 2023-02-12 at 216.6 no of share : 200
# Bought IRFC on 2023-02-12 at 30.2 no of share : 1404
# Bought PNBHOUSING on 2023-02-12 at 472.01 no of share : 96
# Bought PFC on 2023-02-12 at 116.4 no of share : 569
# Bought PNB on 2023-02-12 at 51.4 no of share : 892
# Reduced BANKINDIA to 452 shares on 2023-02-12
# Reduced BLS to 227 shares on 2023-02-12
# 2023-02-13
# 2023-02-14
# BHEL below SMA
# GICRE below SMA
# Sold BHEL at 71.0 on 2023-02-15, realized gain: -6019.199999999997
# Sold GICRE at 142.1 on 2023-02-15, realized gain: -3532.100000000002
# 2023-02-15
# BLS below SMA
# Sold BLS at 171.0 on 2023-02-16, realized gain: 1472.25
# 2023-02-16
# 2023-02-17
# 2023-02-18
# BANKINDIA below SMA
# Sold BANKINDIA at 75.7 on 2023-02-19, realized gain: -5886.4000000000015
# 2023-02-19
# File positions_2023-02-19.csv already exists. Loading existing data.
# Sold JSL at 265.45 on 2023-02-20 due to rank 233.0, realized gain: 1522.5
# Sold RVNL at 68.7 on 2023-02-20 due to rank 356.0, realized gain: -1347.7999999999956
# Sold J&KBANK at 50.4 on 2023-02-20 due to rank 224.0, realized gain: -2308.5999999999985
# Sold IOB at 25.8 on 2023-02-20 due to rank 214.0, realized gain: -1816.0
# Sold JINDALSAW at 147.0 on 2023-02-20 due to rank 227.0, realized gain: 1920.1000000000058
# Sold GPIL at 363.0 on 2023-02-20 due to rank 164.0, realized gain: -504.0
# Sold MAHABANK at 27.1 on 2023-02-20 due to rank 270.0, realized gain: -1288.099999999995
# Sold SWANENERGY at 277.45 on 2023-02-20 due to rank 389.0, realized gain: 671.0
# Sold JWL at 105.45 on 2023-02-20 due to rank 240.0, realized gain: 1459.5
# Sold UNIONBANK at 71.0 on 2023-02-20 due to rank 422.0, realized gain: -1516.7000000000044
# Sold CENTRALBK at 27.0 on 2023-02-20 due to rank 87.0, realized gain: -1111.5
# Sold USHAMART at 182.85 on 2023-02-20 due to rank 426.0, realized gain: -1787.1000000000058
# Sold TITAGARH at 214.8 on 2023-02-20 due to rank 407.0, realized gain: -360.0
# Sold IRFC at 28.95 on 2023-02-20 due to rank 220.0, realized gain: -1755.0
# Sold PNBHOUSING at 493.41 on 2023-02-20 due to rank 325.0, realized gain: 2054.4000000000015
# Sold PFC at 119.44 on 2023-02-20 due to rank 319.0, realized gain: 1729.7599999999948
# Sold PNB at 49.75 on 2023-02-20 due to rank 324.0, realized gain: -1471.7999999999956
# Bought JSL on 2023-02-19 at 265.45 no of share : 203
# Bought JINDALSAW on 2023-02-19 at 147.0 no of share : 396
# Bought RVNL on 2023-02-19 at 68.7 no of share : 594
# Bought GPIL on 2023-02-19 at 363.0 no of share : 126
# Bought IOB on 2023-02-19 at 25.8 no of share : 1167
# Bought JWL on 2023-02-19 at 105.45 no of share : 401
# Bought J&KBANK on 2023-02-19 at 50.4 no of share : 683
# Bought USHAMART on 2023-02-19 at 182.85 no of share : 222
# Bought SWANENERGY on 2023-02-19 at 277.45 no of share : 119
# Bought PNBHOUSING on 2023-02-19 at 493.41 no of share : 95
# Bought TITAGARH on 2023-02-19 at 214.8 no of share : 197
# Bought MAHABANK on 2023-02-19 at 27.1 no of share : 1205
# Bought PFC on 2023-02-19 at 119.44 no of share : 554
# Bought CIEINDIA on 2023-02-19 at 391.2 no of share : 132
# Bought NCC on 2023-02-19 at 92.15 no of share : 580
# Bought JINDALSTEL on 2023-02-19 at 590.9 no of share : 115
# Bought PNCINFRA on 2023-02-19 at 316.45 no of share : 163
# Bought JBMA on 2023-02-19 at 558.55 no of share : 86
# Bought CENTRALBK on 2023-02-19 at 27.0 no of share : 1214
# Bought RAJESHEXPO on 2023-02-19 at 765.9 no of share : 43
# 2023-02-20
# 2023-02-21
# CENTRALBK below SMA
# RAJESHEXPO below SMA
# Sold CENTRALBK at 25.55 on 2023-02-22, realized gain: -1760.2999999999993
# Sold RAJESHEXPO at 713.0 on 2023-02-22, realized gain: -2274.699999999997
# 2023-02-22
# IOB below SMA
# SWANENERGY below SMA
# MAHABANK below SMA
# Sold IOB at 24.4 on 2023-02-23, realized gain: -1633.800000000003
# Sold SWANENERGY at 253.4 on 2023-02-23, realized gain: -2861.9499999999935
# Sold MAHABANK at 25.3 on 2023-02-23, realized gain: -2169.0
# 2023-02-23
# 2023-02-24
# 2023-02-25
# 2023-02-26
# File positions_2023-02-26.csv already exists. Loading existing data.
# Sold JSL at 265.5 on 2023-02-27 due to rank 234.0, realized gain: 10.150000000001455
# Sold JINDALSAW at 157.55 on 2023-02-27 due to rank 228.0, realized gain: 4177.800000000003
# Sold RVNL at 62.9 on 2023-02-27 due to rank 357.0, realized gain: -3445.2000000000044
# Sold GPIL at 356.55 on 2023-02-27 due to rank 165.0, realized gain: -812.6999999999971
# Sold JWL at 95.9 on 2023-02-27 due to rank 241.0, realized gain: -3829.550000000003
# Sold J&KBANK at 48.2 on 2023-02-27 due to rank 225.0, realized gain: -1502.5999999999985
# Sold USHAMART at 178.1 on 2023-02-27 due to rank 427.0, realized gain: -1054.5
# Sold PNBHOUSING at 483.64 on 2023-02-27 due to rank 326.0, realized gain: -928.1500000000087
# Sold TITAGARH at 215.3 on 2023-02-27 due to rank 408.0, realized gain: 98.5
# Sold PFC at 115.2 on 2023-02-27 due to rank 320.0, realized gain: -2348.959999999992
# Sold CIEINDIA at 439.7 on 2023-02-27 due to rank 98.0, realized gain: 6402.0
# Sold NCC at 89.3 on 2023-02-27 due to rank 300.0, realized gain: -1653.0
# Sold JINDALSTEL at 559.0 on 2023-02-27 due to rank 229.0, realized gain: -3668.5
# Sold PNCINFRA at 293.0 on 2023-02-27 due to rank 327.0, realized gain: -3822.3499999999985
# Sold JBMA at 567.3 on 2023-02-27 due to rank 227.0, realized gain: 752.5
# 2023-02-27
# 2023-02-28
# 2023-03-01
# 2023-03-02
# 2023-03-03
# 2023-03-04
# 2023-03-05
# File positions_2023-03-05.csv already exists. Loading existing data.
# 2023-03-06
# 2023-03-07
# 2023-03-08
# 2023-03-09
# 2023-03-10
# 2023-03-11
# 2023-03-12
# File positions_2023-03-12.csv already exists. Loading existing data.
# 2023-03-13
# 2023-03-14
# 2023-03-15
# 2023-03-16
# 2023-03-17
# 2023-03-18
# 2023-03-19
# File positions_2023-03-19.csv already exists. Loading existing data.
# 2023-03-20
# 2023-03-21
# 2023-03-22
# 2023-03-23
# 2023-03-24
# 2023-03-25
# 2023-03-26
# File positions_2023-03-26.csv already exists. Loading existing data.
# 2023-03-27
# 2023-03-28
# 2023-03-29
# 2023-03-30
# 2023-03-31
# 2023-04-01
# 2023-04-02
# File positions_2023-04-02.csv already exists. Loading existing data.
# 2023-04-03
# 2023-04-04
# 2023-04-05
# 2023-04-06
# 2023-04-07
# 2023-04-08
# 2023-04-09
# File positions_2023-04-09.csv already exists. Loading existing data.
# 2023-04-10
# 2023-04-11
# 2023-04-12
# 2023-04-13
# 2023-04-14
# 2023-04-15
# 2023-04-16
# File positions_2023-04-16.csv already exists. Loading existing data.
# 2023-04-17
# 2023-04-18
# 2023-04-19
# 2023-04-20
# 2023-04-21
# 2023-04-22
# 2023-04-23
# File positions_2023-04-23.csv already exists. Loading existing data.
# 2023-04-24
# 2023-04-25
# 2023-04-26
# 2023-04-27
# 2023-04-28
# 2023-04-29
# 2023-04-30
# File positions_2023-04-30.csv already exists. Loading existing data.
# Bought FINCABLES on 2023-04-30 at 904.5 no of share : 64
# Bought SONATSOFTW on 2023-04-30 at 426.0 no of share : 119
# Bought JINDALSAW on 2023-04-30 at 164.65 no of share : 288
# Bought JBMA on 2023-04-30 at 803.5 no of share : 68
# Bought ANURAS on 2023-04-30 at 1139.0 no of share : 74
# Bought ACE on 2023-04-30 at 419.85 no of share : 135
# Bought TITAGARH on 2023-04-30 at 333.45 no of share : 159
# Bought CYIENT on 2023-04-30 at 1185.95 no of share : 62
# Bought ZENSARTECH on 2023-04-30 at 279.0 no of share : 197
# Bought SAFARI on 2023-04-30 at 2461.0 no of share : 24
# Bought TRITURBINE on 2023-04-30 at 367.15 no of share : 138
# Bought NCC on 2023-04-30 at 120.9 no of share : 573
# Bought KPITTECH on 2023-04-30 at 921.35 no of share : 57
# Bought USHAMART on 2023-04-30 at 215.4 no of share : 237
# Bought EQUITASBNK on 2023-04-30 at 69.25 no of share : 647
# 2023-05-01
# 2023-05-02
# 2023-05-03
# 2023-05-04
# 2023-05-05
# 2023-05-06
# 2023-05-07
# File positions_2023-05-07.csv already exists. Loading existing data.
# Sold FINCABLES at 905.2 on 2023-05-08 due to rank 146.0, realized gain: 44.80000000000291
# Sold SONATSOFTW at 432.5 on 2023-05-08 due to rank 383.0, realized gain: 773.5
# Sold JINDALSAW at 156.95 on 2023-05-08 due to rank 233.0, realized gain: -2217.600000000006
# Sold JBMA at 836.85 on 2023-05-08 due to rank 232.0, realized gain: 2267.800000000003
# Sold TITAGARH at 344.45 on 2023-05-08 due to rank 414.0, realized gain: 1749.0
# Sold CYIENT at 1208.0 on 2023-05-08 due to rank 116.0, realized gain: 1367.0999999999913
# Sold ZENSARTECH at 307.6 on 2023-05-08 due to rank 451.0, realized gain: 5634.200000000004
# Sold SAFARI at 2429.0 on 2023-05-08 due to rank 364.0, realized gain: -768.0
# Sold TRITURBINE at 359.25 on 2023-05-08 due to rank 420.0, realized gain: -1090.199999999997
# Sold NCC at 125.3 on 2023-05-08 due to rank 305.0, realized gain: 2521.199999999997
# Sold KPITTECH at 888.95 on 2023-05-08 due to rank 258.0, realized gain: -1846.800000000003
# Sold USHAMART at 231.8 on 2023-05-08 due to rank 433.0, realized gain: 3886.800000000003
# Sold EQUITASBNK at 76.0 on 2023-05-08 due to rank 139.0, realized gain: 4367.25
# Bought FINCABLES on 2023-05-07 at 905.2 no of share : 65
# Bought SONATSOFTW on 2023-05-07 at 432.5 no of share : 120
# Bought JBMA on 2023-05-07 at 836.85 no of share : 68
# Bought JINDALSAW on 2023-05-07 at 156.95 no of share : 290
# Bought TITAGARH on 2023-05-07 at 344.45 no of share : 153
# Bought CYIENT on 2023-05-07 at 1208.0 no of share : 60
# Bought TRITURBINE on 2023-05-07 at 359.25 no of share : 137
# Bought SAFARI on 2023-05-07 at 2429.0 no of share : 23
# Bought ZENSARTECH on 2023-05-07 at 307.6 no of share : 200
# Bought AUROPHARMA on 2023-05-07 at 599.15 no of share : 148
# Bought NCC on 2023-05-07 at 125.3 no of share : 567
# Bought KPITTECH on 2023-05-07 at 888.95 no of share : 56
# Bought EQUITASBNK on 2023-05-07 at 76.0 no of share : 654
# Reduced ANURAS to 68 shares on 2023-05-07
# 2023-05-08
# 2023-05-09
# 2023-05-10
# 2023-05-11
# 2023-05-12
# 2023-05-13
# 2023-05-14
# File positions_2023-05-14.csv already exists. Loading existing data.
# Sold FINCABLES at 905.7 on 2023-05-15 due to rank 146.0, realized gain: 32.5
# Sold SONATSOFTW at 430.03 on 2023-05-15 due to rank 383.0, realized gain: -296.40000000000146
# Sold JBMA at 771.0 on 2023-05-15 due to rank 232.0, realized gain: -4477.800000000003
# Sold JINDALSAW at 171.35 on 2023-05-15 due to rank 233.0, realized gain: 4176.0
# Sold TITAGARH at 344.75 on 2023-05-15 due to rank 414.0, realized gain: 45.900000000001455
# Sold CYIENT at 1210.0 on 2023-05-15 due to rank 116.0, realized gain: 120.0
# Sold TRITURBINE at 400.0 on 2023-05-15 due to rank 420.0, realized gain: 5582.75
# Sold SAFARI at 2494.9 on 2023-05-15 due to rank 364.0, realized gain: 1515.7000000000044
# Sold ZENSARTECH at 341.8 on 2023-05-15 due to rank 451.0, realized gain: 6839.999999999993
# Sold NCC at 118.65 on 2023-05-15 due to rank 305.0, realized gain: -3770.5499999999884
# Sold KPITTECH at 900.9 on 2023-05-15 due to rank 258.0, realized gain: 669.1999999999971
# Sold EQUITASBNK at 77.65 on 2023-05-15 due to rank 139.0, realized gain: 1079.1000000000058
# Bought FINCABLES on 2023-05-14 at 905.7 no of share : 66
# Bought JBMA on 2023-05-14 at 771.0 no of share : 66
# Bought SONATSOFTW on 2023-05-14 at 430.03 no of share : 122
# Bought TITAGARH on 2023-05-14 at 344.75 no of share : 149
# Bought JINDALSAW on 2023-05-14 at 171.35 no of share : 293
# Bought CYIENT on 2023-05-14 at 1210.0 no of share : 58
# Bought TRITURBINE on 2023-05-14 at 400.0 no of share : 133
# Bought SAFARI on 2023-05-14 at 2494.9 no of share : 22
# Bought ZENSARTECH on 2023-05-14 at 341.8 no of share : 200
# Bought NCC on 2023-05-14 at 118.65 no of share : 546
# Bought INDIAMART on 2023-05-14 at 2950.0 no of share : 29
# 2023-05-15
# 2023-05-16
# 2023-05-17
# 2023-05-18
# 2023-05-19
# 2023-05-20
# 2023-05-21
# File positions_2023-05-21.csv already exists. Loading existing data.
# Sold FINCABLES at 884.9 on 2023-05-22 due to rank 146.0, realized gain: -1372.800000000003
# Sold JBMA at 760.85 on 2023-05-22 due to rank 232.0, realized gain: -669.9000000000015
# Sold SONATSOFTW at 461.68 on 2023-05-22 due to rank 383.0, realized gain: 3861.300000000003
# Sold TITAGARH at 325.05 on 2023-05-22 due to rank 414.0, realized gain: -2935.2999999999956
# Sold JINDALSAW at 187.9 on 2023-05-22 due to rank 233.0, realized gain: 4849.150000000009
# Sold CYIENT at 1309.25 on 2023-05-22 due to rank 116.0, realized gain: 5756.5
# Sold TRITURBINE at 379.25 on 2023-05-22 due to rank 420.0, realized gain: -2759.75
# Sold SAFARI at 2536.75 on 2023-05-22 due to rank 364.0, realized gain: 920.6999999999971
# Sold ZENSARTECH at 353.85 on 2023-05-22 due to rank 451.0, realized gain: 2410.0
# Sold NCC at 114.3 on 2023-05-22 due to rank 305.0, realized gain: -2375.100000000006
# Sold INDIAMART at 2797.48 on 2023-05-22 due to rank 211.0, realized gain: -4423.080000000002
# Bought FINCABLES on 2023-05-21 at 884.9 no of share : 67
# Bought JBMA on 2023-05-21 at 760.85 no of share : 66
# Bought TITAGARH on 2023-05-21 at 325.05 no of share : 148
# Bought SONATSOFTW on 2023-05-21 at 461.68 no of share : 120
# Bought CYIENT on 2023-05-21 at 1309.25 no of share : 54
# Bought TRITURBINE on 2023-05-21 at 379.25 no of share : 129
# Bought JINDALSAW on 2023-05-21 at 187.9 no of share : 292
# Bought GLENMARK on 2023-05-21 at 588.0 no of share : 156
# Bought SAFARI on 2023-05-21 at 2536.75 no of share : 21
# Bought ZENSARTECH on 2023-05-21 at 353.85 no of share : 183
# Bought MAHSEAMLES on 2023-05-21 at 433.0 no of share : 143
# Reduced ANURAS to 58 shares on 2023-05-21
# Reduced AUROPHARMA to 140 shares on 2023-05-21
# 2023-05-22
# 2023-05-23
# 2023-05-24
# 2023-05-25
# 2023-05-26
# 2023-05-27
# 2023-05-28
# File positions_2023-05-28.csv already exists. Loading existing data.
# Sold FINCABLES at 840.0 on 2023-05-29 due to rank 146.0, realized gain: -3008.2999999999956
# Sold JBMA at 799.55 on 2023-05-29 due to rank 232.0, realized gain: 2554.199999999997
# Sold TITAGARH at 351.0 on 2023-05-29 due to rank 414.0, realized gain: 3840.5999999999985
# Sold SONATSOFTW at 486.55 on 2023-05-29 due to rank 383.0, realized gain: 2984.4000000000015
# Sold CYIENT at 1314.8 on 2023-05-29 due to rank 116.0, realized gain: 299.6999999999971
# Sold TRITURBINE at 403.7 on 2023-05-29 due to rank 420.0, realized gain: 3154.0499999999956
# Sold JINDALSAW at 197.0 on 2023-05-29 due to rank 233.0, realized gain: 2657.199999999997
# Sold GLENMARK at 591.4 on 2023-05-29 due to rank 159.0, realized gain: 530.3999999999942
# Sold SAFARI at 2698.95 on 2023-05-29 due to rank 364.0, realized gain: 3406.199999999997
# Sold ZENSARTECH at 378.3 on 2023-05-29 due to rank 451.0, realized gain: 4474.350000000006
# Sold MAHSEAMLES at 457.0 on 2023-05-29 due to rank 278.0, realized gain: 3432.0
# Bought FINCABLES on 2023-05-28 at 840.0 no of share : 69
# Bought TITAGARH on 2023-05-28 at 351.0 no of share : 146
# Bought JBMA on 2023-05-28 at 799.55 no of share : 66
# Bought SONATSOFTW on 2023-05-28 at 486.55 no of share : 119
# Bought GLENMARK on 2023-05-28 at 591.4 no of share : 148
# Bought CYIENT on 2023-05-28 at 1314.8 no of share : 51
# Bought TRITURBINE on 2023-05-28 at 403.7 no of share : 126
# Bought MAHSEAMLES on 2023-05-28 at 457.0 no of share : 141
# Bought JINDALSAW on 2023-05-28 at 197.0 no of share : 283
# Bought SAFARI on 2023-05-28 at 2698.95 no of share : 20
# Bought EQUITASBNK on 2023-05-28 at 84.8 no of share : 652
# Bought ZENSARTECH on 2023-05-28 at 378.3 no of share : 172
# 2023-05-29
# 2023-05-30
# 2023-05-31
# 2023-06-01
# 2023-06-02
# 2023-06-03
# 2023-06-04
# File positions_2023-06-04.csv already exists. Loading existing data.
# Sold FINCABLES at 795.0 on 2023-06-05 due to rank 146.0, realized gain: -3105.0
# Sold TITAGARH at 380.9 on 2023-06-05 due to rank 414.0, realized gain: 4365.399999999994
# Sold JBMA at 805.9 on 2023-06-05 due to rank 232.0, realized gain: 419.1000000000058
# Sold SONATSOFTW at 495.0 on 2023-06-05 due to rank 383.0, realized gain: 1005.5499999999956
# Sold GLENMARK at 609.8 on 2023-06-05 due to rank 159.0, realized gain: 2723.199999999997
# Sold CYIENT at 1477.0 on 2023-06-05 due to rank 116.0, realized gain: 8272.199999999997
# Sold TRITURBINE at 390.6 on 2023-06-05 due to rank 420.0, realized gain: -1650.5999999999913
# Sold MAHSEAMLES at 483.95 on 2023-06-05 due to rank 278.0, realized gain: 3799.949999999997
# Sold JINDALSAW at 248.3 on 2023-06-05 due to rank 233.0, realized gain: 14517.900000000009
# Sold SAFARI at 2792.4 on 2023-06-05 due to rank 364.0, realized gain: 1869.0
# Sold EQUITASBNK at 87.25 on 2023-06-05 due to rank 139.0, realized gain: 1597.4000000000015
# Sold ZENSARTECH at 405.0 on 2023-06-05 due to rank 451.0, realized gain: 4592.4000000000015
# Bought TITAGARH on 2023-06-04 at 380.9 no of share : 144
# Bought JBMA on 2023-06-04 at 805.9 no of share : 68
# Bought GLENMARK on 2023-06-04 at 609.8 no of share : 145
# Bought CYIENT on 2023-06-04 at 1477.0 no of share : 47
# Bought FINCABLES on 2023-06-04 at 795.0 no of share : 69
# Bought SONATSOFTW on 2023-06-04 at 495.0 no of share : 119
# Bought MAHSEAMLES on 2023-06-04 at 483.95 no of share : 138
# Bought SAFARI on 2023-06-04 at 2792.4 no of share : 20
# Bought CHENNPETRO on 2023-06-04 at 381.3 no of share : 166
# Bought TRITURBINE on 2023-06-04 at 390.6 no of share : 125
# Bought JINDALSAW on 2023-06-04 at 248.3 no of share : 263
# Bought EQUITASBNK on 2023-06-04 at 87.25 no of share : 652
# Reduced ANURAS to 54 shares on 2023-06-04
# Reduced AUROPHARMA to 126 shares on 2023-06-04
# 2023-06-05
# 2023-06-06
# 2023-06-07
# 2023-06-08
# 2023-06-09
# 2023-06-10
# 2023-06-11
# File positions_2023-06-11.csv already exists. Loading existing data.
# Sold TITAGARH at 425.0 on 2023-06-12 due to rank 414.0, realized gain: 6350.4000000000015
# Sold JBMA at 922.45 on 2023-06-12 due to rank 232.0, realized gain: 7925.400000000009
# Sold GLENMARK at 647.0 on 2023-06-12 due to rank 159.0, realized gain: 5394.0
# Sold CYIENT at 1373.0 on 2023-06-12 due to rank 116.0, realized gain: -4888.0
# Sold FINCABLES at 806.0 on 2023-06-12 due to rank 146.0, realized gain: 759.0
# Sold SONATSOFTW at 520.55 on 2023-06-12 due to rank 383.0, realized gain: 3040.449999999997
# Sold MAHSEAMLES at 496.0 on 2023-06-12 due to rank 278.0, realized gain: 1662.9000000000087
# Sold SAFARI at 2876.4 on 2023-06-12 due to rank 364.0, realized gain: 1680.0
# Sold CHENNPETRO at 361.05 on 2023-06-12 due to rank 97.0, realized gain: -3361.5
# Sold TRITURBINE at 417.7 on 2023-06-12 due to rank 420.0, realized gain: 3387.5
# Sold JINDALSAW at 241.2 on 2023-06-12 due to rank 233.0, realized gain: -1867.300000000003
# Sold EQUITASBNK at 84.7 on 2023-06-12 due to rank 139.0, realized gain: -1662.5999999999985
# Bought TITAGARH on 2023-06-11 at 425.0 no of share : 140
# Bought JBMA on 2023-06-11 at 922.45 no of share : 68
# Bought GLENMARK on 2023-06-11 at 647.0 no of share : 140
# Bought CYIENT on 2023-06-11 at 1373.0 no of share : 44
# Bought MAHSEAMLES on 2023-06-11 at 496.0 no of share : 136
# Bought IRCON on 2023-06-11 at 83.7 no of share : 564
# Bought CHENNPETRO on 2023-06-11 at 361.05 no of share : 162
# Bought GLS on 2023-06-11 at 600.0 no of share : 124
# Bought SAFARI on 2023-06-11 at 2876.4 no of share : 20
# Bought SONATSOFTW on 2023-06-11 at 520.55 no of share : 120
# Bought MINDACORP on 2023-06-11 at 272.85 no of share : 197
# Bought TRITURBINE on 2023-06-11 at 417.7 no of share : 125
# Bought JINDALSAW on 2023-06-11 at 241.2 no of share : 241
# 2023-06-12
# 2023-06-13
# 2023-06-14
# 2023-06-15
# 2023-06-16
# 2023-06-17
# 2023-06-18
# File positions_2023-06-18.csv already exists. Loading existing data.
# Sold TITAGARH at 432.9 on 2023-06-19 due to rank 414.0, realized gain: 1106.0
# Sold JBMA at 989.0 on 2023-06-19 due to rank 232.0, realized gain: 4525.399999999994
# Sold GLENMARK at 642.4 on 2023-06-19 due to rank 159.0, realized gain: -644.0
# Sold CYIENT at 1490.0 on 2023-06-19 due to rank 116.0, realized gain: 5148.0
# Sold MAHSEAMLES at 474.95 on 2023-06-19 due to rank 278.0, realized gain: -2862.800000000003
# Sold IRCON at 83.55 on 2023-06-19 due to rank 224.0, realized gain: -84.60000000000582
# Sold CHENNPETRO at 387.3 on 2023-06-19 due to rank 97.0, realized gain: 4252.5
# Sold GLS at 602.05 on 2023-06-19 due to rank 160.0, realized gain: 254.1999999999971
# Sold SAFARI at 3016.0 on 2023-06-19 due to rank 364.0, realized gain: 2792.0
# Sold SONATSOFTW at 512.5 on 2023-06-19 due to rank 383.0, realized gain: -965.9999999999927
# Sold MINDACORP at 293.0 on 2023-06-19 due to rank 290.0, realized gain: 3969.5499999999956
# Sold TRITURBINE at 425.1 on 2023-06-19 due to rank 420.0, realized gain: 925.0
# Sold JINDALSAW at 235.9 on 2023-06-19 due to rank 233.0, realized gain: -1277.2999999999956
# Bought TITAGARH on 2023-06-18 at 432.9 no of share : 135
# Bought JBMA on 2023-06-18 at 989.0 no of share : 66
# Bought ADANIPOWER on 2023-06-18 at 266.9 no of share : 203
# Bought IRCON on 2023-06-18 at 83.55 no of share : 561
# Bought GLENMARK on 2023-06-18 at 642.4 no of share : 135
# Bought CHENNPETRO on 2023-06-18 at 387.3 no of share : 160
# Bought GLS on 2023-06-18 at 602.05 no of share : 120
# Bought CYIENT on 2023-06-18 at 1490.0 no of share : 41
# Bought MAHSEAMLES on 2023-06-18 at 474.95 no of share : 135
# Bought HSCL on 2023-06-18 at 133.3 no of share : 477
# Bought RKFORGE on 2023-06-18 at 429.35 no of share : 157
# Bought SAFARI on 2023-06-18 at 3016.0 no of share : 20
# Bought JINDALSAW on 2023-06-18 at 235.9 no of share : 227
# Reduced ANURAS to 51 shares on 2023-06-18
# 2023-06-19
# 2023-06-20
# 2023-06-21
# 2023-06-22
# 2023-06-23
# 2023-06-24
# 2023-06-25
# File positions_2023-06-25.csv already exists. Loading existing data.
# Sold TITAGARH at 469.6 on 2023-06-26 due to rank 416.0, realized gain: 4954.5
# Sold JBMA at 1008.9 on 2023-06-26 due to rank 232.0, realized gain: 1313.3999999999942
# Sold IRCON at 83.1 on 2023-06-26 due to rank 224.0, realized gain: -252.4499999999971
# Sold GLENMARK at 630.0 on 2023-06-26 due to rank 159.0, realized gain: -1674.0
# Sold CHENNPETRO at 377.95 on 2023-06-26 due to rank 97.0, realized gain: -1496.0
# Sold GLS at 557.1 on 2023-06-26 due to rank 160.0, realized gain: -5394.0
# Sold CYIENT at 1460.3 on 2023-06-26 due to rank 116.0, realized gain: -1217.7000000000044
# Sold MAHSEAMLES at 477.5 on 2023-06-26 due to rank 278.0, realized gain: 344.25
# Sold HSCL at 131.4 on 2023-06-26 due to rank 197.0, realized gain: -906.3000000000029
# Sold RKFORGE at 430.0 on 2023-06-26 due to rank 362.0, realized gain: 102.05000000000291
# Sold SAFARI at 2928.5 on 2023-06-26 due to rank 366.0, realized gain: -1750.0
# Sold JINDALSAW at 231.55 on 2023-06-26 due to rank 233.0, realized gain: -987.4499999999971
# Bought TITAGARH on 2023-06-25 at 469.6 no of share : 126
# Bought IRCON on 2023-06-25 at 83.1 no of share : 557
# Bought JBMA on 2023-06-25 at 1008.9 no of share : 63
# Bought CHENNPETRO on 2023-06-25 at 377.95 no of share : 159
# Bought CYIENT on 2023-06-25 at 1460.3 no of share : 39
# Bought GLS on 2023-06-25 at 557.1 no of share : 117
# Bought GLENMARK on 2023-06-25 at 630.0 no of share : 132
# Bought HSCL on 2023-06-25 at 131.4 no of share : 471
# Bought RKFORGE on 2023-06-25 at 430.0 no of share : 145
# Bought ENGINERSIN on 2023-06-25 at 113.3 no of share : 522
# Bought MAHSEAMLES on 2023-06-25 at 477.5 no of share : 135
# Bought CHOLAHLDNG on 2023-06-25 at 876.0 no of share : 75
# 2023-06-26
# 2023-06-27
# 2023-06-28
# 2023-06-29
# 2023-06-30
# 2023-07-01
# 2023-07-02
# File positions_2023-07-02.csv already exists. Loading existing data.
# Sold TITAGARH at 506.4 on 2023-07-03 due to rank 418.0, realized gain: 4636.799999999988
# Sold IRCON at 83.95 on 2023-07-03 due to rank 224.0, realized gain: 473.45000000000437
# Sold JBMA at 1345.05 on 2023-07-03 due to rank 232.0, realized gain: 21177.449999999997
# Sold CHENNPETRO at 389.9 on 2023-07-03 due to rank 97.0, realized gain: 1900.050000000003
# Sold CYIENT at 1516.15 on 2023-07-03 due to rank 116.0, realized gain: 2178.1500000000087
# Sold GLS at 571.1 on 2023-07-03 due to rank 160.0, realized gain: 1637.9999999999927
# Sold GLENMARK at 676.0 on 2023-07-03 due to rank 159.0, realized gain: 6072.0
# Sold HSCL at 133.45 on 2023-07-03 due to rank 197.0, realized gain: 965.5499999999956
# Sold RKFORGE at 447.0 on 2023-07-03 due to rank 363.0, realized gain: 2465.0
# Sold ENGINERSIN at 115.5 on 2023-07-03 due to rank 137.0, realized gain: 1148.4000000000015
# Sold MAHSEAMLES at 475.45 on 2023-07-03 due to rank 278.0, realized gain: -276.75
# Sold CHOLAHLDNG at 900.0 on 2023-07-03 due to rank 99.0, realized gain: 1800.0
# Bought TITAGARH on 2023-07-02 at 506.4 no of share : 119
# Bought CHENNPETRO on 2023-07-02 at 389.9 no of share : 159
# Bought JBMA on 2023-07-02 at 1345.05 no of share : 59
# Bought IRCON on 2023-07-02 at 83.95 no of share : 561
# Bought RKFORGE on 2023-07-02 at 447.0 no of share : 136
# Bought CHOLAHLDNG on 2023-07-02 at 900.0 no of share : 74
# Bought HSCL on 2023-07-02 at 133.45 no of share : 471
# Bought CYIENT on 2023-07-02 at 1516.15 no of share : 39
# Bought ENGINERSIN on 2023-07-02 at 115.5 no of share : 514
# Bought GLS on 2023-07-02 at 571.1 no of share : 115
# Bought GLENMARK on 2023-07-02 at 676.0 no of share : 130
# Bought SCHNEIDER on 2023-07-02 at 262.0 no of share : 218
# Bought ADANIENT on 2023-07-02 at 2405.0 no of share : 18
# 2023-07-03
# 2023-07-04
# 2023-07-05
# 2023-07-06
# 2023-07-07
# 2023-07-08
# 2023-07-09
# File positions_2023-07-09.csv already exists. Loading existing data.
# Sold TITAGARH at 503.0 on 2023-07-10 due to rank 419.0, realized gain: -404.59999999999854
# Sold CHENNPETRO at 441.75 on 2023-07-10 due to rank 97.0, realized gain: 8244.150000000001
# Sold JBMA at 1355.0 on 2023-07-10 due to rank 232.0, realized gain: 587.0500000000029
# Sold IRCON at 82.5 on 2023-07-10 due to rank 224.0, realized gain: -813.4500000000044
# Sold RKFORGE at 449.0 on 2023-07-10 due to rank 364.0, realized gain: 272.0
# Sold CHOLAHLDNG at 936.0 on 2023-07-10 due to rank 99.0, realized gain: 2664.0
# Sold HSCL at 129.55 on 2023-07-10 due to rank 197.0, realized gain: -1836.8999999999942
# Sold CYIENT at 1494.0 on 2023-07-10 due to rank 116.0, realized gain: -863.8500000000058
# Sold ENGINERSIN at 121.75 on 2023-07-10 due to rank 137.0, realized gain: 3212.5
# Sold GLS at 602.25 on 2023-07-10 due to rank 160.0, realized gain: 3582.25
# Sold GLENMARK at 691.9 on 2023-07-10 due to rank 159.0, realized gain: 2067.0
# Sold SCHNEIDER at 279.95 on 2023-07-10 due to rank 378.0, realized gain: 3913.0999999999985
# Bought TITAGARH on 2023-07-09 at 503.0 no of share : 115
# Bought SUZLON on 2023-07-09 at 18.05 no of share : 3091
# Bought JBMA on 2023-07-09 at 1355.0 no of share : 50
# Bought CHENNPETRO on 2023-07-09 at 441.75 no of share : 155
# Bought CHOLAHLDNG on 2023-07-09 at 936.0 no of share : 71
# Bought SCHNEIDER on 2023-07-09 at 279.95 no of share : 208
# Bought JWL on 2023-07-09 at 176.0 no of share : 325
# Bought JINDALSAW on 2023-07-09 at 285.95 no of share : 205
# Bought RKFORGE on 2023-07-09 at 449.0 no of share : 129
# Bought ENGINERSIN on 2023-07-09 at 121.75 no of share : 509
# Bought IRCON on 2023-07-09 at 82.5 no of share : 581
# Bought HEG on 2023-07-09 at 1584.7 no of share : 39
# Bought CYIENT on 2023-07-09 at 1494.0 no of share : 39
# 2023-07-10
# 2023-07-11
# 2023-07-12
# 2023-07-13
# 2023-07-14
# 2023-07-15
# 2023-07-16
# File positions_2023-07-16.csv already exists. Loading existing data.
# Sold TITAGARH at 539.7 on 2023-07-17 due to rank 419.0, realized gain: 4220.500000000007
# Sold SUZLON at 18.25 on 2023-07-17 due to rank 400.0, realized gain: 618.1999999999971
# Sold JBMA at 1483.8 on 2023-07-17 due to rank 232.0, realized gain: 6440.0
# Sold CHENNPETRO at 438.0 on 2023-07-17 due to rank 97.0, realized gain: -581.25
# Sold CHOLAHLDNG at 934.95 on 2023-07-17 due to rank 99.0, realized gain: -74.55000000000291
# Sold SCHNEIDER at 284.0 on 2023-07-17 due to rank 378.0, realized gain: 842.4000000000015
# Sold JWL at 182.4 on 2023-07-17 due to rank 246.0, realized gain: 2080.0
# Sold JINDALSAW at 317.45 on 2023-07-17 due to rank 233.0, realized gain: 6457.5
# Sold RKFORGE at 473.8 on 2023-07-17 due to rank 364.0, realized gain: 3199.2000000000044
# Sold ENGINERSIN at 130.0 on 2023-07-17 due to rank 137.0, realized gain: 4199.25
# Sold IRCON at 81.0 on 2023-07-17 due to rank 224.0, realized gain: -871.5
# Sold HEG at 1613.7 on 2023-07-17 due to rank 187.0, realized gain: 1131.0
# Sold CYIENT at 1450.0 on 2023-07-17 due to rank 116.0, realized gain: -1716.0
# Bought TITAGARH on 2023-07-16 at 539.7 no of share : 111
# Bought SUZLON on 2023-07-16 at 18.25 no of share : 2874
# Bought JBMA on 2023-07-16 at 1483.8 no of share : 43
# Bought JINDALSAW on 2023-07-16 at 317.45 no of share : 193
# Bought SCHNEIDER on 2023-07-16 at 284.0 no of share : 200
# Bought JWL on 2023-07-16 at 182.4 no of share : 314
# Bought CHENNPETRO on 2023-07-16 at 438.0 no of share : 149
# Bought TANLA on 2023-07-16 at 1121.0 no of share : 54
# Bought CHOLAHLDNG on 2023-07-16 at 934.95 no of share : 70
# Bought ELECON on 2023-07-16 at 363.95 no of share : 188
# Bought RKFORGE on 2023-07-16 at 473.8 no of share : 125
# Bought HEG on 2023-07-16 at 1613.7 no of share : 38
# Bought INOXWIND on 2023-07-16 at 50.03 no of share : 1107
# Reduced AUROPHARMA to 115 shares on 2023-07-16
# Reduced ACE to 118 shares on 2023-07-16
# Increased ADANIENT to 19 shares on 2023-07-16
# Increased ADANIPOWER to 215 shares on 2023-07-16
# Increased ANURAS to 54 shares on 2023-07-16
# 2023-07-17
# 2023-07-18
# 2023-07-19
# 2023-07-20
# 2023-07-21
# ANURAS below SMA
# Sold ANURAS at 979.7 on 2023-07-22, realized gain: -7800.0999999999985
# 2023-07-22
# 2023-07-23
# File positions_2023-07-23.csv already exists. Loading existing data.
# Sold TITAGARH at 671.95 on 2023-07-24 due to rank 420.0, realized gain: 14679.750000000007
# Sold SUZLON at 20.55 on 2023-07-24 due to rank 401.0, realized gain: 6610.200000000004
# Sold JBMA at 1405.95 on 2023-07-24 due to rank 232.0, realized gain: -3347.550000000003
# Sold JINDALSAW at 380.3 on 2023-07-24 due to rank 233.0, realized gain: 12130.05000000001
# Sold SCHNEIDER at 284.65 on 2023-07-24 due to rank 378.0, realized gain: 129.99999999999272
# Sold JWL at 197.0 on 2023-07-24 due to rank 246.0, realized gain: 4584.4000000000015
# Sold CHENNPETRO at 445.55 on 2023-07-24 due to rank 97.0, realized gain: 1124.949999999997
# Sold TANLA at 1266.1 on 2023-07-24 due to rank 405.0, realized gain: 7835.399999999994
# Sold CHOLAHLDNG at 916.1 on 2023-07-24 due to rank 99.0, realized gain: -1319.5
# Sold ELECON at 370.35 on 2023-07-24 due to rank 133.0, realized gain: 1203.2000000000116
# Sold RKFORGE at 513.0 on 2023-07-24 due to rank 364.0, realized gain: 4900.0
# Sold HEG at 1622.8 on 2023-07-24 due to rank 187.0, realized gain: 345.8000000000029
# Sold INOXWIND at 48.0 on 2023-07-24 due to rank 218.0, realized gain: -2247.209999999999
# Bought SUZLON on 2023-07-23 at 20.55 no of share : 2761
# Bought TITAGARH on 2023-07-23 at 671.95 no of share : 107
# Bought JINDALSAW on 2023-07-23 at 380.3 no of share : 179
# Bought JBMA on 2023-07-23 at 1405.95 no of share : 39
# Bought TANLA on 2023-07-23 at 1266.1 no of share : 52
# Bought JWL on 2023-07-23 at 197.0 no of share : 302
# Bought SCHNEIDER on 2023-07-23 at 284.65 no of share : 192
# Bought INOXWIND on 2023-07-23 at 48.0 no of share : 1034
# Bought CHENNPETRO on 2023-07-23 at 445.55 no of share : 145
# Bought OLECTRA on 2023-07-23 at 1271.0 no of share : 44
# Bought CHOLAHLDNG on 2023-07-23 at 916.1 no of share : 69
# Bought ELECON on 2023-07-23 at 370.35 no of share : 175
# Bought UJJIVANSFB on 2023-07-23 at 43.2 no of share : 1604
# Bought RKFORGE on 2023-07-23 at 513.0 no of share : 122
# Bought HEG on 2023-07-23 at 1622.8 no of share : 37
# 2023-07-24
# 2023-07-25
# 2023-07-26
# 2023-07-27
# 2023-07-28
# 2023-07-29
# 2023-07-30
# File positions_2023-07-30.csv already exists. Loading existing data.
# Sold SUZLON at 18.2 on 2023-07-31 due to rank 402.0, realized gain: -6488.350000000006
# Sold TITAGARH at 664.5 on 2023-07-31 due to rank 421.0, realized gain: -797.1500000000087
# Sold JINDALSAW at 325.65 on 2023-07-31 due to rank 234.0, realized gain: -9782.349999999999
# Sold JBMA at 1420.0 on 2023-07-31 due to rank 233.0, realized gain: 547.9499999999971
# Sold TANLA at 1228.0 on 2023-07-31 due to rank 406.0, realized gain: -1981.199999999997
# ...
# Sold ESCORTS at 3820.05 on 2024-08-05 due to rank 149.0, realized gain: -5854.399999999994
# Sold SUZLON at 69.9 on 2024-08-05 due to rank 420.0, realized gain: 7026.450000000004
# Sold SUNTECK at 565.3 on 2024-08-05 due to rank 416.0, realized gain: -2684.0
# Sold BRIGADE at 1170.0 on 2024-08-05 due to rank 80.0, realized gain: -2818.2000000000044
# Sold HONAUT at 52900.0 on 2024-08-05 due to rank 205.0, realized gain: -1553.75
# Sold SUPREMEIND at 4925.0 on 2024-08-05 due to rank 418.0, realized gain: -4520.0
# Sold DEEPAKFERT at 931.0 on 2024-08-05 due to rank 127.0, realized gain: 4095.0
# Sold VGUARD at 447.0 on 2024-08-05 due to rank 465.0, realized gain: -2362.7999999999956
# Sold GRINDWELL at 2441.0 on 2024-08-05 due to rank 183.0, realized gain: -3507.0
# Sold SUMICHEM at 504.95 on 2024-08-05 due to rank 412.0, realized gain: -3299.5999999999985
# Sold GLENMARK at 1415.0 on 2024-08-05 due to rank 168.0, realized gain: -1309.5
# Bought COCHINSHIP on 2024-08-04 at 2416.1 no of share : 15
# Bought EMAMILTD on 2024-08-04 at 768.95 no of share : 65
# Bought MOTHERSON on 2024-08-04 at 188.0 no of share : 331
# Bought FINCABLES on 2024-08-04 at 1522.0 no of share : 30
# Bought DIXON on 2024-08-04 at 10950.05 no of share : 5
# Bought POWERINDIA on 2024-08-04 at 11642.1 no of share : 3
# Bought JKPAPER on 2024-08-04 at 494.85 no of share : 85
# Bought CROMPTON on 2024-08-04 at 427.05 no of share : 155
# Bought WHIRLPOOL on 2024-08-04 at 2088.55 no of share : 30
# Bought UNOMINDA on 2024-08-04 at 900.0 no of share : 44
# Bought COROMANDEL on 2024-08-04 at 1610.0 no of share : 43
# Bought SUZLON on 2024-08-04 at 69.9 no of share : 980
# Bought KNRCON on 2024-08-04 at 362.05 no of share : 123
# Bought DEEPAKFERT on 2024-08-04 at 931.0 no of share : 60
# Bought EXIDEIND on 2024-08-04 at 490.0 no of share : 108
# Bought M&M on 2024-08-04 at 2679.65 no of share : 26
# Bought GPIL on 2024-08-04 at 1075.0 no of share : 46
# Bought NBCC on 2024-08-04 at 173.8 no of share : 228
# Bought SUNTECK on 2024-08-04 at 565.3 no of share : 85
# Bought SAREGAMA on 2024-08-04 at 507.85 no of share : 102
# Bought GLENMARK on 2024-08-04 at 1415.0 no of share : 53
# Bought VGUARD on 2024-08-04 at 447.0 no of share : 128
# Bought TRENT on 2024-08-04 at 5360.0 no of share : 12
# Bought GLAXO on 2024-08-04 at 2760.0 no of share : 20
# Bought INDIACEM on 2024-08-04 at 365.5 no of share : 163
# Bought TIMKEN on 2024-08-04 at 4199.65 no of share : 11
# Bought EIDPARRY on 2024-08-04 at 749.0 no of share : 75
# Bought SUMICHEM on 2024-08-04 at 504.95 no of share : 110
# Bought SUNTV on 2024-08-04 at 885.0 no of share : 86
# Bought GODFRYPHLP on 2024-08-04 at 4122.35 no of share : 10
# 2024-08-05
# 2024-08-06
# 2024-08-07
# 2024-08-08
# 2024-08-09
# 2024-08-10
# 2024-08-11
# File positions_2024-08-11.csv already exists. Loading existing data.
# Sold COCHINSHIP at 2365.0 on 2024-08-12 due to rank 110.0, realized gain: -766.5
# Sold EMAMILTD at 800.25 on 2024-08-12 due to rank 143.0, realized gain: 2034.5
# Sold MOTHERSON at 185.8 on 2024-08-12 due to rank 310.0, realized gain: -728.1999999999971
# Sold FINCABLES at 1490.0 on 2024-08-12 due to rank 154.0, realized gain: -960.0
# Sold DIXON at 11739.65 on 2024-08-12 due to rank 132.0, realized gain: 3948.0
# Sold POWERINDIA at 11010.8 on 2024-08-12 due to rank 360.0, realized gain: -1893.9000000000087
# Sold JKPAPER at 485.0 on 2024-08-12 due to rank 246.0, realized gain: -837.25
# Sold CROMPTON at 434.95 on 2024-08-12 due to rank 118.0, realized gain: 1224.5
# Sold WHIRLPOOL at 2070.1 on 2024-08-12 due to rank 474.0, realized gain: -553.5000000000073
# Sold UNOMINDA at 1000.0 on 2024-08-12 due to rank 458.0, realized gain: 4400.0
# Sold COROMANDEL at 1709.0 on 2024-08-12 due to rank 114.0, realized gain: 4257.0
# Sold SUZLON at 77.15 on 2024-08-12 due to rank 421.0, realized gain: 7105.0
# Sold KNRCON at 366.0 on 2024-08-12 due to rank 266.0, realized gain: 485.84999999999854
# Sold DEEPAKFERT at 994.8 on 2024-08-12 due to rank 127.0, realized gain: 3828.0
# Sold EXIDEIND at 488.0 on 2024-08-12 due to rank 150.0, realized gain: -216.0
# Sold M&M at 2749.15 on 2024-08-12 due to rank 287.0, realized gain: 1807.0
# Sold GPIL at 1105.05 on 2024-08-12 due to rank 178.0, realized gain: 1382.2999999999956
# Sold NBCC at 183.96 on 2024-08-12 due to rank 323.0, realized gain: 2316.480000000003
# Sold SUNTECK at 580.4 on 2024-08-12 due to rank 417.0, realized gain: 1283.5000000000073
# Sold SAREGAMA at 480.5 on 2024-08-12 due to rank 393.0, realized gain: -2789.7000000000044
# Sold GLENMARK at 1475.6 on 2024-08-12 due to rank 168.0, realized gain: 3211.7999999999884
# Sold VGUARD at 472.05 on 2024-08-12 due to rank 466.0, realized gain: 3206.4000000000015
# Sold TRENT at 6302.95 on 2024-08-12 due to rank 445.0, realized gain: 11315.399999999994
# Sold GLAXO at 2889.0 on 2024-08-12 due to rank 167.0, realized gain: 2580.0
# Sold INDIACEM at 366.0 on 2024-08-12 due to rank 219.0, realized gain: 81.5
# Sold TIMKEN at 3945.0 on 2024-08-12 due to rank 440.0, realized gain: -2801.149999999994
# Sold EIDPARRY at 767.1 on 2024-08-12 due to rank 139.0, realized gain: 1357.5
# Sold SUMICHEM at 516.4 on 2024-08-12 due to rank 413.0, realized gain: 1259.5
# Sold SUNTV at 899.0 on 2024-08-12 due to rank 418.0, realized gain: 1204.0
# Sold GODFRYPHLP at 4430.0 on 2024-08-12 due to rank 174.0, realized gain: 3076.5
# Bought COCHINSHIP on 2024-08-11 at 2365.0 no of share : 15
# Bought EMAMILTD on 2024-08-11 at 800.25 no of share : 63
# Bought MOTHERSON on 2024-08-11 at 185.8 no of share : 319
# Bought FINCABLES on 2024-08-11 at 1490.0 no of share : 31
# Bought DIXON on 2024-08-11 at 11739.65 no of share : 5
# Bought SUZLON on 2024-08-11 at 77.15 no of share : 917
# Bought DEEPAKFERT on 2024-08-11 at 994.8 no of share : 56
# Bought WHIRLPOOL on 2024-08-11 at 2070.1 no of share : 29
# Bought JKPAPER on 2024-08-11 at 485.0 no of share : 83
# Bought INDIACEM on 2024-08-11 at 366.0 no of share : 160
# Bought COROMANDEL on 2024-08-11 at 1709.0 no of share : 42
# Bought CROMPTON on 2024-08-11 at 434.95 no of share : 148
# Bought UNOMINDA on 2024-08-11 at 1000.0 no of share : 44
# Bought KNRCON on 2024-08-11 at 366.0 no of share : 119
# Bought POWERINDIA on 2024-08-11 at 11010.8 no of share : 3
# Bought GLENMARK on 2024-08-11 at 1475.6 no of share : 52
# Bought SUVENPHAR on 2024-08-11 at 940.0 no of share : 59
# Bought VGUARD on 2024-08-11 at 472.05 no of share : 125
# Bought SUNTV on 2024-08-11 at 899.0 no of share : 85
# Bought GLAXO on 2024-08-11 at 2889.0 no of share : 20
# Bought TRENT on 2024-08-11 at 6302.95 no of share : 12
# Bought OIL on 2024-08-11 at 642.5 no of share : 77
# Bought NBCC on 2024-08-11 at 183.96 no of share : 220
# Bought CHOLAHLDNG on 2024-08-11 at 1539.85 no of share : 36
# Bought GPIL on 2024-08-11 at 1105.05 no of share : 46
# Bought SUNTECK on 2024-08-11 at 580.4 no of share : 83
# Bought LALPATHLAB on 2024-08-11 at 3186.4 no of share : 25
# Bought AFFLE on 2024-08-11 at 1595.95 no of share : 38
# Bought M&M on 2024-08-11 at 2749.15 no of share : 25
# Bought IRCON on 2024-08-11 at 264.55 no of share : 126
# Reduced BIKAJI to 84 shares on 2024-08-11
# Reduced ASHOKLEY to 277 shares on 2024-08-11
# Reduced BHARATFORG to 37 shares on 2024-08-11
# Reduced APARINDS to 5 shares on 2024-08-11
# 2024-08-12
# 2024-08-13
# 2024-08-14
# BALKRISIND below SMA
# Sold BALKRISIND at 2794.95 on 2024-08-15, realized gain: -9340.30000000001
# 2024-08-15
# IRCON below SMA
# Sold IRCON at 265.8 on 2024-08-16, realized gain: 157.5
# 2024-08-16
# 2024-08-17
# 2024-08-18
# File positions_2024-08-18.csv already exists. Loading existing data.
# Sold COCHINSHIP at 2206.0 on 2024-08-19 due to rank 110.0, realized gain: -2385.0
# Sold EMAMILTD at 825.85 on 2024-08-19 due to rank 143.0, realized gain: 1612.800000000003
# Sold MOTHERSON at 187.0 on 2024-08-19 due to rank 310.0, realized gain: 382.79999999999563
# Sold FINCABLES at 1456.0 on 2024-08-19 due to rank 154.0, realized gain: -1054.0
# Sold DIXON at 12550.0 on 2024-08-19 due to rank 132.0, realized gain: 4051.75
# Sold SUZLON at 80.64 on 2024-08-19 due to rank 421.0, realized gain: 3200.3300000000017
# Sold DEEPAKFERT at 953.0 on 2024-08-19 due to rank 127.0, realized gain: -2340.7999999999956
# Sold WHIRLPOOL at 2103.15 on 2024-08-19 due to rank 474.0, realized gain: 958.4500000000116
# Sold JKPAPER at 484.0 on 2024-08-19 due to rank 246.0, realized gain: -83.0
# Sold INDIACEM at 365.95 on 2024-08-19 due to rank 219.0, realized gain: -8.0
# Sold COROMANDEL at 1773.95 on 2024-08-19 due to rank 114.0, realized gain: 2727.9000000000087
# Sold CROMPTON at 446.0 on 2024-08-19 due to rank 118.0, realized gain: 1635.4000000000015
# Sold UNOMINDA at 1165.0 on 2024-08-19 due to rank 458.0, realized gain: 7260.0
# Sold KNRCON at 343.0 on 2024-08-19 due to rank 266.0, realized gain: -2737.0
# Sold POWERINDIA at 12099.0 on 2024-08-19 due to rank 360.0, realized gain: 3264.600000000006
# Sold GLENMARK at 1582.1 on 2024-08-19 due to rank 168.0, realized gain: 5538.0
# Sold SUVENPHAR at 1002.3 on 2024-08-19 due to rank 420.0, realized gain: 3675.699999999997
# Sold VGUARD at 524.15 on 2024-08-19 due to rank 466.0, realized gain: 6512.5
# Sold SUNTV at 823.7 on 2024-08-19 due to rank 418.0, realized gain: -6400.5
# Sold GLAXO at 2969.95 on 2024-08-19 due to rank 167.0, realized gain: 1619.0
# Sold TRENT at 6575.0 on 2024-08-19 due to rank 445.0, realized gain: 3264.600000000006
# Sold OIL at 690.0 on 2024-08-19 due to rank 337.0, realized gain: 3657.5
# Sold NBCC at 183.64 on 2024-08-19 due to rank 323.0, realized gain: -70.40000000000873
# Sold CHOLAHLDNG at 1615.0 on 2024-08-19 due to rank 105.0, realized gain: 2705.4000000000015
# Sold GPIL at 995.7 on 2024-08-19 due to rank 178.0, realized gain: -5030.099999999991
# Sold SUNTECK at 596.9 on 2024-08-19 due to rank 417.0, realized gain: 1369.5
# Sold LALPATHLAB at 3310.0 on 2024-08-19 due to rank 273.0, realized gain: 3090.0
# Sold M&M at 2859.9 on 2024-08-19 due to rank 287.0, realized gain: 2768.75
# Bought COCHINSHIP on 2024-08-18 at 2206.0 no of share : 15
# Bought EMAMILTD on 2024-08-18 at 825.85 no of share : 63
# Bought SUZLON on 2024-08-18 at 80.64 no of share : 848
# Bought DEEPAKFERT on 2024-08-18 at 953.0 no of share : 53
# Bought INDIACEM on 2024-08-18 at 365.95 no of share : 162
# Bought MOTHERSON on 2024-08-18 at 187.0 no of share : 311
# Bought DIXON on 2024-08-18 at 12550.0 no of share : 5
# Bought FINCABLES on 2024-08-18 at 1456.0 no of share : 31
# Bought WHIRLPOOL on 2024-08-18 at 2103.15 no of share : 29
# Bought SUVENPHAR on 2024-08-18 at 1002.3 no of share : 55
# Bought COROMANDEL on 2024-08-18 at 1773.95 no of share : 41
# Bought OIL on 2024-08-18 at 690.0 no of share : 73
# Bought GRANULES on 2024-08-18 at 660.0 no of share : 118
# Bought UNOMINDA on 2024-08-18 at 1165.0 no of share : 44
# Bought GLENMARK on 2024-08-18 at 1582.1 no of share : 51
# Bought JKPAPER on 2024-08-18 at 484.0 no of share : 83
# Bought VGUARD on 2024-08-18 at 524.15 no of share : 120
# Bought CHOLAHLDNG on 2024-08-18 at 1615.0 no of share : 35
# Bought KNRCON on 2024-08-18 at 343.0 no of share : 117
# Bought CROMPTON on 2024-08-18 at 446.0 no of share : 146
# Bought TRENT on 2024-08-18 at 6575.0 no of share : 11
# Bought NATCOPHARM on 2024-08-18 at 1466.05 no of share : 44
# Bought GLAXO on 2024-08-18 at 2969.95 no of share : 20
# Bought OFSS on 2024-08-18 at 10969.3 no of share : 5
# Bought SUNTV on 2024-08-18 at 823.7 no of share : 81
# Bought LALPATHLAB on 2024-08-18 at 3310.0 no of share : 24
# Bought JUBLFOOD on 2024-08-18 at 645.0 no of share : 115
# Bought PRAJIND on 2024-08-18 at 714.7 no of share : 73
# Bought SUNTECK on 2024-08-18 at 596.9 no of share : 83
# 2024-08-19
# 2024-08-20
# 2024-08-21
# 2024-08-22
# 2024-08-23
# 2024-08-24
# 2024-08-25
# File positions_2024-08-25.csv already exists. Loading existing data.
# Sold COCHINSHIP at 2100.0 on 2024-08-26 due to rank 110.0, realized gain: -1590.0
# Sold EMAMILTD at 816.0 on 2024-08-26 due to rank 143.0, realized gain: -620.5500000000029
# Sold SUZLON at 79.34 on 2024-08-26 due to rank 421.0, realized gain: -1102.3999999999942
# Sold DEEPAKFERT at 1079.35 on 2024-08-26 due to rank 127.0, realized gain: 6696.549999999996
# Sold INDIACEM at 368.5 on 2024-08-26 due to rank 219.0, realized gain: 413.09999999999854
# Sold MOTHERSON at 199.4 on 2024-08-26 due to rank 310.0, realized gain: 3856.4000000000015
# Sold DIXON at 13399.0 on 2024-08-26 due to rank 132.0, realized gain: 4245.0
# Sold FINCABLES at 1482.0 on 2024-08-26 due to rank 154.0, realized gain: 806.0
# Sold WHIRLPOOL at 2054.0 on 2024-08-26 due to rank 474.0, realized gain: -1425.3500000000058
# Sold SUVENPHAR at 1079.4 on 2024-08-26 due to rank 420.0, realized gain: 4240.500000000007
# Sold COROMANDEL at 1748.5 on 2024-08-26 due to rank 114.0, realized gain: -1043.449999999997
# Sold OIL at 687.0 on 2024-08-26 due to rank 337.0, realized gain: -219.0
# Sold GRANULES at 690.1 on 2024-08-26 due to rank 180.0, realized gain: 3551.800000000003
# Sold UNOMINDA at 1126.95 on 2024-08-26 due to rank 458.0, realized gain: -1674.199999999997
# Sold GLENMARK at 1695.5 on 2024-08-26 due to rank 168.0, realized gain: 5783.400000000009
# Sold JKPAPER at 477.4 on 2024-08-26 due to rank 246.0, realized gain: -547.8000000000029
# Sold VGUARD at 471.0 on 2024-08-26 due to rank 466.0, realized gain: -6378.0
# Sold CHOLAHLDNG at 1718.0 on 2024-08-26 due to rank 105.0, realized gain: 3605.0
# Sold KNRCON at 341.4 on 2024-08-26 due to rank 266.0, realized gain: -187.20000000000437
# Sold CROMPTON at 460.5 on 2024-08-26 due to rank 118.0, realized gain: 2117.0
# Sold TRENT at 7000.0 on 2024-08-26 due to rank 445.0, realized gain: 4675.0
# Sold NATCOPHARM at 1567.7 on 2024-08-26 due to rank 319.0, realized gain: 4472.600000000006
# Sold GLAXO at 2959.0 on 2024-08-26 due to rank 167.0, realized gain: -219.0
# Sold OFSS at 11049.0 on 2024-08-26 due to rank 336.0, realized gain: 398.5
# Sold SUNTV at 777.9 on 2024-08-26 due to rank 418.0, realized gain: -3709.7999999999956
# Sold LALPATHLAB at 3302.0 on 2024-08-26 due to rank 273.0, realized gain: -192.0
# Sold JUBLFOOD at 650.25 on 2024-08-26 due to rank 251.0, realized gain: 603.75
# Sold PRAJIND at 763.0 on 2024-08-26 due to rank 362.0, realized gain: 3525.899999999994
# Sold SUNTECK at 629.55 on 2024-08-26 due to rank 417.0, realized gain: 2709.949999999997
# Bought COCHINSHIP on 2024-08-25 at 2100.0 no of share : 15
# Bought SUZLON on 2024-08-25 at 79.34 no of share : 781
# Bought DEEPAKFERT on 2024-08-25 at 1079.35 no of share : 50
# Bought INDIACEM on 2024-08-25 at 368.5 no of share : 168
# Bought EMAMILTD on 2024-08-25 at 816.0 no of share : 63
# Bought GRANULES on 2024-08-25 at 690.1 no of share : 116
# Bought SUVENPHAR on 2024-08-25 at 1079.4 no of share : 52
# Bought OIL on 2024-08-25 at 687.0 no of share : 71
# Bought MOTHERSON on 2024-08-25 at 199.4 no of share : 307
# Bought DIXON on 2024-08-25 at 13399.0 no of share : 5
# Bought GLENMARK on 2024-08-25 at 1695.5 no of share : 49
# Bought COROMANDEL on 2024-08-25 at 1748.5 no of share : 40
# Bought CHOLAHLDNG on 2024-08-25 at 1718.0 no of share : 34
# Bought WHIRLPOOL on 2024-08-25 at 2054.0 no of share : 29
# Bought OFSS on 2024-08-25 at 11049.0 no of share : 5
# Bought UNOMINDA on 2024-08-25 at 1126.95 no of share : 44
# Bought NATCOPHARM on 2024-08-25 at 1567.7 no of share : 43
# Bought PAYTM on 2024-08-25 at 559.8 no of share : 85
# Bought FSL on 2024-08-25 at 324.4 no of share : 164
# Bought VGUARD on 2024-08-25 at 471.0 no of share : 113
# Bought TRENT on 2024-08-25 at 7000.0 no of share : 11
# Bought PRAJIND on 2024-08-25 at 763.0 no of share : 71
# Bought JUBLFOOD on 2024-08-25 at 650.25 no of share : 113
# Bought KALYANKJIL on 2024-08-25 at 589.0 no of share : 88
# Bought CERA on 2024-08-25 at 9680.05 no of share : 6
# Bought LALPATHLAB on 2024-08-25 at 3302.0 no of share : 24
# Bought PERSISTENT on 2024-08-25 at 4960.0 no of share : 13
# Bought SUNTECK on 2024-08-25 at 629.55 no of share : 82
# Bought FINCABLES on 2024-08-25 at 1482.0 no of share : 32
# Bought NBCC on 2024-08-25 at 180.1 no of share : 213
# Reduced BIKAJI to 72 shares on 2024-08-25
# Reduced AFFLE to 36 shares on 2024-08-25
# Reduced BLUEDART to 7 shares on 2024-08-25
# 2024-08-26
# 2024-08-27
# 2024-08-28
# 2024-08-29
# 2024-08-30
# BDL below SMA
# Sold BDL at 1304.3 on 2024-08-31, realized gain: 31772.65

# %%
plt.figure(figsize=(20, 6))
plt.plot(dates,equity, marker='o', linestyle='-', color='b')
plt.xlabel('Date')
plt.ylabel('Equity Value')
plt.title('Equity Value Over Time')
plt.grid(True)
plt.show()

# %%
for i, j in zip(dates, equity):
    print(i, j)
# Out:
# 2023-01-01 1005272.2999999999
# 2023-01-02 1005272.2999999999
# 2023-01-03 1016472.95
# 2023-01-04 1000422.5800000001
# 2023-01-05 1000962.62
# 2023-01-06 992323.3900000002
# 2023-01-07 1004181.28
# 2023-01-08 1004389.3799999999
# 2023-01-09 1004389.3799999999
# 2023-01-10 980996.0799999998
# 2023-01-11 986515.3399999999
# 2023-01-12 992799.6799999998
# 2023-01-13 1002322.5000000001
# 2023-01-14 1009945.3099999997
# 2023-01-15 1007411.9499999998
# 2023-01-16 1007411.9499999998
# 2023-01-17 995207.5499999998
# 2023-01-18 998776.2999999998
# 2023-01-19 995619.1999999997
# 2023-01-20 997123.9999999997
# 2023-01-21 994567.8999999997
# 2023-01-22 994085.0499999993
# 2023-01-23 994085.0499999993
# 2023-01-24 984072.8499999994
# 2023-01-25 967504.6499999994
# 2023-01-26 930538.2999999993
# 2023-01-27 930538.2999999993
# 2023-01-28 940828.4499999994
# 2023-01-29 935552.6399999992
# 2023-01-30 935552.6399999992
# 2023-01-31 972293.4499999991
# 2023-02-01 930514.8699999992
# 2023-02-02 928930.5499999989
# 2023-02-03 923640.8399999992
# 2023-02-04 922471.059999999
# 2023-02-05 922911.1599999991
# 2023-02-06 922911.1599999991
# 2023-02-07 918297.6199999994
# 2023-02-08 929332.2399999991
# 2023-02-09 924942.1399999992
# 2023-02-10 923644.4699999993
# 2023-02-11 904563.9399999991
# 2023-02-12 906434.9799999992
# 2023-02-13 906434.9799999992
# 2023-02-14 900405.4499999989
# 2023-02-15 911434.8099999989
# 2023-02-16 912708.759999999
# 2023-02-17 907607.299999999
# 2023-02-18 900709.0799999989
# 2023-02-19 902072.449999999
# 2023-02-20 902072.449999999
# 2023-02-21 897051.2699999989
# 2023-02-22 877712.8199999989
# 2023-02-23 886367.4599999989
# 2023-02-24 889653.8899999988
# 2023-02-25 867775.829999999
# 2023-02-26 887914.899999999
# 2023-02-27 887914.899999999
# 2023-02-28 887914.899999999
# 2023-03-01 887914.899999999
# 2023-03-02 887914.899999999
# 2023-03-03 887914.899999999
# 2023-03-04 887914.899999999
# 2023-03-05 887914.899999999
# 2023-03-06 887914.899999999
# 2023-03-07 887914.899999999
# 2023-03-08 887914.899999999
# 2023-03-09 887914.899999999
# 2023-03-10 887914.899999999
# 2023-03-11 887914.899999999
# 2023-03-12 887914.899999999
# 2023-03-13 887914.899999999
# 2023-03-14 887914.899999999
# 2023-03-15 887914.899999999
# 2023-03-16 887914.899999999
# 2023-03-17 887914.899999999
# 2023-03-18 887914.899999999
# 2023-03-19 887914.899999999
# 2023-03-20 887914.899999999
# 2023-03-21 887914.899999999
# 2023-03-22 887914.899999999
# 2023-03-23 887914.899999999
# 2023-03-24 887914.899999999
# 2023-03-25 887914.899999999
# 2023-03-26 887914.899999999
# 2023-03-27 887914.899999999
# 2023-03-28 887914.899999999
# 2023-03-29 887914.899999999
# 2023-03-30 887914.899999999
# 2023-03-31 887914.899999999
# 2023-04-01 887914.899999999
# 2023-04-02 887914.899999999
# 2023-04-03 887914.899999999
# 2023-04-04 887914.899999999
# 2023-04-05 887914.899999999
# 2023-04-06 887914.899999999
# 2023-04-07 887914.899999999
# 2023-04-08 887914.899999999
# 2023-04-09 887914.899999999
# 2023-04-10 887914.899999999
# 2023-04-11 887914.899999999
# 2023-04-12 887914.899999999
# 2023-04-13 887914.899999999
# 2023-04-14 887914.899999999
# 2023-04-15 887914.899999999
# 2023-04-16 887914.899999999
# 2023-04-17 887914.899999999
# 2023-04-18 887914.899999999
# 2023-04-19 887914.899999999
# 2023-04-20 887914.899999999
# 2023-04-21 887914.899999999
# 2023-04-22 887914.899999999
# 2023-04-23 887914.899999999
# 2023-04-24 887914.899999999
# 2023-04-25 887914.899999999
# 2023-04-26 887914.899999999
# 2023-04-27 887914.899999999
# 2023-04-28 887914.899999999
# 2023-04-29 887914.899999999
# 2023-04-30 890166.5199999989
# 2023-05-01 890166.5199999989
# 2023-05-02 890166.5199999989
# 2023-05-03 896483.7699999991
# 2023-05-04 903384.269999999
# 2023-05-05 902034.3699999987
# 2023-05-06 906607.699999999
# 2023-05-07 910177.249999999
# 2023-05-08 910177.249999999
# 2023-05-09 901588.399999999
# 2023-05-10 913785.899999999
# 2023-05-11 915208.4999999991
# 2023-05-12 921375.549999999
# 2023-05-13 937925.399999999
# 2023-05-14 938069.839999999
# 2023-05-15 938069.839999999
# 2023-05-16 928739.3699999991
# 2023-05-17 929163.109999999
# 2023-05-18 926364.239999999
# 2023-05-19 927111.889999999
# 2023-05-20 940454.259999999
# 2023-05-21 944597.069999999
# 2023-05-22 944597.069999999
# 2023-05-23 942187.469999999
# 2023-05-24 941489.2199999992
# 2023-05-25 943944.3699999991
# 2023-05-26 951739.219999999
# 2023-05-27 942787.0699999991
# 2023-05-28 943317.619999999
# 2023-05-29 943317.619999999
# 2023-05-30 949920.0399999991
# 2023-05-31 970625.2899999991
# 2023-06-01 978423.4899999992
# 2023-06-02 995720.569999999
# 2023-06-03 989961.2199999989
# 2023-06-04 989918.0199999987
# 2023-06-05 989918.0199999987
# 2023-06-06 990699.1199999988
# 2023-06-07 1004621.169999999
# 2023-06-08 1001822.789999999
# 2023-06-09 1010008.239999999
# 2023-06-10 1012415.1399999991
# 2023-06-11 1014347.9699999992
# 2023-06-12 1014347.9699999992
# 2023-06-13 1027506.619999999
# 2023-06-14 1023295.4199999992
# 2023-06-15 1024838.1199999992
# 2023-06-16 1031452.2199999992
# 2023-06-17 1037788.9199999991
# 2023-06-18 1040396.4699999992
# 2023-06-19 1040396.4699999992
# 2023-06-20 1046348.3699999992
# 2023-06-21 1045617.3699999991
# 2023-06-22 1034057.319999999
# 2023-06-23 1018079.7699999991
# 2023-06-24 1043891.1699999992
# 2023-06-25 1041118.1699999992
# 2023-06-26 1041118.1699999992
# 2023-06-27 1055771.3699999992
# 2023-06-28 1068904.2699999989
# 2023-06-29 1070091.8699999994
# 2023-06-30 1070091.8699999994
# 2023-07-01 1068578.9199999992
# 2023-07-02 1070844.9699999993
# 2023-07-03 1070844.9699999993
# 2023-07-04 1075374.1199999992
# 2023-07-05 1088247.7199999993
# 2023-07-06 1097439.8699999992
# 2023-07-07 1102841.7199999993
# 2023-07-08 1089930.8699999992
# 2023-07-09 1096212.0699999994
# 2023-07-10 1096212.0699999994
# 2023-07-11 1109360.6199999992
# 2023-07-12 1117291.3199999991
# 2023-07-13 1107643.5699999991
# 2023-07-14 1125852.9699999993
# 2023-07-15 1137700.0699999994
# 2023-07-16 1133343.3699999992
# 2023-07-17 1133343.3699999992
# 2023-07-18 1130742.7599999993
# 2023-07-19 1149656.8099999994
# 2023-07-20 1158495.8899999994
# 2023-07-21 1173898.6399999994
# 2023-07-22 1187713.1299999994
# 2023-07-23 1183635.1999999995
# 2023-07-24 1183635.1999999995
# 2023-07-25 1192923.2599999995
# 2023-07-26 1209701.0299999993
# 2023-07-27 1215803.7099999995
# 2023-07-28 1192050.1299999994
# 2023-07-29 1212986.1699999995
# 2023-07-30 1212349.2299999997
# 2023-07-31 1212349.2299999997
# 2023-08-01 1221004.9799999995
# 2023-08-02 1194630.2799999996
# 2023-08-03 1212671.1599999997
# 2023-08-04 1216180.1099999999
# 2023-08-05 1229657.0599999996
# 2023-08-06 1231733.7099999995
# 2023-08-07 1231733.7099999995
# 2023-08-08 1237677.4299999992
# 2023-08-09 1248218.3099999994
# 2023-08-10 1241037.6999999995
# 2023-08-11 1242999.8899999994
# 2023-08-12 1251408.6299999994
# 2023-08-13 1251593.4299999995
# 2023-08-14 1251593.4299999995
# 2023-08-15 1274011.5699999996
# 2023-08-16 1274011.5699999996
# 2023-08-17 1276293.8199999996
# 2023-08-18 1275965.6399999994
# 2023-08-19 1302417.5099999995
# 2023-08-20 1302683.2499999993
# 2023-08-21 1302683.2499999993
# 2023-08-22 1328853.6999999997
# 2023-08-23 1328222.7599999998
# 2023-08-24 1334361.6099999994
# 2023-08-25 1331843.4299999997
# 2023-08-26 1339992.9999999995
# 2023-08-27 1342083.9699999995
# 2023-08-28 1342083.9699999995
# 2023-08-29 1339631.0399999998
# 2023-08-30 1346562.0499999996
# 2023-08-31 1373375.6699999995
# 2023-09-01 1385610.7099999997
# 2023-09-02 1401918.2999999998
# 2023-09-03 1404455.2699999998
# 2023-09-04 1404455.2699999998
# 2023-09-05 1403246.7699999998
# 2023-09-06 1394223.2199999997
# 2023-09-07 1398771.4099999997
# 2023-09-08 1416654.6199999996
# 2023-09-09 1445231.22
# 2023-09-10 1444895.31
# 2023-09-11 1447663.61
# 2023-09-12 1376477.4599999997
# 2023-09-13 1381371.4099999997
# 2023-09-14 1395337.53
# 2023-09-15 1405900.6599999997
# 2023-09-16 1399203.8599999996
# 2023-09-17 1398848.7800000003
# 2023-09-18 1398848.7800000003
# 2023-09-19 1391727.98
# 2023-09-20 1391727.98
# 2023-09-21 1384543.6099999999
# 2023-09-22 1382456.17
# 2023-09-23 1389452.4199999997
# 2023-09-24 1388342.7199999997
# 2023-09-25 1388342.7199999997
# 2023-09-26 1404241.1699999997
# 2023-09-27 1423025.52
# 2023-09-28 1423637.22
# 2023-09-29 1428744.1699999997
# 2023-09-30 1441762.5199999998
# 2023-10-01 1447353.72
# 2023-10-02 1447353.72
# 2023-10-03 1447353.72
# 2023-10-04 1435573.0699999996
# 2023-10-05 1433439.6699999997
# 2023-10-06 1460744.5699999998
# 2023-10-07 1423528.9199999997
# 2023-10-08 1421196.17
# 2023-10-09 1421196.17
# 2023-10-10 1450772.8699999996
# 2023-10-11 1461934.3699999999
# 2023-10-12 1466114.0199999998
# 2023-10-13 1466535.27
# 2023-10-14 1464635.2200000004
# 2023-10-15 1464609.1199999996
# 2023-10-16 1464609.1199999996
# 2023-10-17 1482205.3199999998
# 2023-10-18 1475958.77
# 2023-10-19 1481723.32
# 2023-10-20 1471903.3699999999
# 2023-10-21 1407819.6199999996
# 2023-10-22 1407392.1699999997
# 2023-10-23 1407392.1699999997
# 2023-10-24 1396824.4200000002
# 2023-10-25 1396824.4200000002
# 2023-10-26 1401317.22
# 2023-10-27 1431111.3699999996
# 2023-10-28 1443475.0699999994
# 2023-10-29 1442764.77
# 2023-10-30 1442764.77
# 2023-10-31 1449317.0699999998
# 2023-11-01 1457277.6699999997
# 2023-11-02 1473864.27
# 2023-11-03 1486222.3199999996
# 2023-11-04 1511480.3699999999
# 2023-11-05 1508463.6699999997
# 2023-11-06 1508463.6699999997
# 2023-11-07 1530365.6199999994
# 2023-11-08 1537770.7699999998
# 2023-11-09 1535984.2699999998
# 2023-11-10 1553628.17
# 2023-11-11 1576401.8699999999
# 2023-11-12 1581335.8699999996
# 2023-11-13 1597845.1199999992
# 2023-11-14 1618974.6199999999
# 2023-11-15 1618974.6199999999
# 2023-11-16 1627272.92
# 2023-11-17 1654840.6699999992
# 2023-11-18 1652325.569999999
# 2023-11-19 1652411.3699999994
# 2023-11-20 1652411.3699999994
# 2023-11-21 1645761.5199999993
# 2023-11-22 1636092.6699999995
# 2023-11-23 1643172.6699999997
# 2023-11-24 1647662.5199999996
# 2023-11-25 1670543.1199999992
# 2023-11-26 1675416.27
# 2023-11-27 1675416.27
# 2023-11-28 1675416.27
# 2023-11-29 1672252.4900000002
# 2023-11-30 1703435.0299999998
# 2023-12-01 1715093.5000000002
# 2023-12-02 1748561.4099999997
# 2023-12-03 1747211.62
# 2023-12-04 1747211.62
# 2023-12-05 1759603.4699999997
# 2023-12-06 1759381.7999999998
# 2023-12-07 1764334.9599999995
# 2023-12-08 1759291.67
# 2023-12-09 1768118.0099999998
# 2023-12-10 1764970.4800000004
# 2023-12-11 1764970.4800000004
# 2023-12-12 1746194.5
# 2023-12-13 1770257.49
# 2023-12-14 1797948.5699999994
# 2023-12-15 1796338.4300000002
# 2023-12-16 1795743.7600000005
# 2023-12-17 1794076.01
# 2023-12-18 1794076.01
# 2023-12-19 1795865.7500000005
# 2023-12-20 1725164.3100000003
# 2023-12-21 1760871.3200000003
# 2023-12-22 1774671.69
# 2023-12-23 1785125.0899999996
# 2023-12-24 1785401.7900000003
# 2023-12-25 1785401.7900000003
# 2023-12-26 1785401.7900000003
# 2023-12-27 1792317.8500000008
# 2023-12-28 1802684.0199999998
# 2023-12-29 1821444.3399999999
# 2023-12-30 1842943.4200000002
# 2023-12-31 1838790.1300000004
# 2024-01-01 1838790.1300000004
# 2024-01-02 1840076.18
# 2024-01-03 1857297.2500000005
# 2024-01-04 1889735.3100000005
# 2024-01-05 1895673.0300000003
# 2024-01-06 1886300.8900000004
# 2024-01-07 1889771.9099999995
# 2024-01-08 1889771.9099999995
# 2024-01-09 1899014.4099999997
# 2024-01-10 1897079.4699999997
# 2024-01-11 1924313.4599999997
# 2024-01-12 1929066.47
# 2024-01-13 1935334.51
# 2024-01-14 1936371.3699999999
# 2024-01-15 1936371.3699999999
# 2024-01-16 1914871.1099999999
# 2024-01-17 1905905.8299999996
# 2024-01-18 1922189.2899999996
# 2024-01-19 1957102.54
# 2024-01-20 1963665.1500000001
# 2024-01-21 1879863.3199999994
# 2024-01-22 1879863.3199999994
# 2024-01-23 1879863.3199999994
# 2024-01-24 1939349.7599999995
# 2024-01-25 1963330.8599999994
# 2024-01-26 2002787.0599999996
# 2024-01-27 2002787.0599999996
# 2024-01-28 2008803.0699999996
# 2024-01-29 2008803.0699999996
# 2024-01-30 2014082.4599999997
# 2024-01-31 2037155.84
# 2024-02-01 2035065.37
# 2024-02-02 2083633.7199999997
# 2024-02-03 2098905.18
# 2024-02-04 2097469.79
# 2024-02-05 2097469.79
# 2024-02-06 2115552.1600000006
# 2024-02-07 2128215.69
# 2024-02-08 2160760.28
# 2024-02-09 2094314.6600000001
# 2024-02-10 1970229.13
# 2024-02-11 1966646.0500000003
# 2024-02-12 1964789.6500000004
# 2024-02-13 1986691.0800000005
# 2024-02-14 2043568.5
# 2024-02-15 2093693.3400000008
# 2024-02-16 2111077.790000001
# 2024-02-17 2141907.7600000007
# 2024-02-18 2143205.9700000007
# 2024-02-19 2141462.2200000007
# 2024-02-20 2127243.6800000006
# 2024-02-21 2087462.5600000003
# 2024-02-22 2108964.9400000004
# 2024-02-23 2116017.6600000006
# 2024-02-24 2103364.8900000006
# 2024-02-25 2102952.490000001
# 2024-02-26 2102952.490000001
# 2024-02-27 2101320.7200000007
# 2024-02-28 2052541.7700000005
# 2024-02-29 2070562.000000001
# 2024-03-01 2103500.080000001
# 2024-03-02 2121455.030000001
# 2024-03-03 2120297.4500000007
# 2024-03-04 2120297.4500000007
# 2024-03-05 2131737.270000001
# 2024-03-06 2090690.9600000007
# 2024-03-07 2090826.0500000003
# 2024-03-08 2045784.310000001
# 2024-03-09 2045784.310000001
# 2024-03-10 2047301.2400000012
# 2024-03-11 2047301.2400000012
# 2024-03-12 1990887.4700000011
# 2024-03-13 1858036.7000000007
# 2024-03-14 1938318.6300000008
# 2024-03-15 1916892.580000001
# 2024-03-16 1907231.3800000013
# 2024-03-17 1910799.5000000007
# 2024-03-18 1910799.5000000007
# 2024-03-19 1877009.3000000005
# 2024-03-20 1880132.840000001
# 2024-03-21 1941231.9800000002
# 2024-03-22 1957706.4800000002
# 2024-03-23 1970495.81
# 2024-03-24 1973713.3800000004
# 2024-03-25 1973713.3800000004
# 2024-03-26 1973713.3800000004
# 2024-03-27 1980788.0399999998
# 2024-03-28 2000305.0
# 2024-03-29 2041996.91
# 2024-03-30 2041996.91
# 2024-03-31 2033300.1400000004
# 2024-04-01 2033300.1400000004
# 2024-04-02 2059579.5000000002
# 2024-04-03 2071852.2300000002
# 2024-04-04 2071172.54
# 2024-04-05 2083231.06
# 2024-04-06 2081555.97
# 2024-04-07 2084984.2299999993
# 2024-04-08 2084984.2299999993
# 2024-04-09 2080413.8099999996
# 2024-04-10 2086565.87
# 2024-04-11 2068561.7999999998
# 2024-04-12 2068561.7999999998
# 2024-04-13 2045708.7999999998
# 2024-04-14 2041947.2699999996
# 2024-04-15 2041947.2699999996
# 2024-04-16 2048706.0399999996
# 2024-04-17 2047787.0999999994
# 2024-04-18 2047787.0999999994
# 2024-04-19 2045032.0299999996
# 2024-04-20 2062251.4499999997
# 2024-04-21 2065870.05
# 2024-04-22 2065870.05
# 2024-04-23 2072327.7899999998
# 2024-04-24 2078601.2799999996
# 2024-04-25 2107253.8
# 2024-04-26 2110158.33
# 2024-04-27 2123798.14
# 2024-04-28 2121594.3299999996
# 2024-04-29 2121594.3299999996
# 2024-04-30 2139912.2599999993
# 2024-05-01 2160433.599999999
# 2024-05-02 2160433.599999999
# 2024-05-03 2157423.0399999996
# 2024-05-04 2131669.08
# 2024-05-05 2131040.7499999995
# 2024-05-06 2131040.7499999995
# 2024-05-07 2080493.9099999997
# 2024-05-08 2100336.4599999995
# 2024-05-09 2058585.1
# 2024-05-10 2074791.2599999998
# 2024-05-11 2097308.05
# 2024-05-12 2092041.19
# 2024-05-13 2092041.19
# 2024-05-14 2139696.7399999998
# 2024-05-15 2167614.749999999
# 2024-05-16 2205317.8999999994
# 2024-05-17 2252566.009999999
# 2024-05-18 2287371.079999999
# 2024-05-19 2324440.7199999993
# 2024-05-20 2324440.7199999993
# 2024-05-21 2327724.8199999994
# 2024-05-22 2312016.309999999
# 2024-05-23 2333171.92
# 2024-05-24 2333361.4199999995
# 2024-05-25 2326103.749999999
# 2024-05-26 2321662.0699999994
# 2024-05-27 2321662.0699999994
# 2024-05-28 2288034.0199999986
# 2024-05-29 2291854.869999999
# 2024-05-30 2271972.7199999993
# 2024-05-31 2296600.119999999
# 2024-06-01 2377739.5699999984
# 2024-06-02 2381651.3699999987
# 2024-06-03 2381651.3699999987
# 2024-06-04 2156386.669999999
# 2024-06-05 2193730.269999999
# 2024-06-06 2225483.8699999987
# 2024-06-07 2245965.7199999993
# 2024-06-08 2246630.3199999994
# 2024-06-09 2249700.9799999986
# 2024-06-10 2249700.9799999986
# 2024-06-11 2261378.5099999984
# 2024-06-12 2277285.3699999987
# 2024-06-13 2306828.6299999985
# 2024-06-14 2336910.309999998
# 2024-06-15 2357485.509999998
# 2024-06-16 2359244.509999999
# 2024-06-17 2359244.509999999
# 2024-06-18 2359244.509999999
# 2024-06-19 2326263.399999999
# 2024-06-20 2328358.569999999
# 2024-06-21 2327968.499999998
# 2024-06-22 2342943.449999999
# 2024-06-23 2345384.1499999994
# 2024-06-24 2345384.1499999994
# 2024-06-25 2353609.909999999
# 2024-06-26 2346392.609999999
# 2024-06-27 2341659.789999999
# 2024-06-28 2337199.2199999993
# 2024-06-29 2362060.4699999997
# 2024-06-30 2362943.159999999
# 2024-07-01 2362943.159999999
# 2024-07-02 2356215.9699999993
# 2024-07-03 2375561.3999999994
# 2024-07-04 2390853.19
# 2024-07-05 2407820.7399999998
# 2024-07-06 2383473.6799999997
# 2024-07-07 2389586.2799999984
# 2024-07-08 2389586.2799999984
# 2024-07-09 2389202.3099999996
# 2024-07-10 2359176.259999999
# 2024-07-11 2331558.129999999
# 2024-07-12 2314890.809999999
# 2024-07-13 2329934.3199999994
# 2024-07-14 2323956.9699999997
# 2024-07-15 2323956.9699999997
# 2024-07-16 2337934.629999999
# 2024-07-17 2308456.3299999996
# 2024-07-18 2308456.3299999996
# 2024-07-19 2240521.9299999997
# 2024-07-20 2252028.6399999983
# 2024-07-21 2262458.1599999983
# 2024-07-22 2262458.1599999983
# 2024-07-23 2251090.449999999
# 2024-07-24 2266708.589999999
# 2024-07-25 2253405.029999999
# 2024-07-26 2288448.7999999984
# 2024-07-27 2328236.5899999994
# 2024-07-28 2332453.1699999995
# 2024-07-29 2332453.1699999995
# 2024-07-30 2343374.099999999
# 2024-07-31 2344605.319999999
# 2024-08-01 2319209.779999999
# 2024-08-02 2293536.579999999
# 2024-08-03 2205801.9899999993
# 2024-08-04 2207757.9599999995
# 2024-08-05 2207757.9599999995
# 2024-08-06 2201514.059999999
# 2024-08-07 2254901.349999998
# 2024-08-08 2255414.0199999986
# 2024-08-09 2295061.649999999
# 2024-08-10 2299266.189999999
# 2024-08-11 2298013.229999999
# 2024-08-12 2298013.229999999
# 2024-08-13 2276421.549999999
# 2024-08-14 2266445.3399999985
# 2024-08-15 2311476.989999999
# 2024-08-16 2311476.989999999
# 2024-08-17 2317463.6599999988
# 2024-08-18 2320527.4899999993
# 2024-08-19 2320527.4899999993
# 2024-08-20 2320638.929999999
# 2024-08-21 2349677.909999999
# 2024-08-22 2353975.429999999
# 2024-08-23 2361801.919999999
# 2024-08-24 2367286.6799999992
# 2024-08-25 2365733.0299999984
# 2024-08-26 2365733.0299999984
# 2024-08-27 2363272.249999998
# 2024-08-28 2368967.789999999
# 2024-08-29 2355326.479999998
# 2024-08-30 2370415.7699999986
