# %%
import pandas as pd
from datetime import datetime
import yfinance as yf
from scipy.stats import linregress
import numpy as np
import ta
import os
import matplotlib.pyplot as plt

# %%
#get circuit limit data for stocks 
circuit_limit = pd.read_csv("F:\\Bot\\MomentumStrategy\\nifty500_price_bands.csv")
circuit_limit['stock_name'] = circuit_limit['stock_name'].str.strip()
print(circuit_limit.columns)
# Out:
# Index(['stock_name', 'price_band'], dtype='object')

# %%
def exponential_regression(x, y):
    #log of closing price
    log_y = np.log(y)

    #get slope, and r_value
    slope, intercept, r_value, _, _ = linregress(x, log_y)

    '''
    r**2 -> coefficient of determinent
    ranges from 0 - 1
    ''' 
    return slope, intercept, r_value**2

# %%
def annualize_return(daily_slope):
    return ((np.exp(daily_slope) ** 250) - 1) * 100

# %%
def calculate_adjusted_return(df, ticker):
    '''
    returns -> list [ticker, slope, annualized_return, adjusted return]
    '''

    #getting last 90 days data
    x = np.arange(90)                   #list from 0-89
    y = df['close'].iloc[-90:].values   #last 90 closing prices


    slope, intercept, r2 = exponential_regression(x, y)
    annualized_return = annualize_return(slope)
    
    adjusted_return = annualized_return * r2
    

    return [ticker, slope, annualized_return, adjusted_return]

# %%
def check_circuits(df, upper_circuit=20, lower_circuit=20):
    '''
    hit -> if circuit was hit in the last 90 days
    freq -> frequency of circuit hits 
    '''

    hit = False
    freq = 0
    upper_circuit = int(upper_circuit) - 0.01
    lower_circuit = int(lower_circuit) - 0.01

    # Filtering the last 90 days data
    days_90 = df.iloc[-90:, :].copy()

    # Calculate the upper and lower circuit levels
    days_90.loc[:, 'upper_circuit'] = days_90['close'].shift(1) * (1 + upper_circuit / 100)
    days_90.loc[:, 'lower_circuit'] = days_90['close'].shift(1) * (1 - lower_circuit / 100)

    # Initialize the circuit columns 
    days_90['Hit Upper Circuit'] = False
    days_90['Hit Lower Circuit'] = False

    # Explicitly cast columns to bool dtype
    days_90['Hit Upper Circuit'] = days_90['Hit Upper Circuit'].astype(bool)
    days_90['Hit Lower Circuit'] = days_90['Hit Lower Circuit'].astype(bool)

   
    days_90.loc[days_90['high'] >= days_90['upper_circuit'], 'Hit Upper Circuit'] = True    
    days_90.loc[days_90['low'] <= days_90['lower_circuit'], 'Hit Lower Circuit'] = True

    # Count the number of hits for both upper and lower circuits
    upper_circuit_hits = days_90['Hit Upper Circuit'].sum()
    lower_circuit_hits = days_90['Hit Lower Circuit'].sum()
    freq = upper_circuit_hits + lower_circuit_hits

    # Determine if there were any hits
    if freq > 0:
        hit = True

    return hit, freq

# %%
def check_circuits_on_full_df(df, upper_circuit=20, lower_circuit=20):
    
    '''function only for simulation

    Returns two new columns:
    - circuit_hit_90d`: True/False if a circuit was hit in the last 90 days.
    - circuit_freq_90d`: The frequency of circuit hits in the last 90 days.'''
    
    circuit_hit_90d = []
    circuit_freq_90d = []

    for i in range(len(df)):
        if i < 90:
            # If we have less than 90 rows, use what we have
            sub_df = df.iloc[:i+1]
        else:
            # Otherwise, use the last 90 rows
            sub_df = df.iloc[i-89:i+1]

        hit, freq = check_circuits(sub_df, upper_circuit, lower_circuit)
        circuit_hit_90d.append(hit)
        circuit_freq_90d.append(freq)

    df['circuit_hit_90d'] = circuit_hit_90d
    df['circuit_freq_90d'] = circuit_freq_90d

    return df

# %%
def calculate_atr(df, window=14):
    atr = ta.volatility.AverageTrueRange(df['high'], df['low'], df['close'], window=window)
    # Calculate RMA manually
    rma_atr = atr.average_true_range().ewm(alpha=1/window, min_periods=window, adjust=False).mean()
    return rma_atr

# %%
def get_sma(df, window = 200):
    df.columns = [i.lower() for i in df.columns]
    #SMA calcluation
    df['sma_' + str(window)] = ta.trend.sma_indicator(df['close'], window=window)
    df['sma_' + str(window)+'_above'] = df['close'] > df['sma_' + str(window)] 
    return df

# %%
nifty500_data = pd.read_csv('F:\\Bot\\MomentumStrategy\\nifty500_data.csv')
nifty500_data.columns = [i.strip().lower() for i in nifty500_data.columns]
nifty500_data['date'] = pd.to_datetime(nifty500_data['date'], format='%d-%b-%y').dt.date
nifty500_data = get_sma(nifty500_data)


nifty50_data = pd.read_csv('F:\\Bot\\MomentumStrategy\\nifty50_data.csv')
nifty50_data.columns = [i.strip().lower() for i in nifty50_data.columns]
nifty50_data['date'] = pd.to_datetime(nifty50_data['date'], format='%d-%b-%y').dt.date
nifty50_data = get_sma(nifty50_data)


nifty500_stocks = pd.read_csv('F:\\Bot\\csv_files\\nifty500list.csv')
#filtering csv to EQ and getting only symbol column
nifty500_stocks = nifty500_stocks.loc[nifty500_stocks['Series'] == 'EQ', 'Symbol']
print(nifty500_data.shape, nifty500_stocks.shape, nifty50_data.shape)
# Out:
# (664, 9) (500,) (664, 9)

# %%
nifty500_data.tail()
# Out:
#            date      open      high       low     close  shares traded
# 659  2024-08-30  23728.55  23766.40  23673.95  23734.55   7.015025e+09  \
# 660  2024-09-02  23835.20  23835.20  23693.65  23760.70   2.522874e+09
# 661  2024-09-03  23817.00  23817.55  23771.20  23788.45   1.814622e+09
# 662  2024-09-04  23611.80  23761.40  23605.35  23748.90   2.062020e+09
# 663  2024-09-05  23821.00  23836.35  23749.05  23762.80            NaN
#
#      turnover (₹ cr)      sma_200  sma_200_above
# 659        201988.80  20717.12950           True
# 660         90696.23  20749.65000           True
# 661         88512.76  20781.78675           True
# 662         91617.99  20813.93825           True
# 663              NaN  20845.21200           True

# %%
def get_positional_data(nifty500_stocks, 
                        specific_date = datetime.today().date() - pd.Timedelta(days = 1),  
                        num_periods = 400, path = 'F:\\Bot\\data dump\\outputs\\', 
                        account_value = 1000000,
                        risk_factor = 0.002):
    
    '''
    nifty500_stocks ->  list of stock names
    specific_date   ->  extract data till previous date
    numperiods      ->  number of datapoints (days) to be extracted from csv
    path            ->  path for csv file for stock data

    returns a filtered dataframe
    
    '''
    
    main_df = pd.DataFrame(columns=['stock_name', 'prev_close', 'slope', 'annualized_return', 'adjusted_return', 'prev_sma_100_above', 'circuit_hitted', 'circuit_freq', 'prev_atr_20'])


    for i in nifty500_stocks:
        try:
            
            data = pd.read_csv(path + i + '.csv')  # readin file
            data['Date'] = pd.to_datetime(data['Date']).dt.date  #converting to datetime columns
            
            # Filter data up to the specific date
            data = data[data['Date'] <= specific_date]
            
            # Select the last 400 data points
            data = data.iloc[-num_periods:]
            

            # If less than 400 data points, continue to next stock
            if len(data) < num_periods:
                continue

        except Exception as e:
            print(e)
            continue

        
        ''' 
        getting sma and circuit is repeated data, we already have that in csv file
        remove it later on
        
        '''
        # Getting sma
        data = get_sma(data, 100)

        # Circuit hit
        
        circuit = circuit_limit.loc[circuit_limit['stock_name'] == i, 'price_band'].values[0]
        #print(i, circuit)
        if not circuit:
            hit, freq = check_circuits(data, 
                                    upper_circuit = circuit, 
                                    lower_circuit = circuit)
        else:
            hit, freq = check_circuits(data)
        
        # Getting atr
        data['atr_20'] = calculate_atr(data, 20)
        
        
        
        # Getting slope, annualized return, adjusted_return
        l = calculate_adjusted_return(data, i)
        new_row = {
            'stock_name': l[0],
            'prev_close': data['close'].iloc[-1],
            'slope': l[1],
            'annualized_return': l[2],
            'adjusted_return': l[3],
            'prev_sma_100_above': data['sma_100_above'].iloc[-1],
            'circuit_hitted': hit,
            'circuit_freq': freq,
            'prev_atr_20': data['atr_20'].iloc[-1]
        }
        
        # Adding to dataframe
        main_df.loc[len(main_df.index)] = new_row
    

    filtered_df = main_df.sort_values(by='adjusted_return', ascending=False)
    
    account_value = 1000000
    risk_factor = 0.002

    #filtering
    filtered_df['no_of_shares'] = [account_value * risk_factor]/filtered_df['prev_atr_20']
    filtered_df['no_of_shares'] = filtered_df['no_of_shares'].astype(int)
    
    

    #checking till our cumulative cash reached close to account value
    filtered_df['invested_amount'] = filtered_df['no_of_shares'] * filtered_df['prev_close']
    filtered_df['cumulative_invested_amount'] = filtered_df['invested_amount'].cumsum()

    
    return filtered_df

# %%
def get_and_save_positional_data(nifty500_stocks, specific_date):
    # Define the filename based on the specific date
    filename = f"positions_{specific_date}.csv"
    filepath = os.path.join("F:\Bot\MomentumStrategy\positionalData", filename)

    # Check if the file already exists
    if os.path.exists(filepath):
        print(f"File {filename} already exists. Loading existing data.")
        position_data = pd.read_csv(filepath)
    else:
        # Generate the positional data
        position_data = get_positional_data(nifty500_stocks, specific_date)
        
        # Save to CSV
        position_data.to_csv(filepath, index=False)
        print(f"Positional data saved to {filename}.")

    return position_data

# %%
def preprocess(df, stock_name):
    #getting circuits
    circuit = circuit_limit.loc[circuit_limit['stock_name'] == stock_name, 'price_band'].values[0]
    if not circuit:
            df = check_circuits_on_full_df(df, 
                                    upper_circuit = circuit, 
                                    lower_circuit = circuit)
    else:
        df = check_circuits_on_full_df(df)

    #getting sma

    df = get_sma(df, 100)
    return df

# %%
data_dict = {}

# %%
initial_cash = 1000000  # Example starting cash
risk_factor = 0.002
cash_in_hand = initial_cash
portfolio = {}

# %%
def simulate(start_date, end_date, nifty500_data):
    
    global cash_in_hand, portfolio
    
    equity = []
    dates = []

    
    current_date = start_date

    last_positional_data_date = current_date - pd.Timedelta(days = 8)

    while current_date <= end_date:
        current_nifty_500_datapoint = nifty500_data.loc[nifty500_data['date'] == current_date]
        
        if  current_nifty_500_datapoint.empty:  # 5 is Saturday, 6 is Sunday #if it was market holiday
            print(current_date, 'market holiday! or sat sun')
            current_date += pd.Timedelta(days=1)
            continue

        print(current_date)
        
        # Daily exit condition check
        stock_to_exit = []
        for stock in portfolio:
            try:
                # Load the latest data for the stock
                stock_df = data_dict[stock]
                sma_100 = stock_df.loc[stock_df['Date'] < current_date, 'sma_100_above'].values[-1]
                circuit_check = stock_df.loc[stock_df['Date'] < current_date, 'circuit_hit_90d'].values[-1]
                
                # Exit conditions
                if not sma_100:
                    print(stock, 'below SMA')
                    stock_to_exit.append(stock)
                
                elif circuit_check:
                    print(stock, 'circuit hit')

                    stock_to_exit.append(stock)
                    
            except Exception as e:
                print(f"Error checking exit conditions for {stock}: {e}")
                stock_to_exit.append(stock)
            
        # Exiting stocks and adding to cash in hand
        for stock in stock_to_exit:
            #we will sell on opening of current day
            sell_price = data_dict[stock].loc[data_dict[stock]['Date'] == current_date, 'open'].values[0] #sell on next day opening


            exit_amount = sell_price * portfolio[stock]['shares']
            cash_in_hand += exit_amount
            print(f'Sold {stock} at {sell_price} on {current_date + pd.Timedelta(days = 1)}, realized gain: {exit_amount - portfolio[stock]["invested_amount"]}')
            del portfolio[stock]

        

        #  # Check if it's time for weekly rebalancing and buying
        if (current_date - last_positional_data_date).days > 7:
            positional_data = get_and_save_positional_data(nifty500_stocks, current_date)
            last_positional_data_date = current_date

            #rank based exit
            positional_data['rank'] = positional_data['stock_name'].rank(method='first')
            for stock in list(portfolio.keys()):
                
                stock_rank = positional_data.loc[positional_data['stock_name'] == stock, 'rank'].values[0]
                if stock_rank > 75:
                    sell_price = data_dict[stock].loc[data_dict[stock]['Date'] >= current_date, 'open'].values[0] #exiting on next day opening as weekly is checked before market hours
                    exit_amount = sell_price * portfolio[stock]['shares']
                    cash_in_hand += exit_amount
                    print(f'Sold {stock} at {sell_price} on {current_date + pd.Timedelta(days=1)} due to rank {stock_rank}, realized gain: {exit_amount - portfolio[stock]["invested_amount"]}')
                    del portfolio[stock]

            # Rebalancing: Reducing shares
            for i, row in positional_data.iterrows():
                if row['stock_name'] in portfolio:
                    current_shares = portfolio[row['stock_name']]['shares']
                    new_shares = row['no_of_shares']

                    #5% conditions
                    if abs(new_shares - current_shares) / current_shares > 0.05 and current_shares > new_shares:
                        shares_to_sell = current_shares - new_shares
                        sell_price = data_dict[row['stock_name']].loc[data_dict[row['stock_name']]['Date'] >= current_date, 'open'].values[0] #sell on today
                        sell_amount = shares_to_sell * sell_price

                        portfolio[row['stock_name']]['shares'] = new_shares
                        portfolio[row['stock_name']]['invested_amount'] -= sell_amount
                        cash_in_hand += sell_amount
                        print(f'Reduced {row["stock_name"]} to {new_shares} shares on {current_date}')

            # Rebalancing: Adding shares
            for i, row in positional_data.iterrows():
                if row['stock_name'] in portfolio:
                    current_shares = portfolio[row['stock_name']]['shares']
                    new_shares = row['no_of_shares']

                    if new_shares > current_shares and abs(new_shares - current_shares) / current_shares > 0.05:
                        shares_to_buy = new_shares - current_shares
                        buy_price = data_dict[row['stock_name']].loc[data_dict[row['stock_name']]['Date'] >= current_date, 'open'].values[0]
                        buy_amount = shares_to_buy * buy_price

                        if cash_in_hand >= buy_amount:
                            portfolio[row['stock_name']]['shares'] += shares_to_buy
                            portfolio[row['stock_name']]['invested_amount'] += buy_amount
                            cash_in_hand -= buy_amount
                            print(f'Increased {row["stock_name"]} to {portfolio[row["stock_name"]]["shares"]} shares on {current_date}')

            # Buying new stocks

            for i, row in positional_data.iterrows():
                if row['stock_name'] not in portfolio:
                    if (
                        row['prev_sma_100_above'] 
                        and not row['circuit_hitted'] 
                        and row['no_of_shares'] != 0
                        and cash_in_hand > row['invested_amount'] 
                        and nifty500_data.loc[nifty500_data['date'] == current_date, 'sma_200_above'].values[-1]
                    ):
                       
                        stock_df = data_dict.get(row['stock_name'], pd.read_csv("F:\\Bot\\data dump\\outputs\\" + row['stock_name'] + '.csv'))
                        stock_df['Date'] = pd.to_datetime(stock_df['Date']).dt.date
                        data_dict[row['stock_name']] = stock_df

                        
                        current_opening_price = stock_df.loc[stock_df['Date'] == current_date, 'open'].values[0]
                        
                        portfolio[row['stock_name']] = {
                            'entry_date': current_date,
                            'shares': row['no_of_shares'],
                            'invested_amount': row['no_of_shares'] * current_opening_price
                        }
                        cash_in_hand -= portfolio[row['stock_name']]['invested_amount']
                        print(f'Bought {row["stock_name"]} on {current_date} at {current_opening_price} no of share : {row["no_of_shares"]}')
        
        # Calculating equity
        
        equity_value = sum(
            portfolio[stock]['shares'] * data_dict[stock].loc[data_dict[stock]['Date'] >= current_date, 'close'].values[0]
            for stock in portfolio
        ) + cash_in_hand
        equity.append(equity_value)
        dates.append(current_date)
        

        current_date += pd.Timedelta(days=1)

    return equity, dates

# %%
start_date = datetime(2023, 1, 2).date()
end_date = datetime(2024, 8, 30).date()
equity, dates = simulate(start_date, end_date, nifty500_data)
# Out:
# 2023-01-02
# File positions_2023-01-02.csv already exists. Loading existing data.
# Bought RVNL on 2023-01-02 at 68.25 no of share : 605
# Bought MAZDOCK on 2023-01-02 at 798.0 no of share : 49
# Bought UNIONBANK on 2023-01-02 at 80.9 no of share : 553
# Bought BANKINDIA on 2023-01-02 at 88.95 no of share : 516
# Bought J&KBANK on 2023-01-02 at 56.9 no of share : 747
# Bought GODFRYPHLP on 2023-01-02 at 1986.0 no of share : 26
# Bought MAHABANK on 2023-01-02 at 30.85 no of share : 1317
# Bought JSL on 2023-01-02 at 241.0 no of share : 249
# Bought IOB on 2023-01-02 at 32.4 no of share : 1306
# Bought CENTRALBK on 2023-01-02 at 32.4 no of share : 1195
# Bought INDIANB on 2023-01-02 at 287.0 no of share : 187
# Bought JKLAKSHMI on 2023-01-02 at 822.55 no of share : 67
# Bought PNB on 2023-01-02 at 56.8 no of share : 984
# Bought COCHINSHIP on 2023-01-02 at 265.48 no of share : 141
# Bought IRFC on 2023-01-02 at 32.7 no of share : 1535
# Bought IRCON on 2023-01-02 at 60.0 no of share : 695
# Bought GRSE on 2023-01-02 at 487.0 no of share : 77
# Bought RAYMOND on 2023-01-02 at 1475.0 no of share : 30
# Bought BLS on 2023-01-02 at 165.8 no of share : 258
# Bought IIFL on 2023-01-02 at 469.42 no of share : 117
# Bought BANKBARODA on 2023-01-02 at 186.6 no of share : 377
# 2023-01-03
# 2023-01-04
# 2023-01-05
# 2023-01-06
# 2023-01-07 market holiday! or sat sun
# 2023-01-08 market holiday! or sat sun
# 2023-01-09
# COCHINSHIP below SMA
# Sold COCHINSHIP at 252.45 on 2023-01-10, realized gain: -1837.2300000000032
# 2023-01-10
# File positions_2023-01-10.csv already exists. Loading existing data.
# Sold RVNL at 72.2 on 2023-01-11 due to rank 355.0, realized gain: 2389.75
# Sold MAZDOCK at 810.4 on 2023-01-11 due to rank 277.0, realized gain: 607.5999999999985
# Sold UNIONBANK at 81.4 on 2023-01-11 due to rank 419.0, realized gain: 276.5
# Sold J&KBANK at 56.9 on 2023-01-11 due to rank 224.0, realized gain: 0.0
# Sold GODFRYPHLP at 2112.35 on 2023-01-11 due to rank 160.0, realized gain: 3285.0999999999985
# Sold MAHABANK at 30.9 on 2023-01-11 due to rank 269.0, realized gain: 65.84999999999127
# Sold JSL at 240.55 on 2023-01-11 due to rank 233.0, realized gain: -112.04999999999563
# Sold IOB at 30.55 on 2023-01-11 due to rank 214.0, realized gain: -2416.0999999999985
# Sold CENTRALBK at 31.15 on 2023-01-11 due to rank 87.0, realized gain: -1493.75
# Sold INDIANB at 296.45 on 2023-01-11 due to rank 206.0, realized gain: 1767.1500000000015
# Sold JKLAKSHMI at 752.35 on 2023-01-11 due to rank 230.0, realized gain: -4703.399999999994
# Sold PNB at 56.9 on 2023-01-11 due to rank 323.0, realized gain: 98.40000000000146
# Sold IRFC at 32.85 on 2023-01-11 due to rank 220.0, realized gain: 230.24999999999272
# Sold IRCON at 61.55 on 2023-01-11 due to rank 218.0, realized gain: 1077.25
# Sold GRSE at 478.6 on 2023-01-11 due to rank 170.0, realized gain: -646.7999999999956
# Sold RAYMOND at 1439.65 on 2023-01-11 due to rank 342.0, realized gain: -1060.5
# Sold IIFL at 461.63 on 2023-01-11 due to rank 202.0, realized gain: -911.4300000000003
# Reduced BANKINDIA to 486 shares on 2023-01-10
# Bought RVNL on 2023-01-10 at 72.2 no of share : 594
# Bought UNIONBANK on 2023-01-10 at 81.4 no of share : 521
# Bought MAZDOCK on 2023-01-10 at 810.4 no of share : 49
# Bought J&KBANK on 2023-01-10 at 56.9 no of share : 702
# Bought GODFRYPHLP on 2023-01-10 at 2112.35 no of share : 25
# Bought JSL on 2023-01-10 at 240.55 no of share : 229
# Bought MAHABANK on 2023-01-10 at 30.9 no of share : 1224
# Bought IOB on 2023-01-10 at 30.55 no of share : 1180
# Bought CENTRALBK on 2023-01-10 at 31.15 no of share : 1120
# Bought IRFC on 2023-01-10 at 32.85 no of share : 1426
# Bought PNB on 2023-01-10 at 56.9 no of share : 951
# Bought INDIANB on 2023-01-10 at 296.45 no of share : 180
# Bought IRCON on 2023-01-10 at 61.55 no of share : 664
# Bought JKLAKSHMI on 2023-01-10 at 752.35 no of share : 65
# Bought RAYMOND on 2023-01-10 at 1439.65 no of share : 30
# Bought RBLBANK on 2023-01-10 at 185.8 no of share : 335
# Bought IIFL on 2023-01-10 at 461.63 no of share : 115
# Bought APARINDS on 2023-01-10 at 1802.0 no of share : 27
# 2023-01-11
# 2023-01-12
# 2023-01-13
# 2023-01-14 market holiday! or sat sun
# 2023-01-15 market holiday! or sat sun
# 2023-01-16
# 2023-01-17
# 2023-01-18
# File positions_2023-01-18.csv already exists. Loading existing data.
# Sold RVNL at 76.5 on 2023-01-19 due to rank 355.0, realized gain: 2554.199999999997
# Sold UNIONBANK at 81.5 on 2023-01-19 due to rank 419.0, realized gain: 52.099999999998545
# Sold MAZDOCK at 767.8 on 2023-01-19 due to rank 277.0, realized gain: -2087.4000000000015
# Sold J&KBANK at 56.2 on 2023-01-19 due to rank 224.0, realized gain: -491.3999999999942
# Sold GODFRYPHLP at 1930.0 on 2023-01-19 due to rank 160.0, realized gain: -4558.75
# Sold JSL at 244.15 on 2023-01-19 due to rank 233.0, realized gain: 824.3999999999942
# Sold MAHABANK at 32.45 on 2023-01-19 due to rank 269.0, realized gain: 1897.2000000000044
# Sold IOB at 31.45 on 2023-01-19 due to rank 214.0, realized gain: 1062.0
# Sold CENTRALBK at 32.75 on 2023-01-19 due to rank 87.0, realized gain: 1792.0
# Sold IRFC at 32.9 on 2023-01-19 due to rank 220.0, realized gain: 71.30000000000291
# Sold PNB at 57.85 on 2023-01-19 due to rank 323.0, realized gain: 903.4499999999971
# Sold INDIANB at 288.4 on 2023-01-19 due to rank 206.0, realized gain: -1449.0000000000073
# Sold IRCON at 61.15 on 2023-01-19 due to rank 218.0, realized gain: -265.59999999999854
# Sold JKLAKSHMI at 754.4 on 2023-01-19 due to rank 230.0, realized gain: 133.25
# Sold RAYMOND at 1504.9 on 2023-01-19 due to rank 342.0, realized gain: 1957.5
# Sold RBLBANK at 171.8 on 2023-01-19 due to rank 344.0, realized gain: -4690.0
# Sold IIFL at 502.39 on 2023-01-19 due to rank 202.0, realized gain: 4687.4000000000015
# Reduced BLS to 244 shares on 2023-01-18
# Bought RVNL on 2023-01-18 at 76.5 no of share : 589
# Bought J&KBANK on 2023-01-18 at 56.2 no of share : 685
# Bought UNIONBANK on 2023-01-18 at 81.5 no of share : 516
# Bought JSL on 2023-01-18 at 244.15 no of share : 220
# Bought MAHABANK on 2023-01-18 at 32.45 no of share : 1180
# Bought IOB on 2023-01-18 at 31.45 no of share : 1135
# Bought GODFRYPHLP on 2023-01-18 at 1930.0 no of share : 24
# Bought CENTRALBK on 2023-01-18 at 32.75 no of share : 1105
# Bought MAZDOCK on 2023-01-18 at 767.8 no of share : 50
# Bought IRFC on 2023-01-18 at 32.9 no of share : 1402
# Bought PNB on 2023-01-18 at 57.85 no of share : 939
# Bought IRCON on 2023-01-18 at 61.15 no of share : 658
# Bought INDIANB on 2023-01-18 at 288.4 no of share : 181
# Bought GICRE on 2023-01-18 at 179.1 no of share : 229
# Bought RBLBANK on 2023-01-18 at 171.8 no of share : 329
# Bought NIACL on 2023-01-18 at 126.05 no of share : 351
# Bought TITAGARH on 2023-01-18 at 216.45 no of share : 211
# Bought RCF on 2023-01-18 at 125.8 no of share : 319
# 2023-01-19
# 2023-01-20
# 2023-01-21 market holiday! or sat sun
# 2023-01-22 market holiday! or sat sun
# 2023-01-23
# 2023-01-24
# 2023-01-25
# 2023-01-26 market holiday! or sat sun
# 2023-01-27
# File positions_2023-01-27.csv already exists. Loading existing data.
# Sold RVNL at 76.5 on 2023-01-28 due to rank 354.0, realized gain: 0.0
# Sold J&KBANK at 56.35 on 2023-01-28 due to rank 223.0, realized gain: 102.75
# Sold UNIONBANK at 78.45 on 2023-01-28 due to rank 418.0, realized gain: -1573.7999999999956
# Sold JSL at 256.5 on 2023-01-28 due to rank 232.0, realized gain: 2717.0
# Sold MAHABANK at 29.55 on 2023-01-28 due to rank 268.0, realized gain: -3422.0
# Sold IOB at 28.7 on 2023-01-28 due to rank 213.0, realized gain: -3121.25
# Sold GODFRYPHLP at 1982.95 on 2023-01-28 due to rank 159.0, realized gain: 1270.800000000003
# Sold CENTRALBK at 29.85 on 2023-01-28 due to rank 87.0, realized gain: -3204.5
# Sold MAZDOCK at 741.75 on 2023-01-28 due to rank 276.0, realized gain: -1302.5
# Sold IRFC at 32.15 on 2023-01-28 due to rank 219.0, realized gain: -1051.5
# Sold PNB at 53.75 on 2023-01-28 due to rank 322.0, realized gain: -3849.9000000000015
# Sold IRCON at 58.1 on 2023-01-28 due to rank 217.0, realized gain: -2006.8999999999942
# Sold INDIANB at 293.5 on 2023-01-28 due to rank 205.0, realized gain: 923.1000000000058
# Sold GICRE at 176.6 on 2023-01-28 due to rank 150.0, realized gain: -572.5
# Sold RBLBANK at 158.05 on 2023-01-28 due to rank 343.0, realized gain: -4523.75
# Sold NIACL at 121.3 on 2023-01-28 due to rank 302.0, realized gain: -1667.25
# Sold TITAGARH at 223.25 on 2023-01-28 due to rank 403.0, realized gain: 1434.800000000003
# Sold RCF at 119.0 on 2023-01-28 due to rank 344.0, realized gain: -2169.199999999997
# Bought RVNL on 2023-01-27 at 76.5 no of share : 591
# Bought JSL on 2023-01-27 at 256.5 no of share : 214
# Bought J&KBANK on 2023-01-27 at 56.35 no of share : 690
# Bought UNIONBANK on 2023-01-27 at 78.45 no of share : 524
# Bought IOB on 2023-01-27 at 28.7 no of share : 1131
# Bought MAHABANK on 2023-01-27 at 29.55 no of share : 1178
# Bought CENTRALBK on 2023-01-27 at 29.85 no of share : 1128
# Bought GODFRYPHLP on 2023-01-27 at 1982.95 no of share : 23
# Bought IRFC on 2023-01-27 at 32.15 no of share : 1416
# Bought SWANENERGY on 2023-01-27 at 355.8 no of share : 141
# Bought PNB on 2023-01-27 at 53.75 no of share : 944
# Bought GICRE on 2023-01-27 at 176.6 no of share : 223
# Bought NIACL on 2023-01-27 at 121.3 no of share : 348
# Bought TITAGARH on 2023-01-27 at 223.25 no of share : 210
# Bought GPIL on 2023-01-27 at 392.0 no of share : 129
# Bought IRCON on 2023-01-27 at 58.1 no of share : 667
# Bought RBLBANK on 2023-01-27 at 158.05 no of share : 326
# 2023-01-28 market holiday! or sat sun
# 2023-01-29 market holiday! or sat sun
# 2023-01-30
# BANKBARODA below SMA
# APARINDS below SMA
# Sold BANKBARODA at 158.1 on 2023-01-31, realized gain: -10744.5
# Sold APARINDS at 1440.0 on 2023-01-31, realized gain: -9774.0
# 2023-01-31
# 2023-02-01
# 2023-02-02
# 2023-02-03
# 2023-02-04 market holiday! or sat sun
# 2023-02-05 market holiday! or sat sun
# 2023-02-06
# File positions_2023-02-06.csv already exists. Loading existing data.
# Sold RVNL at 72.75 on 2023-02-07 due to rank 356.0, realized gain: -2216.25
# Sold JSL at 266.25 on 2023-02-07 due to rank 233.0, realized gain: 2086.5
# Sold J&KBANK at 52.75 on 2023-02-07 due to rank 224.0, realized gain: -2484.0
# Sold UNIONBANK at 74.3 on 2023-02-07 due to rank 422.0, realized gain: -2174.600000000006
# Sold IOB at 26.75 on 2023-02-07 due to rank 214.0, realized gain: -2205.4500000000007
# Sold MAHABANK at 28.85 on 2023-02-07 due to rank 270.0, realized gain: -824.5999999999985
# Sold CENTRALBK at 28.0 on 2023-02-07 due to rank 87.0, realized gain: -2086.800000000003
# Sold GODFRYPHLP at 1827.0 on 2023-02-07 due to rank 160.0, realized gain: -3586.8499999999985
# Sold IRFC at 31.55 on 2023-02-07 due to rank 220.0, realized gain: -849.5999999999985
# Sold SWANENERGY at 272.5 on 2023-02-07 due to rank 389.0, realized gain: -11745.300000000003
# Sold PNB at 51.9 on 2023-02-07 due to rank 324.0, realized gain: -1746.4000000000015
# Sold GICRE at 155.3 on 2023-02-07 due to rank 151.0, realized gain: -4749.899999999994
# Sold NIACL at 107.95 on 2023-02-07 due to rank 304.0, realized gain: -4645.800000000003
# Sold TITAGARH at 193.3 on 2023-02-07 due to rank 407.0, realized gain: -6289.5
# Sold GPIL at 385.0 on 2023-02-07 due to rank 164.0, realized gain: -903.0
# Sold IRCON at 57.15 on 2023-02-07 due to rank 218.0, realized gain: -633.6500000000087
# Sold RBLBANK at 157.0 on 2023-02-07 due to rank 345.0, realized gain: -342.3000000000029
# Reduced BANKINDIA to 451 shares on 2023-02-06
# Reduced BLS to 231 shares on 2023-02-06
# Bought JSL on 2023-02-06 at 266.25 no of share : 205
# Bought RVNL on 2023-02-06 at 72.75 no of share : 587
# Bought J&KBANK on 2023-02-06 at 52.75 no of share : 679
# Bought IOB on 2023-02-06 at 26.75 no of share : 1124
# Bought UNIONBANK on 2023-02-06 at 74.3 no of share : 520
# Bought MAHABANK on 2023-02-06 at 28.85 no of share : 1161
# Bought CENTRALBK on 2023-02-06 at 28.0 no of share : 1147
# Bought GPIL on 2023-02-06 at 385.0 no of share : 127
# Bought JWL on 2023-02-06 at 100.3 no of share : 435
# Bought IRFC on 2023-02-06 at 31.55 no of share : 1402
# Bought JINDALSAW on 2023-02-06 at 130.45 no of share : 448
# Bought GICRE on 2023-02-06 at 155.3 no of share : 213
# Bought PNB on 2023-02-06 at 51.9 no of share : 904
# Bought TITAGARH on 2023-02-06 at 193.3 no of share : 204
# Bought GODFRYPHLP on 2023-02-06 at 1827.0 no of share : 23
# Bought NIACL on 2023-02-06 at 107.95 no of share : 343
# Bought USHAMART on 2023-02-06 at 180.5 no of share : 225
# Bought PFC on 2023-02-06 at 113.32 no of share : 583
# Bought PNBHOUSING on 2023-02-06 at 447.91 no of share : 98
# 2023-02-07
# 2023-02-08
# 2023-02-09
# 2023-02-10
# 2023-02-11 market holiday! or sat sun
# 2023-02-12 market holiday! or sat sun
# 2023-02-13
# NIACL below SMA
# Sold NIACL at 103.1 on 2023-02-14, realized gain: -1663.550000000003
# 2023-02-14
# GICRE below SMA
# GODFRYPHLP below SMA
# Sold GICRE at 149.0 on 2023-02-15, realized gain: -1341.9000000000015
# Sold GODFRYPHLP at 1688.95 on 2023-02-15, realized gain: -3175.1500000000015
# File positions_2023-02-14.csv already exists. Loading existing data.
# Sold JSL at 258.65 on 2023-02-15 due to rank 233.0, realized gain: -1558.0000000000073
# Sold RVNL at 69.2 on 2023-02-15 due to rank 356.0, realized gain: -2083.8499999999985
# Sold J&KBANK at 50.6 on 2023-02-15 due to rank 224.0, realized gain: -1459.8499999999985
# Sold IOB at 26.75 on 2023-02-15 due to rank 214.0, realized gain: 0.0
# Sold UNIONBANK at 71.5 on 2023-02-15 due to rank 422.0, realized gain: -1456.0
# Sold MAHABANK at 27.45 on 2023-02-15 due to rank 270.0, realized gain: -1625.3999999999978
# Sold CENTRALBK at 27.3 on 2023-02-15 due to rank 87.0, realized gain: -802.8999999999978
# Sold GPIL at 362.1 on 2023-02-15 due to rank 164.0, realized gain: -2908.2999999999956
# Sold JWL at 101.0 on 2023-02-15 due to rank 240.0, realized gain: 304.5
# Sold IRFC at 29.8 on 2023-02-15 due to rank 220.0, realized gain: -2453.5
# Sold JINDALSAW at 146.0 on 2023-02-15 due to rank 227.0, realized gain: 6966.400000000009
# Sold PNB at 50.4 on 2023-02-15 due to rank 324.0, realized gain: -1356.0
# Sold TITAGARH at 210.5 on 2023-02-15 due to rank 407.0, realized gain: 3508.7999999999956
# Sold USHAMART at 186.45 on 2023-02-15 due to rank 426.0, realized gain: 1338.75
# Sold PFC at 114.32 on 2023-02-15 due to rank 319.0, realized gain: 583.0
# Sold PNBHOUSING at 472.38 on 2023-02-15 due to rank 325.0, realized gain: 2398.0599999999977
# Bought JSL on 2023-02-14 at 258.65 no of share : 203
# Bought RVNL on 2023-02-14 at 69.2 no of share : 588
# Bought JINDALSAW on 2023-02-14 at 146.0 no of share : 411
# Bought IOB on 2023-02-14 at 26.75 no of share : 1143
# Bought J&KBANK on 2023-02-14 at 50.6 no of share : 679
# Bought GPIL on 2023-02-14 at 362.1 no of share : 126
# Bought JWL on 2023-02-14 at 101.0 no of share : 410
# Bought SWANENERGY on 2023-02-14 at 280.0 no of share : 120
# Bought MAHABANK on 2023-02-14 at 27.45 no of share : 1181
# Bought USHAMART on 2023-02-14 at 186.45 no of share : 221
# Bought PNBHOUSING on 2023-02-14 at 472.38 no of share : 96
# Bought TITAGARH on 2023-02-14 at 210.5 no of share : 199
# Bought UNIONBANK on 2023-02-14 at 71.5 no of share : 526
# Bought CENTRALBK on 2023-02-14 at 27.3 no of share : 1185
# Bought IRFC on 2023-02-14 at 29.8 no of share : 1414
# Bought PFC on 2023-02-14 at 114.32 no of share : 563
# Bought JINDALSTEL on 2023-02-14 at 588.0 no of share : 117
# Bought NCC on 2023-02-14 at 92.7 no of share : 578
# 2023-02-15
# BLS below SMA
# Sold BLS at 168.45 on 2023-02-16, realized gain: 842.8499999999913
# 2023-02-16
# 2023-02-17
# 2023-02-18 market holiday! or sat sun
# 2023-02-19 market holiday! or sat sun
# 2023-02-20
# BANKINDIA below SMA
# Sold BANKINDIA at 75.7 on 2023-02-21, realized gain: -6085.5
# 2023-02-21
# CENTRALBK below SMA
# IRFC below SMA
# Sold CENTRALBK at 26.8 on 2023-02-22, realized gain: -592.5
# Sold IRFC at 28.3 on 2023-02-22, realized gain: -2121.0
# 2023-02-22
# IOB below SMA
# SWANENERGY below SMA
# MAHABANK below SMA
# UNIONBANK below SMA
# Sold IOB at 24.4 on 2023-02-23, realized gain: -2686.050000000003
# Sold SWANENERGY at 259.5 on 2023-02-23, realized gain: -2460.0
# Sold MAHABANK at 25.8 on 2023-02-23, realized gain: -1948.6500000000015
# Sold UNIONBANK at 69.5 on 2023-02-23, realized gain: -1052.0
# File positions_2023-02-22.csv already exists. Loading existing data.
# Sold JSL at 272.25 on 2023-02-23 due to rank 233.0, realized gain: 2760.800000000003
# Sold RVNL at 63.9 on 2023-02-23 due to rank 356.0, realized gain: -3116.4000000000015
# Sold JINDALSAW at 153.0 on 2023-02-23 due to rank 227.0, realized gain: 2877.0
# Sold J&KBANK at 48.0 on 2023-02-23 due to rank 224.0, realized gain: -1765.4000000000015
# Sold GPIL at 374.0 on 2023-02-23 due to rank 164.0, realized gain: 1499.3999999999942
# Sold JWL at 102.25 on 2023-02-23 due to rank 240.0, realized gain: 512.5
# Sold USHAMART at 174.5 on 2023-02-23 due to rank 426.0, realized gain: -2640.949999999997
# Sold PNBHOUSING at 473.42 on 2023-02-23 due to rank 325.0, realized gain: 99.84000000000378
# Sold TITAGARH at 209.75 on 2023-02-23 due to rank 407.0, realized gain: -149.25
# Sold PFC at 119.32 on 2023-02-23 due to rank 319.0, realized gain: 2814.9999999999927
# Sold JINDALSTEL at 589.0 on 2023-02-23 due to rank 228.0, realized gain: 117.0
# Sold NCC at 89.45 on 2023-02-23 due to rank 299.0, realized gain: -1878.5
# 2023-02-23
# 2023-02-24
# 2023-02-25 market holiday! or sat sun
# 2023-02-26 market holiday! or sat sun
# 2023-02-27
# 2023-02-28
# 2023-03-01
# 2023-03-02
# File positions_2023-03-02.csv already exists. Loading existing data.
# 2023-03-03
# 2023-03-04 market holiday! or sat sun
# 2023-03-05 market holiday! or sat sun
# 2023-03-06
# 2023-03-07 market holiday! or sat sun
# 2023-03-08
# 2023-03-09
# 2023-03-10
# File positions_2023-03-10.csv already exists. Loading existing data.
# 2023-03-11 market holiday! or sat sun
# 2023-03-12 market holiday! or sat sun
# 2023-03-13
# 2023-03-14
# 2023-03-15
# 2023-03-16
# 2023-03-17
# 2023-03-18 market holiday! or sat sun
# 2023-03-19 market holiday! or sat sun
# 2023-03-20
# File positions_2023-03-20.csv already exists. Loading existing data.
# 2023-03-21
# 2023-03-22
# 2023-03-23
# 2023-03-24
# 2023-03-25 market holiday! or sat sun
# 2023-03-26 market holiday! or sat sun
# 2023-03-27
# 2023-03-28
# File positions_2023-03-28.csv already exists. Loading existing data.
# 2023-03-29
# 2023-03-30 market holiday! or sat sun
# 2023-03-31
# 2023-04-01 market holiday! or sat sun
# 2023-04-02 market holiday! or sat sun
# 2023-04-03
# 2023-04-04 market holiday! or sat sun
# 2023-04-05
# File positions_2023-04-05.csv already exists. Loading existing data.
# 2023-04-06
# 2023-04-07 market holiday! or sat sun
# 2023-04-08 market holiday! or sat sun
# 2023-04-09 market holiday! or sat sun
# 2023-04-10
# 2023-04-11
# 2023-04-12
# 2023-04-13
# File positions_2023-04-13.csv already exists. Loading existing data.
# 2023-04-14 market holiday! or sat sun
# 2023-04-15 market holiday! or sat sun
# 2023-04-16 market holiday! or sat sun
# 2023-04-17
# 2023-04-18
# 2023-04-19
# 2023-04-20
# 2023-04-21
# File positions_2023-04-21.csv already exists. Loading existing data.
# 2023-04-22 market holiday! or sat sun
# 2023-04-23 market holiday! or sat sun
# 2023-04-24
# 2023-04-25
# 2023-04-26
# 2023-04-27
# 2023-04-28
# 2023-04-29 market holiday! or sat sun
# 2023-04-30 market holiday! or sat sun
# 2023-05-01 market holiday! or sat sun
# 2023-05-02
# File positions_2023-05-02.csv already exists. Loading existing data.
# Bought FINCABLES on 2023-05-02 at 904.5 no of share : 64
# Bought SONATSOFTW on 2023-05-02 at 426.0 no of share : 119
# Bought JINDALSAW on 2023-05-02 at 164.65 no of share : 289
# Bought JBMA on 2023-05-02 at 803.5 no of share : 68
# Bought ANURAS on 2023-05-02 at 1139.0 no of share : 73
# Bought ACE on 2023-05-02 at 419.85 no of share : 135
# Bought TITAGARH on 2023-05-02 at 333.45 no of share : 158
# Bought CYIENT on 2023-05-02 at 1185.95 no of share : 62
# Bought SAFARI on 2023-05-02 at 2461.0 no of share : 24
# Bought ZENSARTECH on 2023-05-02 at 279.0 no of share : 198
# Bought TRITURBINE on 2023-05-02 at 367.15 no of share : 138
# Bought NCC on 2023-05-02 at 120.9 no of share : 572
# Bought KPITTECH on 2023-05-02 at 921.35 no of share : 56
# Bought AUROPHARMA on 2023-05-02 at 617.95 no of share : 149
# 2023-05-03
# 2023-05-04
# 2023-05-05
# 2023-05-06 market holiday! or sat sun
# 2023-05-07 market holiday! or sat sun
# 2023-05-08
# 2023-05-09
# 2023-05-10
# File positions_2023-05-10.csv already exists. Loading existing data.
# Sold FINCABLES at 900.0 on 2023-05-11 due to rank 146.0, realized gain: -288.0
# Sold SONATSOFTW at 426.38 on 2023-05-11 due to rank 383.0, realized gain: 45.220000000001164
# Sold JINDALSAW at 161.7 on 2023-05-11 due to rank 233.0, realized gain: -852.5500000000029
# Sold JBMA at 834.0 on 2023-05-11 due to rank 232.0, realized gain: 2074.0
# Sold TITAGARH at 340.8 on 2023-05-11 due to rank 414.0, realized gain: 1161.300000000003
# Sold CYIENT at 1168.85 on 2023-05-11 due to rank 116.0, realized gain: -1060.2000000000116
# Sold SAFARI at 2415.0 on 2023-05-11 due to rank 364.0, realized gain: -1104.0
# Sold ZENSARTECH at 307.75 on 2023-05-11 due to rank 451.0, realized gain: 5692.5
# Sold TRITURBINE at 386.3 on 2023-05-11 due to rank 420.0, realized gain: 2642.7000000000044
# Sold NCC at 112.4 on 2023-05-11 due to rank 305.0, realized gain: -4862.0
# Sold KPITTECH at 884.1 on 2023-05-11 due to rank 258.0, realized gain: -2086.0
# Reduced ANURAS to 64 shares on 2023-05-10
# Bought FINCABLES on 2023-05-10 at 900.0 no of share : 65
# Bought SONATSOFTW on 2023-05-10 at 426.38 no of share : 121
# Bought JBMA on 2023-05-10 at 834.0 no of share : 67
# Bought JINDALSAW on 2023-05-10 at 161.7 no of share : 292
# Bought TITAGARH on 2023-05-10 at 340.8 no of share : 151
# Bought CYIENT on 2023-05-10 at 1168.85 no of share : 59
# Bought TRITURBINE on 2023-05-10 at 386.3 no of share : 134
# Bought SAFARI on 2023-05-10 at 2415.0 no of share : 23
# Bought ZENSARTECH on 2023-05-10 at 307.75 no of share : 201
# Bought NCC on 2023-05-10 at 112.4 no of share : 554
# Bought INDIAMART on 2023-05-10 at 2973.5 no of share : 29
# 2023-05-11
# 2023-05-12
# 2023-05-13 market holiday! or sat sun
# 2023-05-14 market holiday! or sat sun
# 2023-05-15
# 2023-05-16
# 2023-05-17
# 2023-05-18
# File positions_2023-05-18.csv already exists. Loading existing data.
# Sold FINCABLES at 907.95 on 2023-05-19 due to rank 146.0, realized gain: 516.75
# Sold SONATSOFTW at 467.58 on 2023-05-19 due to rank 383.0, realized gain: 4985.200000000004
# Sold JBMA at 760.0 on 2023-05-19 due to rank 232.0, realized gain: -4958.0
# Sold JINDALSAW at 183.0 on 2023-05-19 due to rank 233.0, realized gain: 6219.600000000006
# Sold TITAGARH at 327.4 on 2023-05-19 due to rank 414.0, realized gain: -2023.4000000000087
# Sold CYIENT at 1270.0 on 2023-05-19 due to rank 116.0, realized gain: 5967.850000000006
# Sold TRITURBINE at 400.35 on 2023-05-19 due to rank 420.0, realized gain: 1882.699999999997
# Sold SAFARI at 2537.5 on 2023-05-19 due to rank 364.0, realized gain: 2817.5
# Sold ZENSARTECH at 352.0 on 2023-05-19 due to rank 451.0, realized gain: 8894.25
# Sold NCC at 114.0 on 2023-05-19 due to rank 305.0, realized gain: 886.3999999999942
# Sold INDIAMART at 2930.93 on 2023-05-19 due to rank 211.0, realized gain: -1234.5299999999988
# Reduced ANURAS to 59 shares on 2023-05-18
# Reduced AUROPHARMA to 141 shares on 2023-05-18
# Bought FINCABLES on 2023-05-18 at 907.95 no of share : 67
# Bought JBMA on 2023-05-18 at 760.0 no of share : 66
# Bought SONATSOFTW on 2023-05-18 at 467.58 no of share : 120
# Bought TITAGARH on 2023-05-18 at 327.4 no of share : 148
# Bought CYIENT on 2023-05-18 at 1270.0 no of share : 55
# Bought TRITURBINE on 2023-05-18 at 400.35 no of share : 129
# Bought JINDALSAW on 2023-05-18 at 183.0 no of share : 293
# Bought SAFARI on 2023-05-18 at 2537.5 no of share : 21
# Bought ZENSARTECH on 2023-05-18 at 352.0 no of share : 187
# Bought GLENMARK on 2023-05-18 at 608.1 no of share : 158
# Bought MAHSEAMLES on 2023-05-18 at 442.95 no of share : 144
# 2023-05-19
# 2023-05-20 market holiday! or sat sun
# 2023-05-21 market holiday! or sat sun
# 2023-05-22
# 2023-05-23
# 2023-05-24
# 2023-05-25
# 2023-05-26
# File positions_2023-05-26.csv already exists. Loading existing data.
# Sold FINCABLES at 850.0 on 2023-05-27 due to rank 146.0, realized gain: -3882.6500000000015
# Sold JBMA at 795.8 on 2023-05-27 due to rank 232.0, realized gain: 2362.7999999999956
# Sold SONATSOFTW at 466.85 on 2023-05-27 due to rank 383.0, realized gain: -87.59999999999854
# Sold TITAGARH at 354.05 on 2023-05-27 due to rank 414.0, realized gain: 3944.2000000000044
# Sold CYIENT at 1315.0 on 2023-05-27 due to rank 116.0, realized gain: 2475.0
# Sold TRITURBINE at 394.95 on 2023-05-27 due to rank 420.0, realized gain: -696.6000000000058
# Sold JINDALSAW at 195.25 on 2023-05-27 due to rank 233.0, realized gain: 3589.25
# Sold SAFARI at 2608.9 on 2023-05-27 due to rank 364.0, realized gain: 1499.4000000000015
# Sold ZENSARTECH at 361.65 on 2023-05-27 due to rank 451.0, realized gain: 1804.550000000003
# Sold GLENMARK at 606.2 on 2023-05-27 due to rank 159.0, realized gain: -300.1999999999971
# Sold MAHSEAMLES at 442.0 on 2023-05-27 due to rank 278.0, realized gain: -136.79999999999563
# Reduced ANURAS to 56 shares on 2023-05-26
# Bought FINCABLES on 2023-05-26 at 850.0 no of share : 69
# Bought TITAGARH on 2023-05-26 at 354.05 no of share : 146
# Bought JBMA on 2023-05-26 at 795.8 no of share : 66
# Bought SONATSOFTW on 2023-05-26 at 466.85 no of share : 119
# Bought GLENMARK on 2023-05-26 at 606.2 no of share : 148
# Bought CYIENT on 2023-05-26 at 1315.0 no of share : 51
# Bought TRITURBINE on 2023-05-26 at 394.95 no of share : 126
# Bought MAHSEAMLES on 2023-05-26 at 442.0 no of share : 141
# Bought JINDALSAW on 2023-05-26 at 195.25 no of share : 283
# Bought SAFARI on 2023-05-26 at 2608.9 no of share : 20
# Bought EQUITASBNK on 2023-05-26 at 83.2 no of share : 652
# Bought ZENSARTECH on 2023-05-26 at 361.65 no of share : 172
# 2023-05-27 market holiday! or sat sun
# 2023-05-28 market holiday! or sat sun
# 2023-05-29
# 2023-05-30
# 2023-05-31
# 2023-06-01
# 2023-06-02
# 2023-06-03 market holiday! or sat sun
# 2023-06-04 market holiday! or sat sun
# 2023-06-05
# File positions_2023-06-05.csv already exists. Loading existing data.
# Sold FINCABLES at 795.0 on 2023-06-06 due to rank 146.0, realized gain: -3795.0
# Sold TITAGARH at 380.9 on 2023-06-06 due to rank 414.0, realized gain: 3920.0999999999913
# Sold JBMA at 805.9 on 2023-06-06 due to rank 232.0, realized gain: 666.6000000000058
# Sold SONATSOFTW at 495.0 on 2023-06-06 due to rank 383.0, realized gain: 3349.8499999999985
# Sold GLENMARK at 609.8 on 2023-06-06 due to rank 159.0, realized gain: 532.7999999999884
# Sold CYIENT at 1477.0 on 2023-06-06 due to rank 116.0, realized gain: 8262.0
# Sold TRITURBINE at 390.6 on 2023-06-06 due to rank 420.0, realized gain: -548.0999999999913
# Sold MAHSEAMLES at 483.95 on 2023-06-06 due to rank 278.0, realized gain: 5914.949999999997
# Sold JINDALSAW at 248.3 on 2023-06-06 due to rank 233.0, realized gain: 15013.150000000009
# Sold SAFARI at 2792.4 on 2023-06-06 due to rank 364.0, realized gain: 3670.0
# Sold EQUITASBNK at 87.25 on 2023-06-06 due to rank 139.0, realized gain: 2640.5999999999985
# Sold ZENSARTECH at 405.0 on 2023-06-06 due to rank 451.0, realized gain: 7456.200000000004
# Reduced ANURAS to 53 shares on 2023-06-05
# Reduced AUROPHARMA to 125 shares on 2023-06-05
# Bought TITAGARH on 2023-06-05 at 380.9 no of share : 143
# Bought JBMA on 2023-06-05 at 805.9 no of share : 68
# Bought GLENMARK on 2023-06-05 at 609.8 no of share : 144
# Bought CYIENT on 2023-06-05 at 1477.0 no of share : 46
# Bought MAHSEAMLES on 2023-06-05 at 483.95 no of share : 137
# Bought SONATSOFTW on 2023-06-05 at 495.0 no of share : 119
# Bought FINCABLES on 2023-06-05 at 795.0 no of share : 69
# Bought CHENNPETRO on 2023-06-05 at 381.3 no of share : 165
# Bought SAFARI on 2023-06-05 at 2792.4 no of share : 20
# Bought TRITURBINE on 2023-06-05 at 390.6 no of share : 125
# Bought JINDALSAW on 2023-06-05 at 248.3 no of share : 258
# Bought GLS on 2023-06-05 at 551.0 no of share : 128
# 2023-06-06
# 2023-06-07
# 2023-06-08
# 2023-06-09
# 2023-06-10 market holiday! or sat sun
# 2023-06-11 market holiday! or sat sun
# 2023-06-12
# 2023-06-13
# File positions_2023-06-13.csv already exists. Loading existing data.
# Sold TITAGARH at 418.65 on 2023-06-14 due to rank 414.0, realized gain: 5398.25
# Sold JBMA at 927.0 on 2023-06-14 due to rank 232.0, realized gain: 8234.800000000003
# Sold GLENMARK at 638.55 on 2023-06-14 due to rank 159.0, realized gain: 4140.0
# Sold CYIENT at 1434.9 on 2023-06-14 due to rank 116.0, realized gain: -1936.5999999999913
# Sold MAHSEAMLES at 484.85 on 2023-06-14 due to rank 278.0, realized gain: 123.30000000000291
# Sold SONATSOFTW at 512.0 on 2023-06-14 due to rank 383.0, realized gain: 2023.0
# Sold FINCABLES at 805.95 on 2023-06-14 due to rank 146.0, realized gain: 755.5500000000029
# Sold CHENNPETRO at 372.2 on 2023-06-14 due to rank 97.0, realized gain: -1501.5
# Sold SAFARI at 2909.95 on 2023-06-14 due to rank 364.0, realized gain: 2351.0
# Sold TRITURBINE at 402.8 on 2023-06-14 due to rank 420.0, realized gain: 1525.0
# Sold JINDALSAW at 237.0 on 2023-06-14 due to rank 233.0, realized gain: -2915.4000000000015
# Sold GLS at 615.0 on 2023-06-14 due to rank 160.0, realized gain: 8192.0
# Bought TITAGARH on 2023-06-13 at 418.65 no of share : 137
# Bought JBMA on 2023-06-13 at 927.0 no of share : 67
# Bought GLENMARK on 2023-06-13 at 638.55 no of share : 137
# Bought CYIENT on 2023-06-13 at 1434.9 no of share : 42
# Bought IRCON on 2023-06-13 at 84.2 no of share : 561
# Bought CHENNPETRO on 2023-06-13 at 372.2 no of share : 161
# Bought GLS on 2023-06-13 at 615.0 no of share : 122
# Bought MAHSEAMLES on 2023-06-13 at 484.85 no of share : 135
# Bought SAFARI on 2023-06-13 at 2909.95 no of share : 20
# Bought ADANIPOWER on 2023-06-13 at 272.6 no of share : 203
# Bought HSCL on 2023-06-13 at 129.5 no of share : 481
# Bought RKFORGE on 2023-06-13 at 389.0 no of share : 160
# Bought TRITURBINE on 2023-06-13 at 402.8 no of share : 126
# 2023-06-14
# 2023-06-15
# 2023-06-16
# 2023-06-17 market holiday! or sat sun
# 2023-06-18 market holiday! or sat sun
# 2023-06-19
# 2023-06-20
# 2023-06-21
# File positions_2023-06-21.csv already exists. Loading existing data.
# Sold TITAGARH at 490.75 on 2023-06-22 due to rank 415.0, realized gain: 9877.700000000004
# Sold JBMA at 1042.2 on 2023-06-22 due to rank 232.0, realized gain: 7718.400000000009
# Sold GLENMARK at 643.75 on 2023-06-22 due to rank 159.0, realized gain: 712.4000000000087
# Sold CYIENT at 1502.1 on 2023-06-22 due to rank 116.0, realized gain: 2822.399999999994
# Sold IRCON at 87.5 on 2023-06-22 due to rank 224.0, realized gain: 1851.2999999999956
# Sold CHENNPETRO at 388.4 on 2023-06-22 due to rank 97.0, realized gain: 2608.199999999997
# Sold GLS at 589.0 on 2023-06-22 due to rank 160.0, realized gain: -3172.0
# Sold MAHSEAMLES at 480.6 on 2023-06-22 due to rank 278.0, realized gain: -573.75
# Sold SAFARI at 2970.0 on 2023-06-22 due to rank 365.0, realized gain: 1201.0
# Sold HSCL at 135.5 on 2023-06-22 due to rank 197.0, realized gain: 2886.0
# Sold RKFORGE at 462.0 on 2023-06-22 due to rank 361.0, realized gain: 11680.0
# Sold TRITURBINE at 413.2 on 2023-06-22 due to rank 421.0, realized gain: 1310.3999999999942
# Bought TITAGARH on 2023-06-21 at 490.75 no of share : 129
# Bought JBMA on 2023-06-21 at 1042.2 no of share : 64
# Bought IRCON on 2023-06-21 at 87.5 no of share : 560
# Bought CHENNPETRO on 2023-06-21 at 388.4 no of share : 159
# Bought GLS on 2023-06-21 at 589.0 no of share : 118
# Bought CYIENT on 2023-06-21 at 1502.1 no of share : 40
# Bought GLENMARK on 2023-06-21 at 643.75 no of share : 133
# Bought HSCL on 2023-06-21 at 135.5 no of share : 473
# Bought RKFORGE on 2023-06-21 at 462.0 no of share : 150
# Bought MAHSEAMLES on 2023-06-21 at 480.6 no of share : 135
# Bought SAFARI on 2023-06-21 at 2970.0 no of share : 20
# Bought ENGINERSIN on 2023-06-21 at 121.0 no of share : 528
# 2023-06-22
# 2023-06-23
# 2023-06-24 market holiday! or sat sun
# 2023-06-25 market holiday! or sat sun
# 2023-06-26
# 2023-06-27
# 2023-06-28
# 2023-06-29 market holiday! or sat sun
# 2023-06-30
# File positions_2023-06-30.csv already exists. Loading existing data.
# Sold TITAGARH at 511.55 on 2023-07-01 due to rank 418.0, realized gain: 2683.199999999997
# Sold JBMA at 1243.1 on 2023-07-01 due to rank 232.0, realized gain: 12857.599999999991
# Sold IRCON at 84.5 on 2023-07-01 due to rank 224.0, realized gain: -1680.0
# Sold CHENNPETRO at 387.0 on 2023-07-01 due to rank 97.0, realized gain: -222.59999999999854
# Sold GLS at 568.25 on 2023-07-01 due to rank 160.0, realized gain: -2448.5
# Sold CYIENT at 1463.8 on 2023-07-01 due to rank 116.0, realized gain: -1532.0
# Sold GLENMARK at 678.0 on 2023-07-01 due to rank 159.0, realized gain: 4555.25
# Sold HSCL at 135.1 on 2023-07-01 due to rank 197.0, realized gain: -189.20000000000437
# Sold RKFORGE at 446.0 on 2023-07-01 due to rank 363.0, realized gain: -2400.0
# Sold MAHSEAMLES at 480.65 on 2023-07-01 due to rank 278.0, realized gain: 6.75
# Sold SAFARI at 2975.0 on 2023-07-01 due to rank 367.0, realized gain: 100.0
# Sold ENGINERSIN at 116.0 on 2023-07-01 due to rank 137.0, realized gain: -2640.0
# Bought TITAGARH on 2023-06-30 at 511.55 no of share : 119
# Bought CHENNPETRO on 2023-06-30 at 387.0 no of share : 159
# Bought JBMA on 2023-06-30 at 1243.1 no of share : 59
# Bought IRCON on 2023-06-30 at 84.5 no of share : 561
# Bought RKFORGE on 2023-06-30 at 446.0 no of share : 136
# Bought CHOLAHLDNG on 2023-06-30 at 917.0 no of share : 74
# Bought HSCL on 2023-06-30 at 135.1 no of share : 471
# Bought CYIENT on 2023-06-30 at 1463.8 no of share : 39
# Bought ENGINERSIN on 2023-06-30 at 116.0 no of share : 514
# Bought GLS on 2023-06-30 at 568.25 no of share : 115
# Bought GLENMARK on 2023-06-30 at 678.0 no of share : 130
# Bought SCHNEIDER on 2023-06-30 at 265.8 no of share : 218
# 2023-07-01 market holiday! or sat sun
# 2023-07-02 market holiday! or sat sun
# 2023-07-03
# 2023-07-04
# 2023-07-05
# 2023-07-06
# 2023-07-07
# 2023-07-08 market holiday! or sat sun
# 2023-07-09 market holiday! or sat sun
# 2023-07-10
# File positions_2023-07-10.csv already exists. Loading existing data.
# Sold TITAGARH at 503.0 on 2023-07-11 due to rank 419.0, realized gain: -1017.4500000000044
# Sold CHENNPETRO at 441.75 on 2023-07-11 due to rank 97.0, realized gain: 8705.25
# Sold JBMA at 1355.0 on 2023-07-11 due to rank 232.0, realized gain: 6602.100000000006
# Sold IRCON at 82.5 on 2023-07-11 due to rank 224.0, realized gain: -1122.0
# Sold RKFORGE at 449.0 on 2023-07-11 due to rank 364.0, realized gain: 408.0
# Sold CHOLAHLDNG at 936.0 on 2023-07-11 due to rank 99.0, realized gain: 1406.0
# Sold HSCL at 129.55 on 2023-07-11 due to rank 197.0, realized gain: -2614.0499999999956
# Sold CYIENT at 1494.0 on 2023-07-11 due to rank 116.0, realized gain: 1177.800000000003
# Sold ENGINERSIN at 121.75 on 2023-07-11 due to rank 137.0, realized gain: 2955.5
# Sold GLS at 602.25 on 2023-07-11 due to rank 160.0, realized gain: 3910.0
# Sold GLENMARK at 691.9 on 2023-07-11 due to rank 159.0, realized gain: 1807.0
# Sold SCHNEIDER at 279.95 on 2023-07-11 due to rank 378.0, realized gain: 3084.699999999997
# Reduced AUROPHARMA to 117 shares on 2023-07-10
# Bought TITAGARH on 2023-07-10 at 503.0 no of share : 114
# Bought SUZLON on 2023-07-10 at 18.05 no of share : 3042
# Bought JBMA on 2023-07-10 at 1355.0 no of share : 49
# Bought CHENNPETRO on 2023-07-10 at 441.75 no of share : 154
# Bought SCHNEIDER on 2023-07-10 at 279.95 no of share : 206
# Bought CHOLAHLDNG on 2023-07-10 at 936.0 no of share : 71
# Bought JWL on 2023-07-10 at 176.0 no of share : 323
# Bought JINDALSAW on 2023-07-10 at 285.95 no of share : 202
# Bought RKFORGE on 2023-07-10 at 449.0 no of share : 128
# Bought ENGINERSIN on 2023-07-10 at 121.75 no of share : 508
# Bought HEG on 2023-07-10 at 1584.7 no of share : 39
# Bought IRCON on 2023-07-10 at 82.5 no of share : 586
# Bought TANLA on 2023-07-10 at 1024.8 no of share : 56
# Bought CYIENT on 2023-07-10 at 1494.0 no of share : 39
# 2023-07-11
# 2023-07-12
# 2023-07-13
# 2023-07-14
# 2023-07-15 market holiday! or sat sun
# 2023-07-16 market holiday! or sat sun
# 2023-07-17
# 2023-07-18
# File positions_2023-07-18.csv already exists. Loading existing data.
# Sold TITAGARH at 545.9 on 2023-07-19 due to rank 419.0, realized gain: 4890.5999999999985
# Sold SUZLON at 18.3 on 2023-07-19 due to rank 400.0, realized gain: 760.5
# Sold JBMA at 1478.15 on 2023-07-19 due to rank 232.0, realized gain: 6034.350000000006
# Sold CHENNPETRO at 426.0 on 2023-07-19 due to rank 97.0, realized gain: -2425.5
# Sold SCHNEIDER at 278.75 on 2023-07-19 due to rank 378.0, realized gain: -247.1999999999971
# Sold CHOLAHLDNG at 916.0 on 2023-07-19 due to rank 99.0, realized gain: -1420.0
# Sold JWL at 181.3 on 2023-07-19 due to rank 246.0, realized gain: 1711.9000000000015
# Sold JINDALSAW at 346.0 on 2023-07-19 due to rank 233.0, realized gain: 12130.100000000006
# Sold RKFORGE at 486.0 on 2023-07-19 due to rank 364.0, realized gain: 4736.0
# Sold ENGINERSIN at 129.5 on 2023-07-19 due to rank 137.0, realized gain: 3937.0
# Sold HEG at 1589.3 on 2023-07-19 due to rank 187.0, realized gain: 179.39999999999418
# Sold IRCON at 84.3 on 2023-07-19 due to rank 224.0, realized gain: 1054.7999999999956
# Sold TANLA at 1113.85 on 2023-07-19 due to rank 404.0, realized gain: 4986.799999999996
# Sold CYIENT at 1461.4 on 2023-07-19 due to rank 116.0, realized gain: -1271.3999999999942
# Reduced ACE to 114 shares on 2023-07-18
# Increased ADANIPOWER to 218 shares on 2023-07-18
# Bought SUZLON on 2023-07-18 at 18.3 no of share : 2816
# Bought TITAGARH on 2023-07-18 at 545.9 no of share : 110
# Bought JBMA on 2023-07-18 at 1478.15 no of share : 41
# Bought JINDALSAW on 2023-07-18 at 346.0 no of share : 187
# Bought JWL on 2023-07-18 at 181.3 no of share : 310
# Bought SCHNEIDER on 2023-07-18 at 278.75 no of share : 197
# Bought TANLA on 2023-07-18 at 1113.85 no of share : 53
# Bought CHENNPETRO on 2023-07-18 at 426.0 no of share : 147
# Bought CHOLAHLDNG on 2023-07-18 at 916.0 no of share : 69
# Bought INOXWIND on 2023-07-18 at 47.85 no of share : 1073
# Bought ELECON on 2023-07-18 at 366.33 no of share : 182
# Bought RKFORGE on 2023-07-18 at 486.0 no of share : 124
# Bought UJJIVANSFB on 2023-07-18 at 42.5 no of share : 1604
# Bought HEG on 2023-07-18 at 1589.3 no of share : 37
# 2023-07-19
# 2023-07-20
# 2023-07-21
# ANURAS below SMA
# Sold ANURAS at 978.0 on 2023-07-22, realized gain: -8258.149999999994
# 2023-07-22 market holiday! or sat sun
# 2023-07-23 market holiday! or sat sun
# 2023-07-24
# 2023-07-25
# 2023-07-26
# File positions_2023-07-26.csv already exists. Loading existing data.
# Sold SUZLON at 18.05 on 2023-07-27 due to rank 402.0, realized gain: -704.0
# Sold TITAGARH at 690.0 on 2023-07-27 due to rank 421.0, realized gain: 15851.0
# Sold JBMA at 1422.0 on 2023-07-27 due to rank 233.0, realized gain: -2302.1500000000015
# Sold JINDALSAW at 363.15 on 2023-07-27 due to rank 234.0, realized gain: 3207.050000000003
# Sold JWL at 212.6 on 2023-07-27 due to rank 247.0, realized gain: 9703.0
# Sold SCHNEIDER at 281.85 on 2023-07-27 due to rank 379.0, realized gain: 610.7000000000044
# Sold TANLA at 1247.85 on 2023-07-27 due to rank 406.0, realized gain: 7101.999999999993
# Sold CHENNPETRO at 398.55 on 2023-07-27 due to rank 98.0, realized gain: -4035.1500000000015
# Sold CHOLAHLDNG at 923.0 on 2023-07-27 due to rank 100.0, realized gain: 483.0
# Sold INOXWIND at 51.84 on 2023-07-27 due to rank 219.0, realized gain: 4281.270000000004
# Sold ELECON at 377.5 on 2023-07-27 due to rank 134.0, realized gain: 2032.9400000000023
# Sold RKFORGE at 545.0 on 2023-07-27 due to rank 365.0, realized gain: 7316.0
# Sold UJJIVANSFB at 44.4 on 2023-07-27 due to rank 434.0, realized gain: 3047.5999999999913
# Sold HEG at 1690.95 on 2023-07-27 due to rank 188.0, realized gain: 3761.050000000003
# Reduced ACE to 104 shares on 2023-07-26
# Reduced AUROPHARMA to 111 shares on 2023-07-26
# Bought SUZLON on 2023-07-26 at 18.05 no of share : 2683
# Bought JINDALSAW on 2023-07-26 at 363.15 no of share : 171
# Bought TITAGARH on 2023-07-26 at 690.0 no of share : 102
# Bought TANLA on 2023-07-26 at 1247.85 no of share : 50
# Bought JWL on 2023-07-26 at 212.6 no of share : 288
# Bought JBMA on 2023-07-26 at 1422.0 no of share : 37
# Bought INOXWIND on 2023-07-26 at 51.84 no of share : 987
# Bought SCHNEIDER on 2023-07-26 at 281.85 no of share : 189
# Bought OLECTRA on 2023-07-26 at 1075.0 no of share : 41
# Bought ELECON on 2023-07-26 at 377.5 no of share : 170
# Bought CHENNPETRO on 2023-07-26 at 398.55 no of share : 142
# Bought ENGINERSIN on 2023-07-26 at 149.15 no of share : 479
# Bought UJJIVANSFB on 2023-07-26 at 44.4 no of share : 1602
# Bought CHOLAHLDNG on 2023-07-26 at 923.0 no of share : 68
# Bought RKFORGE on 2023-07-26 at 545.0 no of share : 118
# Bought HEG on 2023-07-26 at 1690.95 no of share : 36
# 2023-07-27
# 2023-07-28
# 2023-07-29 market holiday! or sat sun
# 2023-07-30 market holiday! or sat sun
# 2023-07-31
# 2023-08-01
# 2023-08-02
# 2023-08-03
# File positions_2023-08-03.csv already exists. Loading existing data.
# Sold SUZLON at 18.45 on 2023-08-04 due to rank 406.0, realized gain: 1073.199999999997
# Sold JINDALSAW at 311.55 on 2023-08-04 due to rank 235.0, realized gain: -8823.599999999991
# Sold TITAGARH at 654.4 on 2023-08-04 due to rank 425.0, realized gain: -3631.199999999997
# Sold TANLA at 1157.0 on 2023-08-04 due to rank 410.0, realized gain: -4542.499999999993
# Sold JWL at 202.85 on 2023-08-04 due to rank 248.0, realized gain: -2808.0
# Sold JBMA at 1362.0 on 2023-08-04 due to rank 234.0, realized gain: -2220.0
# Sold INOXWIND at 51.59 on 2023-08-04 due to rank 220.0, realized gain: -246.75
# Sold SCHNEIDER at 280.0 on 2023-08-04 due to rank 383.0, realized gain: -349.65000000000146
# Sold OLECTRA at 1130.0 on 2023-08-04 due to rank 325.0, realized gain: 2255.0
# Sold ELECON at 398.0 on 2023-08-04 due to rank 135.0, realized gain: 3485.0
# Sold CHENNPETRO at 415.1 on 2023-08-04 due to rank 98.0, realized gain: 2350.100000000006
# Sold ENGINERSIN at 149.7 on 2023-08-04 due to rank 139.0, realized gain: 263.44999999998254
# Sold UJJIVANSFB at 48.1 on 2023-08-04 due to rank 438.0, realized gain: 5927.399999999994
# Sold CHOLAHLDNG at 930.45 on 2023-08-04 due to rank 100.0, realized gain: 506.6000000000058
# Sold RKFORGE at 549.35 on 2023-08-04 due to rank 369.0, realized gain: 513.3000000000029
# Sold HEG at 1743.95 on 2023-08-04 due to rank 189.0, realized gain: 1908.0
# Reduced ACE to 92 shares on 2023-08-03
# Bought SUZLON on 2023-08-03 at 18.45 no of share : 2563
# Bought JINDALSAW on 2023-08-03 at 311.55 no of share : 152
# Bought TITAGARH on 2023-08-03 at 654.4 no of share : 94
# Bought INOXWIND on 2023-08-03 at 51.59 no of share : 922
# Bought JWL on 2023-08-03 at 202.85 no of share : 261
# Bought TANLA on 2023-08-03 at 1157.0 no of share : 46
# Bought JBMA on 2023-08-03 at 1362.0 no of share : 35
# Bought OLECTRA on 2023-08-03 at 1130.0 no of share : 37
# Bought SCHNEIDER on 2023-08-03 at 280.0 no of share : 187
# Bought HBLPOWER on 2023-08-03 at 192.0 no of share : 328
# Bought ENGINERSIN on 2023-08-03 at 149.7 no of share : 448
# Bought ELECON on 2023-08-03 at 398.0 no of share : 163
# Bought RKFORGE on 2023-08-03 at 549.35 no of share : 111
# Bought UJJIVANSFB on 2023-08-03 at 48.1 no of share : 1504
# Bought HEG on 2023-08-03 at 1743.95 no of share : 35
# Bought LODHA on 2023-08-03 at 732.8 no of share : 73
# Bought CHENNPETRO on 2023-08-03 at 415.1 no of share : 139
# 2023-08-04
# 2023-08-05 market holiday! or sat sun
# 2023-08-06 market holiday! or sat sun
# 2023-08-07
# 2023-08-08
# 2023-08-09
# 2023-08-10
# 2023-08-11
# File positions_2023-08-11.csv already exists. Loading existing data.
# Sold SUZLON at 20.75 on 2023-08-12 due to rank 406.0, realized gain: 5894.9000000000015
# Sold JINDALSAW at 348.3 on 2023-08-12 due to rank 235.0, realized gain: 5586.0
# Sold TITAGARH at 664.9 on 2023-08-12 due to rank 425.0, realized gain: 987.0
# Sold INOXWIND at 53.5 on 2023-08-12 due to rank 220.0, realized gain: 1761.0199999999968
# Sold JWL at 242.0 on 2023-08-12 due to rank 248.0, realized gain: 10218.150000000001
# Sold TANLA at 1161.0 on 2023-08-12 due to rank 410.0, realized gain: 184.0
# Sold JBMA at 1284.95 on 2023-08-12 due to rank 234.0, realized gain: -2696.75
# Sold OLECTRA at 1068.25 on 2023-08-12 due to rank 325.0, realized gain: -2284.75
# Sold SCHNEIDER at 298.0 on 2023-08-12 due to rank 383.0, realized gain: 3366.0
# Sold HBLPOWER at 221.1 on 2023-08-12 due to rank 184.0, realized gain: 9544.800000000003
# Sold ENGINERSIN at 150.25 on 2023-08-12 due to rank 139.0, realized gain: 246.40000000000873
# Sold ELECON at 395.0 on 2023-08-12 due to rank 135.0, realized gain: -489.0
# Sold RKFORGE at 572.85 on 2023-08-12 due to rank 369.0, realized gain: 2608.5
# Sold UJJIVANSFB at 48.7 on 2023-08-12 due to rank 438.0, realized gain: 902.3999999999942
# Sold HEG at 1718.0 on 2023-08-12 due to rank 189.0, realized gain: -908.25
# Sold LODHA at 696.85 on 2023-08-12 due to rank 270.0, realized gain: -2624.3499999999913
# Sold CHENNPETRO at 375.5 on 2023-08-12 due to rank 98.0, realized gain: -5504.4000000000015
# Reduced ACE to 84 shares on 2023-08-11
# Reduced AUROPHARMA to 103 shares on 2023-08-11
# Bought SUZLON on 2023-08-11 at 20.75 no of share : 2493
# Bought JINDALSAW on 2023-08-11 at 348.3 no of share : 142
# Bought TITAGARH on 2023-08-11 at 664.9 no of share : 90
# Bought JWL on 2023-08-11 at 242.0 no of share : 240
# Bought INOXWIND on 2023-08-11 at 53.5 no of share : 874
# Bought TANLA on 2023-08-11 at 1161.0 no of share : 44
# Bought HBLPOWER on 2023-08-11 at 221.1 no of share : 287
# Bought OLECTRA on 2023-08-11 at 1068.25 no of share : 35
# Bought JBMA on 2023-08-11 at 1284.95 no of share : 34
# Bought ENGINERSIN on 2023-08-11 at 150.25 no of share : 418
# Bought ELECON on 2023-08-11 at 395.0 no of share : 157
# Bought RKFORGE on 2023-08-11 at 572.85 no of share : 106
# Bought SCHNEIDER on 2023-08-11 at 298.0 no of share : 185
# Bought KALYANKJIL on 2023-08-11 at 182.35 no of share : 345
# Bought UJJIVANSFB on 2023-08-11 at 48.7 no of share : 1393
# Bought BSE on 2023-08-11 at 895.0 no of share : 90
# Bought ZENSARTECH on 2023-08-11 at 516.95 no of share : 126
# Bought LODHA on 2023-08-11 at 696.85 no of share : 73
# 2023-08-12 market holiday! or sat sun
# 2023-08-13 market holiday! or sat sun
# 2023-08-14
# 2023-08-15 market holiday! or sat sun
# 2023-08-16
# 2023-08-17
# 2023-08-18
# 2023-08-19 market holiday! or sat sun
# 2023-08-20 market holiday! or sat sun
# 2023-08-21
# File positions_2023-08-21.csv already exists. Loading existing data.
# Sold SUZLON at 20.1 on 2023-08-22 due to rank 406.0, realized gain: -1620.449999999997
# Sold JINDALSAW at 320.8 on 2023-08-22 due to rank 235.0, realized gain: -3905.0
# Sold TITAGARH at 639.7 on 2023-08-22 due to rank 425.0, realized gain: -2267.9999999999927
# Sold JWL at 282.9 on 2023-08-22 due to rank 248.0, realized gain: 9816.0
# Sold INOXWIND at 47.53 on 2023-08-22 due to rank 220.0, realized gain: -5217.779999999999
# Sold TANLA at 1080.0 on 2023-08-22 due to rank 410.0, realized gain: -3564.0
# Sold HBLPOWER at 266.0 on 2023-08-22 due to rank 184.0, realized gain: 12886.300000000003
# Sold OLECTRA at 1194.95 on 2023-08-22 due to rank 325.0, realized gain: 4434.5
# Sold JBMA at 1401.0 on 2023-08-22 due to rank 234.0, realized gain: 3945.699999999997
# Sold ENGINERSIN at 154.5 on 2023-08-22 due to rank 139.0, realized gain: 1776.5
# Sold ELECON at 417.25 on 2023-08-22 due to rank 135.0, realized gain: 3493.25
# Sold RKFORGE at 606.4 on 2023-08-22 due to rank 369.0, realized gain: 3556.2999999999884
# Sold SCHNEIDER at 333.0 on 2023-08-22 due to rank 383.0, realized gain: 6475.0
# Sold KALYANKJIL at 216.0 on 2023-08-22 due to rank 251.0, realized gain: 11609.25
# Sold UJJIVANSFB at 48.85 on 2023-08-22 due to rank 438.0, realized gain: 208.9499999999971
# Sold BSE at 868.35 on 2023-08-22 due to rank 78.0, realized gain: -2398.5
# Sold ZENSARTECH at 506.75 on 2023-08-22 due to rank 462.0, realized gain: -1285.2000000000044
# Sold LODHA at 696.05 on 2023-08-22 due to rank 270.0, realized gain: -58.40000000000873
# Bought SUZLON on 2023-08-21 at 20.1 no of share : 2455
# Bought JWL on 2023-08-21 at 282.9 no of share : 221
# Bought JINDALSAW on 2023-08-21 at 320.8 no of share : 135
# Bought TITAGARH on 2023-08-21 at 639.7 no of share : 86
# Bought HBLPOWER on 2023-08-21 at 266.0 no of share : 254
# Bought INOXWIND on 2023-08-21 at 47.53 no of share : 842
# Bought KALYANKJIL on 2023-08-21 at 216.0 no of share : 312
# Bought OLECTRA on 2023-08-21 at 1194.95 no of share : 34
# Bought JBMA on 2023-08-21 at 1401.0 no of share : 32
# Bought TANLA on 2023-08-21 at 1080.0 no of share : 42
# Bought RKFORGE on 2023-08-21 at 606.4 no of share : 103
# Bought ELECON on 2023-08-21 at 417.25 no of share : 154
# Bought SCHNEIDER on 2023-08-21 at 333.0 no of share : 176
# ...
# Bought FINCABLES on 2024-07-31 at 1599.9 no of share : 30
# Bought POWERINDIA on 2024-07-31 at 11777.05 no of share : 3
# Bought DIXON on 2024-07-31 at 12601.1 no of share : 5
# Bought JKPAPER on 2024-07-31 at 521.55 no of share : 87
# Bought CROMPTON on 2024-07-31 at 449.15 no of share : 158
# Bought UNOMINDA on 2024-07-31 at 1059.5 no of share : 44
# Bought WHIRLPOOL on 2024-07-31 at 2147.05 no of share : 30
# Bought EXIDEIND on 2024-07-31 at 537.7 no of share : 107
# Bought COROMANDEL on 2024-07-31 at 1666.05 no of share : 44
# Bought M&M on 2024-07-31 at 2937.0 no of share : 26
# Bought KNRCON on 2024-07-31 at 411.0 no of share : 125
# Bought SUZLON on 2024-07-31 at 70.11 no of share : 998
# Bought GPIL on 2024-07-31 at 1117.9 no of share : 46
# Bought DEEPAKFERT on 2024-07-31 at 968.75 no of share : 62
# Bought NBCC on 2024-07-31 at 185.25 no of share : 231
# Bought SAREGAMA on 2024-07-31 at 560.6 no of share : 103
# Bought SUNTECK on 2024-07-31 at 601.5 no of share : 86
# Bought GLENMARK on 2024-07-31 at 1434.5 no of share : 54
# Bought VGUARD on 2024-07-31 at 460.8 no of share : 129
# Bought TRENT on 2024-07-31 at 5625.05 no of share : 12
# Bought ESCORTS on 2024-07-31 at 4145.0 no of share : 16
# Bought TIMKEN on 2024-07-31 at 4234.0 no of share : 11
# Bought SUMICHEM on 2024-07-31 at 520.0 no of share : 111
# Bought EIDPARRY on 2024-07-31 at 828.0 no of share : 76
# Bought GODFRYPHLP on 2024-07-31 at 4255.8 no of share : 10
# Bought GLAXO on 2024-07-31 at 2710.5 no of share : 20
# Bought GRINDWELL on 2024-07-31 at 2700.0 no of share : 21
# Bought SUNTV on 2024-07-31 at 879.35 no of share : 87
# 2024-08-01
# 2024-08-02
# 2024-08-03 market holiday! or sat sun
# 2024-08-04 market holiday! or sat sun
# 2024-08-05
# 2024-08-06
# 2024-08-07
# 2024-08-08
# File positions_2024-08-08.csv already exists. Loading existing data.
# Sold COCHINSHIP at 2360.0 on 2024-08-09 due to rank 110.0, realized gain: -4800.0
# Sold EMAMILTD at 787.95 on 2024-08-09 due to rank 143.0, realized gain: -752.3999999999942
# Sold MOTHERSON at 180.91 on 2024-08-09 due to rank 309.0, realized gain: -4994.790000000001
# Sold FINCABLES at 1493.5 on 2024-08-09 due to rank 154.0, realized gain: -3192.0
# Sold POWERINDIA at 10970.0 on 2024-08-09 due to rank 359.0, realized gain: -2421.149999999994
# Sold DIXON at 11640.0 on 2024-08-09 due to rank 132.0, realized gain: -4805.5
# Sold JKPAPER at 481.0 on 2024-08-09 due to rank 246.0, realized gain: -3527.8499999999985
# Sold CROMPTON at 437.9 on 2024-08-09 due to rank 118.0, realized gain: -1777.5
# Sold UNOMINDA at 999.0 on 2024-08-09 due to rank 457.0, realized gain: -2662.0
# Sold WHIRLPOOL at 2067.35 on 2024-08-09 due to rank 473.0, realized gain: -2391.0000000000073
# Sold EXIDEIND at 498.7 on 2024-08-09 due to rank 150.0, realized gain: -4173.0
# Sold COROMANDEL at 1608.0 on 2024-08-09 due to rank 114.0, realized gain: -2554.199999999997
# Sold M&M at 2660.5 on 2024-08-09 due to rank 286.0, realized gain: -7189.0
# Sold KNRCON at 374.8 on 2024-08-09 due to rank 265.0, realized gain: -4525.0
# Sold SUZLON at 71.0 on 2024-08-09 due to rank 420.0, realized gain: 888.2200000000012
# Sold GPIL at 1155.0 on 2024-08-09 due to rank 178.0, realized gain: 1706.5999999999985
# Sold DEEPAKFERT at 1025.0 on 2024-08-09 due to rank 127.0, realized gain: 3487.5
# Sold NBCC at 171.33 on 2024-08-09 due to rank 322.0, realized gain: -3215.519999999997
# Sold SAREGAMA at 491.0 on 2024-08-09 due to rank 392.0, realized gain: -7168.800000000003
# Sold SUNTECK at 550.0 on 2024-08-09 due to rank 416.0, realized gain: -4429.0
# Sold GLENMARK at 1459.0 on 2024-08-09 due to rank 168.0, realized gain: 1323.0
# Sold VGUARD at 473.3 on 2024-08-09 due to rank 465.0, realized gain: 1612.5
# Sold TRENT at 5515.0 on 2024-08-09 due to rank 444.0, realized gain: -1320.6000000000058
# Sold ESCORTS at 3720.0 on 2024-08-09 due to rank 149.0, realized gain: -6800.0
# Sold TIMKEN at 4064.95 on 2024-08-09 due to rank 439.0, realized gain: -1859.550000000003
# Sold SUMICHEM at 505.0 on 2024-08-09 due to rank 412.0, realized gain: -1665.0
# Sold EIDPARRY at 759.0 on 2024-08-09 due to rank 139.0, realized gain: -5244.0
# Sold GODFRYPHLP at 4180.05 on 2024-08-09 due to rank 174.0, realized gain: -757.5
# Sold GLAXO at 2834.65 on 2024-08-09 due to rank 167.0, realized gain: 2483.0
# Sold GRINDWELL at 2440.6 on 2024-08-09 due to rank 183.0, realized gain: -5447.4000000000015
# Sold SUNTV at 888.0 on 2024-08-09 due to rank 417.0, realized gain: 752.5500000000029
# Reduced BHARATFORG to 37 shares on 2024-08-08
# Bought COCHINSHIP on 2024-08-08 at 2360.0 no of share : 15
# Bought EMAMILTD on 2024-08-08 at 787.95 no of share : 64
# Bought MOTHERSON on 2024-08-08 at 180.91 no of share : 321
# Bought FINCABLES on 2024-08-08 at 1493.5 no of share : 31
# Bought DIXON on 2024-08-08 at 11640.0 no of share : 5
# Bought SUZLON on 2024-08-08 at 71.0 no of share : 930
# Bought DEEPAKFERT on 2024-08-08 at 1025.0 no of share : 56
# Bought WHIRLPOOL on 2024-08-08 at 2067.35 no of share : 29
# Bought JKPAPER on 2024-08-08 at 481.0 no of share : 84
# Bought POWERINDIA on 2024-08-08 at 10970.0 no of share : 3
# Bought CROMPTON on 2024-08-08 at 437.9 no of share : 149
# Bought COROMANDEL on 2024-08-08 at 1608.0 no of share : 43
# Bought UNOMINDA on 2024-08-08 at 999.0 no of share : 44
# Bought KNRCON on 2024-08-08 at 374.8 no of share : 120
# Bought INDIACEM on 2024-08-08 at 368.0 no of share : 160
# Bought GLENMARK on 2024-08-08 at 1459.0 no of share : 53
# Bought VGUARD on 2024-08-08 at 473.3 no of share : 125
# Bought GLAXO on 2024-08-08 at 2834.65 no of share : 20
# Bought SUNTV on 2024-08-08 at 888.0 no of share : 85
# Bought GPIL on 2024-08-08 at 1155.0 no of share : 46
# Bought SUVENPHAR on 2024-08-08 at 990.85 no of share : 60
# Bought NBCC on 2024-08-08 at 171.33 no of share : 222
# Bought SUNTECK on 2024-08-08 at 550.0 no of share : 84
# Bought TRENT on 2024-08-08 at 5515.0 no of share : 12
# Bought M&M on 2024-08-08 at 2660.5 no of share : 25
# Bought CHOLAHLDNG on 2024-08-08 at 1474.85 no of share : 36
# Bought LALPATHLAB on 2024-08-08 at 3273.0 no of share : 25
# Bought OIL on 2024-08-08 at 617.8 no of share : 78
# Bought AFFLE on 2024-08-08 at 1492.75 no of share : 39
# Bought PRAJIND on 2024-08-08 at 678.0 no of share : 74
# Bought SUMICHEM on 2024-08-08 at 505.0 no of share : 108
# 2024-08-09
# 2024-08-10 market holiday! or sat sun
# 2024-08-11 market holiday! or sat sun
# 2024-08-12
# 2024-08-13
# 2024-08-14
# BALKRISIND below SMA
# Sold BALKRISIND at 2799.05 on 2024-08-15, realized gain: -9219.549999999996
# 2024-08-15 market holiday! or sat sun
# 2024-08-16
# File positions_2024-08-16.csv already exists. Loading existing data.
# Sold COCHINSHIP at 2240.0 on 2024-08-17 due to rank 110.0, realized gain: -1800.0
# Sold EMAMILTD at 809.5 on 2024-08-17 due to rank 143.0, realized gain: 1379.199999999997
# Sold MOTHERSON at 188.1 on 2024-08-17 due to rank 310.0, realized gain: 2307.989999999998
# Sold FINCABLES at 1480.0 on 2024-08-17 due to rank 154.0, realized gain: -418.5
# Sold DIXON at 12087.0 on 2024-08-17 due to rank 132.0, realized gain: 2235.0
# Sold SUZLON at 77.95 on 2024-08-17 due to rank 421.0, realized gain: 6463.5
# Sold DEEPAKFERT at 965.75 on 2024-08-17 due to rank 127.0, realized gain: -3318.0
# Sold WHIRLPOOL at 2059.75 on 2024-08-17 due to rank 474.0, realized gain: -220.39999999999418
# Sold JKPAPER at 487.0 on 2024-08-17 due to rank 246.0, realized gain: 504.0
# Sold POWERINDIA at 11150.0 on 2024-08-17 due to rank 360.0, realized gain: 540.0
# Sold CROMPTON at 429.05 on 2024-08-17 due to rank 118.0, realized gain: -1318.6499999999942
# Sold COROMANDEL at 1692.85 on 2024-08-17 due to rank 114.0, realized gain: 3648.550000000003
# Sold UNOMINDA at 1118.0 on 2024-08-17 due to rank 458.0, realized gain: 5236.0
# Sold KNRCON at 350.0 on 2024-08-17 due to rank 266.0, realized gain: -2976.0
# Sold INDIACEM at 365.75 on 2024-08-17 due to rank 219.0, realized gain: -360.0
# Sold GLENMARK at 1514.7 on 2024-08-17 due to rank 168.0, realized gain: 2952.100000000006
# Sold VGUARD at 521.3 on 2024-08-17 due to rank 466.0, realized gain: 5999.999999999993
# Sold GLAXO at 2830.0 on 2024-08-17 due to rank 167.0, realized gain: -93.0
# Sold SUNTV at 816.0 on 2024-08-17 due to rank 418.0, realized gain: -6120.0
# Sold GPIL at 970.0 on 2024-08-17 due to rank 178.0, realized gain: -8510.0
# Sold SUVENPHAR at 1000.0 on 2024-08-17 due to rank 420.0, realized gain: 549.0
# Sold NBCC at 176.5 on 2024-08-17 due to rank 323.0, realized gain: 1147.739999999998
# Sold SUNTECK at 589.45 on 2024-08-17 due to rank 417.0, realized gain: 3313.800000000003
# Sold TRENT at 6440.0 on 2024-08-17 due to rank 445.0, realized gain: 11100.0
# Sold M&M at 2789.0 on 2024-08-17 due to rank 287.0, realized gain: 3212.5
# Sold CHOLAHLDNG at 1572.85 on 2024-08-17 due to rank 105.0, realized gain: 3528.0
# Sold LALPATHLAB at 3210.2 on 2024-08-17 due to rank 273.0, realized gain: -1570.0
# Sold OIL at 664.95 on 2024-08-17 due to rank 337.0, realized gain: 3677.7000000000116
# Sold PRAJIND at 708.7 on 2024-08-17 due to rank 362.0, realized gain: 2271.800000000003
# Sold SUMICHEM at 538.0 on 2024-08-17 due to rank 413.0, realized gain: 3564.0
# Reduced BIKAJI to 78 shares on 2024-08-16
# Reduced AFFLE to 37 shares on 2024-08-16
# Reduced BLUEDART to 7 shares on 2024-08-16
# Bought COCHINSHIP on 2024-08-16 at 2240.0 no of share : 15
# Bought EMAMILTD on 2024-08-16 at 809.5 no of share : 63
# Bought SUZLON on 2024-08-16 at 77.95 no of share : 848
# Bought DEEPAKFERT on 2024-08-16 at 965.75 no of share : 53
# Bought INDIACEM on 2024-08-16 at 365.75 no of share : 162
# Bought MOTHERSON on 2024-08-16 at 188.1 no of share : 311
# Bought DIXON on 2024-08-16 at 12087.0 no of share : 5
# Bought FINCABLES on 2024-08-16 at 1480.0 no of share : 31
# Bought WHIRLPOOL on 2024-08-16 at 2059.75 no of share : 29
# Bought SUVENPHAR on 2024-08-16 at 1000.0 no of share : 55
# Bought COROMANDEL on 2024-08-16 at 1692.85 no of share : 41
# Bought OIL on 2024-08-16 at 664.95 no of share : 73
# Bought GRANULES on 2024-08-16 at 673.05 no of share : 118
# Bought UNOMINDA on 2024-08-16 at 1118.0 no of share : 44
# Bought GLENMARK on 2024-08-16 at 1514.7 no of share : 51
# Bought JKPAPER on 2024-08-16 at 487.0 no of share : 83
# Bought VGUARD on 2024-08-16 at 521.3 no of share : 120
# Bought CHOLAHLDNG on 2024-08-16 at 1572.85 no of share : 35
# Bought KNRCON on 2024-08-16 at 350.0 no of share : 117
# Bought CROMPTON on 2024-08-16 at 429.05 no of share : 146
# Bought TRENT on 2024-08-16 at 6440.0 no of share : 11
# Bought NATCOPHARM on 2024-08-16 at 1468.1 no of share : 44
# Bought GLAXO on 2024-08-16 at 2830.0 no of share : 20
# Bought OFSS on 2024-08-16 at 10799.8 no of share : 5
# Bought SUNTV on 2024-08-16 at 816.0 no of share : 81
# Bought LALPATHLAB on 2024-08-16 at 3210.2 no of share : 24
# Bought JUBLFOOD on 2024-08-16 at 640.0 no of share : 115
# Bought PRAJIND on 2024-08-16 at 708.7 no of share : 73
# Bought SUNTECK on 2024-08-16 at 589.45 no of share : 83
# Bought NBCC on 2024-08-16 at 176.5 no of share : 215
# Bought GESHIP on 2024-08-16 at 1380.0 no of share : 32
# Bought POWERINDIA on 2024-08-16 at 11150.0 no of share : 3
# 2024-08-17 market holiday! or sat sun
# 2024-08-18 market holiday! or sat sun
# 2024-08-19
# 2024-08-20
# 2024-08-21
# 2024-08-22
# 2024-08-23
# 2024-08-24 market holiday! or sat sun
# 2024-08-25 market holiday! or sat sun
# 2024-08-26
# File positions_2024-08-26.csv already exists. Loading existing data.
# Sold COCHINSHIP at 2100.0 on 2024-08-27 due to rank 110.0, realized gain: -2100.0
# Sold EMAMILTD at 816.0 on 2024-08-27 due to rank 143.0, realized gain: 409.5
# Sold SUZLON at 79.34 on 2024-08-27 due to rank 421.0, realized gain: 1178.7200000000012
# Sold DEEPAKFERT at 1079.35 on 2024-08-27 due to rank 127.0, realized gain: 6020.799999999996
# Sold INDIACEM at 368.5 on 2024-08-27 due to rank 219.0, realized gain: 445.5
# Sold MOTHERSON at 199.4 on 2024-08-27 due to rank 310.0, realized gain: 3514.300000000003
# Sold DIXON at 13399.0 on 2024-08-27 due to rank 132.0, realized gain: 6560.0
# Sold FINCABLES at 1482.0 on 2024-08-27 due to rank 154.0, realized gain: 62.0
# Sold WHIRLPOOL at 2054.0 on 2024-08-27 due to rank 474.0, realized gain: -166.75
# Sold SUVENPHAR at 1079.4 on 2024-08-27 due to rank 420.0, realized gain: 4367.000000000007
# Sold COROMANDEL at 1748.5 on 2024-08-27 due to rank 114.0, realized gain: 2281.6500000000087
# Sold OIL at 687.0 on 2024-08-27 due to rank 337.0, realized gain: 1609.6499999999942
# Sold GRANULES at 690.1 on 2024-08-27 due to rank 180.0, realized gain: 2011.9000000000087
# Sold UNOMINDA at 1126.95 on 2024-08-27 due to rank 458.0, realized gain: 393.8000000000029
# Sold GLENMARK at 1695.5 on 2024-08-27 due to rank 168.0, realized gain: 9220.800000000003
# Sold JKPAPER at 477.4 on 2024-08-27 due to rank 246.0, realized gain: -796.8000000000029
# Sold VGUARD at 471.0 on 2024-08-27 due to rank 466.0, realized gain: -6035.999999999993
# Sold CHOLAHLDNG at 1718.0 on 2024-08-27 due to rank 105.0, realized gain: 5080.25
# Sold KNRCON at 341.4 on 2024-08-27 due to rank 266.0, realized gain: -1006.2000000000044
# Sold CROMPTON at 460.5 on 2024-08-27 due to rank 118.0, realized gain: 4591.699999999997
# Sold TRENT at 7000.0 on 2024-08-27 due to rank 445.0, realized gain: 6160.0
# Sold NATCOPHARM at 1567.7 on 2024-08-27 due to rank 319.0, realized gain: 4382.400000000009
# Sold GLAXO at 2959.0 on 2024-08-27 due to rank 167.0, realized gain: 2580.0
# Sold OFSS at 11049.0 on 2024-08-27 due to rank 336.0, realized gain: 1246.0
# Sold SUNTV at 777.9 on 2024-08-27 due to rank 418.0, realized gain: -3086.0999999999985
# Sold LALPATHLAB at 3302.0 on 2024-08-27 due to rank 273.0, realized gain: 2203.2000000000116
# Sold JUBLFOOD at 650.25 on 2024-08-27 due to rank 251.0, realized gain: 1178.75
# Sold PRAJIND at 763.0 on 2024-08-27 due to rank 362.0, realized gain: 3963.899999999994
# Sold SUNTECK at 629.55 on 2024-08-27 due to rank 417.0, realized gain: 3328.2999999999884
# Sold NBCC at 180.1 on 2024-08-27 due to rank 323.0, realized gain: 774.0
# Sold GESHIP at 1325.05 on 2024-08-27 due to rank 163.0, realized gain: -1758.4000000000015
# Sold POWERINDIA at 12288.0 on 2024-08-27 due to rank 360.0, realized gain: 3414.0
# Reduced BIKAJI to 71 shares on 2024-08-26
# Increased AEGISLOG to 48 shares on 2024-08-26
# Increased BDL to 27 shares on 2024-08-26
# Bought SUZLON on 2024-08-26 at 79.34 no of share : 771
# Bought COCHINSHIP on 2024-08-26 at 2100.0 no of share : 15
# Bought DEEPAKFERT on 2024-08-26 at 1079.35 no of share : 49
# Bought INDIACEM on 2024-08-26 at 368.5 no of share : 170
# Bought EMAMILTD on 2024-08-26 at 816.0 no of share : 63
# Bought GRANULES on 2024-08-26 at 690.1 no of share : 116
# Bought OIL on 2024-08-26 at 687.0 no of share : 71
# Bought SUVENPHAR on 2024-08-26 at 1079.4 no of share : 52
# Bought GLENMARK on 2024-08-26 at 1695.5 no of share : 49
# Bought MOTHERSON on 2024-08-26 at 199.4 no of share : 308
# Bought DIXON on 2024-08-26 at 13399.0 no of share : 5
# Bought COROMANDEL on 2024-08-26 at 1748.5 no of share : 40
# Bought CHOLAHLDNG on 2024-08-26 at 1718.0 no of share : 34
# Bought OFSS on 2024-08-26 at 11049.0 no of share : 5
# Bought WHIRLPOOL on 2024-08-26 at 2054.0 no of share : 29
# Bought FSL on 2024-08-26 at 324.4 no of share : 161
# Bought NATCOPHARM on 2024-08-26 at 1567.7 no of share : 42
# Bought PAYTM on 2024-08-26 at 559.8 no of share : 84
# Bought UNOMINDA on 2024-08-26 at 1126.95 no of share : 44
# Bought TRENT on 2024-08-26 at 7000.0 no of share : 11
# Bought VGUARD on 2024-08-26 at 471.0 no of share : 112
# Bought KALYANKJIL on 2024-08-26 at 589.0 no of share : 87
# Bought PERSISTENT on 2024-08-26 at 4960.0 no of share : 13
# Bought PRAJIND on 2024-08-26 at 763.0 no of share : 71
# Bought CERA on 2024-08-26 at 9680.05 no of share : 6
# Bought JUBLFOOD on 2024-08-26 at 650.25 no of share : 112
# Bought LALPATHLAB on 2024-08-26 at 3302.0 no of share : 24
# Bought SUNTECK on 2024-08-26 at 629.55 no of share : 82
# Bought NBCC on 2024-08-26 at 180.1 no of share : 213
# Bought GLAXO on 2024-08-26 at 2959.0 no of share : 20
# Bought FINCABLES on 2024-08-26 at 1482.0 no of share : 32
# Bought CAMS on 2024-08-26 at 4434.0 no of share : 11
# 2024-08-27
# 2024-08-28
# 2024-08-29
# 2024-08-30
# BDL below SMA
# Sold BDL at 1300.0 on 2024-08-31, realized gain: 28373.949999999997

# %% [markdown]
# #Visualizations

# %%
total_return = (equity[-1] - equity[0]) / equity[0] * 100
print('total_return : ', total_return)
# Out:
# total_return :  143.7412528958349

# %%
plt.figure(figsize=(20, 6))
plt.plot(dates,equity, linestyle='-', color='b')
plt.xlabel('Date')
plt.ylabel('Equity Value')
plt.title('Equity Value Over Time')
plt.grid(True)
plt.show()

# %%
def calculate_cagr(beginning_value, ending_value, years):
    
    if beginning_value <= 0 or years <= 0:
        raise ValueError("Beginning value and years must be greater than zero.")
    
    cagr = (ending_value / beginning_value) ** (1 / years) - 1
    
    return cagr * 100  


years = 1 + (8 / 12)     

cagr = calculate_cagr(equity[0], equity[-1], years)
print(f"The CAGR is: {cagr:.2f}%")
# Out:
# The CAGR is: 70.67%

# %%
total_return = (equity[-1] - equity[0]) / equity[0] * 100
print('total_return : ', total_return)
# Out:
# total_return :  143.7412528958349

# %%
import numpy as np

def calculate_sharpe_ratio(daily_equity, risk_free_rate=0.07, trading_days=252):
    
    daily_returns = np.diff(daily_equity) / daily_equity[:-1]
    
    
    avg_daily_return = np.mean(daily_returns)
    annualized_return = avg_daily_return * trading_days
    
    
    daily_volatility = np.std(daily_returns)
    annualized_volatility = daily_volatility * np.sqrt(trading_days)
    
    
    sharpe_ratio = (annualized_return - risk_free_rate) / annualized_volatility
    return sharpe_ratio

sharpe_ratio = calculate_sharpe_ratio(equity)
print('Sharpe Ratio : ', sharpe_ratio)
# Out:
# Sharpe Ratio :  2.306195715361315

# %%
nifty500_data = nifty500_data.loc[nifty500_data['date'] >= start_date]
nifty500_data = nifty500_data.loc[nifty500_data['date'] <=end_date]

nifty50_data = nifty50_data.loc[nifty50_data['date'] >= start_date]
nifty50_data = nifty50_data.loc[nifty50_data['date'] <=end_date]
nifty500_data.shape, len(equity), nifty50_data.shape
# Out:
# ((412, 9), 412, (412, 9))

# %%
data = {
    'Equity' : equity,
    'Nifty 50' : nifty50_data['close'],
    'Nifty 500' : nifty500_data['close']
}
df = pd.DataFrame(data)
df['Equity Daily Return'] = df['Equity'].pct_change() * 100
df['Nifty 50 Daily Return'] = df['Nifty 50'].pct_change() * 100
df['Nifty 500 Daily Return'] = df['Nifty 500'].pct_change() * 100

# Calculate cumulative returns
df['Equity Cumulative Return'] = (1 + df['Equity Daily Return'] / 100).cumprod() - 1
df['Nifty 50 Cumulative Return'] = (1 + df['Nifty 50 Daily Return'] / 100).cumprod() - 1
df['Nifty 500 Cumulative Return'] = (1 + df['Nifty 500 Daily Return'] / 100).cumprod() - 1

# Convert cumulative returns to percentage
df['Equity Cumulative Return'] *= 100
df['Nifty 50 Cumulative Return'] *= 100
df['Nifty 500 Cumulative Return'] *= 100

# Plot the cumulative returns
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Equity Cumulative Return'], label='Equity Cumulative Return v1', color='blue')
plt.plot(df.index, df['Nifty 50 Cumulative Return'], label='Nifty 50 Cumulative Return', color='red')

plt.plot(df.index, df['Nifty 500 Cumulative Return'], label='Nifty 500 Cumulative Return', color='green')

plt.title('Cumulative Returns Comparison')
plt.xlabel('Date')
plt.ylabel('Cumulative Return (%)')
plt.legend()
plt.grid(True)
plt.show()

# %%
def calculate_drawdown(series):
    running_max = series.cummax()
    drawdown = (series - running_max) / series
    max_drawdown = drawdown.min()
    return drawdown, max_drawdown

# Calculate drawdowns
df['Equity Drawdown'], max_drawdown_equity = calculate_drawdown(df['Equity'])
df['Nifty 50 Drawdown'], max_drawdown_nifty50 = calculate_drawdown(df['Nifty 50'])
df['Nifty 500 Drawdown'], max_drawdown_nifty500 = calculate_drawdown(df['Nifty 500'])

print(f"\nMaximum drawdown for Equity: {max_drawdown_equity * 100:.2f}%")
print(f"Maximum drawdown for Nifty 50: {max_drawdown_nifty50 * 100:.2f}%")
print(f"Maximum drawdown for Nifty 500: {max_drawdown_nifty500 * 100:.2f}%")

# Plot drawdowns
plt.figure(figsize=(14, 7))
plt.plot(dates, df['Equity Drawdown'], linestyle='-', color='blue', label='Equity Drawdown')
plt.plot(dates, df['Nifty 50 Drawdown'], linestyle='-', color='red', label='Nifty 50 Drawdown')
plt.plot(dates, df['Nifty 500 Drawdown'], linestyle='-', color='green', label='Nifty 500 Drawdown')
plt.xlabel('Date')
plt.ylabel('Drawdown %')
plt.title('Drawdown Over Time')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Maximum drawdown for Equity: -15.40%
# Maximum drawdown for Nifty 50: -7.60%
# Maximum drawdown for Nifty 500: -9.47%
